# %% [markdown]
# # Sales Data Exploration.
# In the realm of sales analysis, where numbers and data are the guiding stars, a story of commerce unfolds. It's a narrative that goes beyond the mere exchange of products and services; it's a journey into the heart of businesses, revealing the secrets of success and the pathways to growth. This story revolves around a MySQL database, a digital ledger that holds the records of orders from prominent companies such as Walmart, Microsoft, and more. Within this digital realm, we discover the pulse of sales, the best-sellers, the most significant customers, and the dynamic sales growth rate.
#
# At the heart of this data-driven exploration, the data virtuoso takes the stage, armed with cutting-edge tools and techniques for analysis. The mission is to transform raw data into actionable insights, shedding light on the products that shine brightest in the marketplace. It's about identifying the best-sellers that resonate with consumers, offering businesses a roadmap for success.
#
# But it's not just about products; it's also about customers. The database reveals the biggest customers, the driving force behind revenue generation. The data virtuoso meticulously scrutinizes the records, recognizing the names that leave an indelible mark on the company's ledger. They paint a picture of customer loyalty and engagement.
#
# As the exploration delves deeper into the database, it's not just data analysis; it's storytelling. The sales growth rate becomes a compelling narrative, a journey of businesses navigating the ever-evolving currents of commerce. With expertise and precision, the data virtuoso tracks this growth, offering businesses a vision of their future.
#
# In collaboration with the project team, captivating data visualizations are crafted, bringing these insights to life. Graphs and charts become windows into the world of commerce, offering a visual narrative that complements the depth of data. In the world of sales analysis, the data virtuoso may remain behind the scenes, but their dedication to transforming data into actionable insights makes every transaction extraordinary. They are the unsung heroes of commerce, driving businesses forward and contributing to the ongoing saga of economic growth and achievement.

# %% [markdown]
# # Task 1: Data Download, Import, and Database Connection.

# %%
pip install --upgrade pip

# %%
pip install sqlalchemy pymysql

# %%
pip install ipython-sql

# %%
# -- Load the sql extention ----
# %load_ext sql

# %%
# --- Load your mysql db using credentials from the "DB" area ---
#%sql mysql+pymysql://<user>:<password>@localhost/<db_name>
#22se@localhost/b476dbe7
# %sql mysql+pymysql://root:@localhost/Sales_EDA

# %%
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %% [markdown]
# # Task 1: Mapping the Commerce of the Midwest.
# Within the database's intricate web, a query unfolds, revealing the tapestry of the "Midwest" region. As the data virtuoso, we unearth the connections, with region names, sales reps, and account names forming the threads of this narrative. Through the meticulous SQL query, we bridge the gaps, forging links from region to representative to account, all within the expansive Midwest. And as the results emerge, ordered alphabetically by account name, the story of commerce in this region comes to life, showcasing the ordered harmony of business relationships in the heart of the Midwest.
#
# ===========
#
# Midwest Region Sales and Their Associated Accounts.
# Write SQL query for the following:
#
# Which sales and their associated accounts are located in the Midwest region, and what are their names?

# %%
# %%sql
# select sr.name as Name,acct.name as Associated_accounts, r.name as Region from sales_reps sr
# JOIN region r ON sr.region_id = r.id
# JOIN accounts acct ON sr.id = acct.sales_rep_id
# WHERE r.name = 'Midwest';
# Out:
#  * mysql+pymysql://root:***@localhost/Sales_EDA
# 48 rows affected.
# [('Sherlene Wetherington', 'Rite Aid', 'Midwest'),
#  ('Chau Rowles', 'Tech Data', 'Midwest'),
#  ('Carletta Kosinski', "McDonald's", 'Midwest'),
#  ('Charles Bidwell', 'Qualcomm', 'Midwest'),
#  ('Cliff Meints', 'Sears Holdings', 'Midwest'),
#  ('Delilah Krum', 'Capital One Financial', 'Midwest'),
#  ('Kathleen Lalonde', 'EMC', 'Midwest'),
#  ('Julie Starr', 'USAA', 'Midwest'),
#  ('Cordell Rieder', 'Duke Energy', 'Midwest'),
#  ('Sherlene Wetherington', 'Time Warner Cable', 'Midwest'),
#  ('Chau Rowles', 'Halliburton', 'Midwest'),
#  ('Carletta Kosinski', 'Northrop Grumman', 'Midwest'),
#  ('Charles Bidwell', 'Arrow Electronics', 'Midwest'),
#  ('Cliff Meints', 'Raytheon', 'Midwest'),
#  ('Delilah Krum', 'Plains GP Holdings', 'Midwest'),
#  ('Kathleen Lalonde', 'US Foods Holding', 'Midwest'),
#  ('Julie Starr', 'AbbVie', 'Midwest'),
#  ('Cordell Rieder', 'Centene', 'Midwest'),
#  ('Sherlene Wetherington', 'Community Health Systems', 'Midwest'),
#  ('Chau Rowles', 'Alcoa', 'Midwest'),
#  ('Carletta Kosinski', 'International Paper', 'Midwest'),
#  ('Charles Bidwell', 'Emerson Electric', 'Midwest'),
#  ('Cliff Meints', 'Union Pacific', 'Midwest'),
#  ('Delilah Krum', 'Amgen', 'Midwest'),
#  ('Sherlene Wetherington', 'U.S. Bancorp', 'Midwest'),
#  ('Chau Rowles', 'Staples', 'Midwest'),
#  ('Carletta Kosinski', 'Danaher', 'Midwest'),
#  ('Charles Bidwell', 'Whirlpool', 'Midwest'),
#  ('Cliff Meints', 'Aflac', 'Midwest'),
#  ('Delilah Krum', 'AutoNation', 'Midwest'),
#  ('Sherlene Wetherington', 'Progressive', 'Midwest'),
#  ('Chau Rowles', 'Abbott Laboratories', 'Midwest'),
#  ('Carletta Kosinski', 'Dollar General', 'Midwest'),
#  ('Charles Bidwell', 'Tenet Healthcare', 'Midwest'),
#  ('Cliff Meints', 'Eli Lilly', 'Midwest'),
#  ('Delilah Krum', 'Southwest Airlines', 'Midwest'),
#  ('Kathleen Lalonde', 'Penske Automotive Group', 'Midwest'),
#  ('Julie Starr', 'ManpowerGroup', 'Midwest'),
#  ('Cordell Rieder', "Kohl's", 'Midwest'),
#  ('Charles Bidwell', 'Starbucks', 'Midwest'),
#  ('Cliff Meints', 'Paccar', 'Midwest'),
#  ('Delilah Krum', 'Cummins', 'Midwest'),
#  ('Charles Bidwell', 'Altria Group', 'Midwest'),
#  ('Cliff Meints', 'Xerox', 'Midwest'),
#  ('Delilah Krum', 'Kimberly-Clark', 'Midwest'),
#  ('Delilah Krum', 'Hartford Financial Services Group', 'Midwest'),
#  ('Kathleen Lalonde', 'Kraft Heinz', 'Midwest'),
#  ('Julie Starr', 'Lear', 'Midwest')]

# %% [markdown]
# # Task 2: Sifting for Gold in the Midwest.
# In the world of Midwest commerce, a query has uncovered a unique facet. By isolating sales representatives with names starting with 'S,' we've unveiled a distinct narrative. The results, elegantly ordered by account name, shed light on the intricate relationships forged by this 'S' factor. It's a story of selective synergy, offering insights into how these representatives connect with various accounts. In the heartland of the Midwest, the data virtuoso has unveiled a fascinating story where a single letter becomes a key to understanding the complex tapestry of sales.
#
# ============
#
# Midwest Region Sales Representatives with 'S' Initial and Their Associated Accounts.
# Write SQL query for the following:
#
# Which sales representatives with names starting with 'S' are associated with accounts in the Midwest region, and what are their names and the names of their accounts?

# %%
# %%sql
# select sr.name as Name, acct.name as Associated_accounts, r.name as Region  from sales_reps sr
# JOIN region r ON sr.region_id = r.id
# JOIN accounts acct ON sr.id = acct.sales_rep_id
# WHERE r.name = 'Midwest' and sr.name LIKE 'S%';
# Out:
#  * mysql+pymysql://root:***@localhost/Sales_EDA
# 5 rows affected.
# [('Sherlene Wetherington', 'Rite Aid', 'Midwest'),
#  ('Sherlene Wetherington', 'Time Warner Cable', 'Midwest'),
#  ('Sherlene Wetherington', 'Community Health Systems', 'Midwest'),
#  ('Sherlene Wetherington', 'U.S. Bancorp', 'Midwest'),
#  ('Sherlene Wetherington', 'Progressive', 'Midwest')]

# %% [markdown]
# # Task 3: Kaleidoscope of Sales.
# In the vast data landscape of Midwest commerce, a unique perspective unfolds. This SQL query spotlights sales representatives with 'K' in their names, revealing the intricate ties between regions, reps, and accounts. The results, thoughtfully sorted by account name, unveil the influence of the 'K' factor. It's a tale of selective synergy, providing insights into the special connections these representatives have with a diverse range of accounts. This Midwest journey, driven by a single letter, offers a captivating snapshot of the complex web of business relationships that define the region.
#
# ==========
#
# Midwest Region Sales Representatives with 'K' in Their Name and Their Associated Accounts.
# Write SQL query for the following:
#
# Which sales representatives with 'K' in their name are associated with accounts in the Midwest region, and what are their names and the names of their accounts?

# %%
# %%sql
# select sr.name as Name, acct.name as Associated_accounts, r.name as Region from sales_reps sr
# JOIN region r ON sr.region_id = r.id
# JOIN accounts acct ON sr.id = acct.sales_rep_id
# WHERE r.name = 'Midwest' and sr.name LIKE '%K%';
# Out:
#  * mysql+pymysql://root:***@localhost/Sales_EDA
# 17 rows affected.
# [('Carletta Kosinski', "McDonald's", 'Midwest'),
#  ('Delilah Krum', 'Capital One Financial', 'Midwest'),
#  ('Kathleen Lalonde', 'EMC', 'Midwest'),
#  ('Carletta Kosinski', 'Northrop Grumman', 'Midwest'),
#  ('Delilah Krum', 'Plains GP Holdings', 'Midwest'),
#  ('Kathleen Lalonde', 'US Foods Holding', 'Midwest'),
#  ('Carletta Kosinski', 'International Paper', 'Midwest'),
#  ('Delilah Krum', 'Amgen', 'Midwest'),
#  ('Carletta Kosinski', 'Danaher', 'Midwest'),
#  ('Delilah Krum', 'AutoNation', 'Midwest'),
#  ('Carletta Kosinski', 'Dollar General', 'Midwest'),
#  ('Delilah Krum', 'Southwest Airlines', 'Midwest'),
#  ('Kathleen Lalonde', 'Penske Automotive Group', 'Midwest'),
#  ('Delilah Krum', 'Cummins', 'Midwest'),
#  ('Delilah Krum', 'Kimberly-Clark', 'Midwest'),
#  ('Delilah Krum', 'Hartford Financial Services Group', 'Midwest'),
#  ('Kathleen Lalonde', 'Kraft Heinz', 'Midwest')]

# %% [markdown]
# # Task 4: Uncovering Value in Sales.
# Within the intricate sales data tapestry, an intriguing narrative unfolds. The SQL query dissects the connections between regions, accounts, and orders, focusing on those with a standard quantity exceeding 100. The query's results reveal the unit price calculated from the total amount and quantity, offering insights into the worth of each unit within these sales transactions. It's a story of value in commerce, underscoring the significance of each unit's pricing dynamics, inspiring businesses to embrace a deeper understanding of the true worth of their sales units.
#
# =======
#
# Unit Price Calculation for Orders with Standard Quantity > 100.
# Write SQL query for the following:
#
# For orders with a standard quantity greater than 100, what is the unit price of each order in the all region, along with the associated account names?
#
# Unit price is calculated dividing the total amount in USD by the sum of the total quantity and a small constant (0.01) to avoid division by zero errors.

# %%
# %%sql
# select region.name as region, accounts.name as account_name, total_amt_usd/(total + 0.01) as unit_price from orders
# JOIN accounts ON accounts.id = orders.account_id
# JOIN sales_reps ON sales_reps.id = accounts.sales_rep_id
# JOIN region ON region.id = sales_reps.region_id
# WHERE orders.standard_qty > 100;
# Out:
#  * mysql+pymysql://root:***@localhost/Sales_EDA
# 3748 rows affected.
# [('Northeast', 'Walmart', Decimal('5.759600')),
#  ('Northeast', 'Walmart', Decimal('5.965175')),
#  ('Northeast', 'Walmart', Decimal('5.444236')),
#  ('Northeast', 'Walmart', Decimal('5.960184')),
#  ('Northeast', 'Walmart', Decimal('6.168719')),
#  ('Northeast', 'Walmart', Decimal('6.628910')),
#  ('Northeast', 'Walmart', Decimal('5.646522')),
#  ('Northeast', 'Walmart', Decimal('6.033417')),
#  ('Northeast', 'Walmart', Decimal('6.019492')),
#  ('Northeast', 'Walmart', Decimal('6.109804')),
#  ('Northeast', 'Walmart', Decimal('6.391138')),
#  ('Northeast', 'Exxon Mobil', Decimal('5.054602')),
#  ('Northeast', 'Apple', Decimal('5.096584')),
#  ('Northeast', 'Apple', Decimal('5.263203')),
#  ('Northeast', 'Apple', Decimal('5.120315')),
#  ('Northeast', 'Apple', Decimal('5.176939')),
#  ('Northeast', 'Apple', Decimal('5.064018')),
#  ('Northeast', 'Apple', Decimal('5.093753')),
#  ('Northeast', 'Berkshire Hathaway', Decimal('5.483687')),
#  ('Northeast', 'McKesson', Decimal('5.713830')),
#  ('Northeast', 'McKesson', Decimal('5.157017')),
#  ('Northeast', 'McKesson', Decimal('5.700722')),
#  ('Northeast', 'UnitedHealth Group', Decimal('5.346446')),
#  ('Northeast', 'UnitedHealth Group', Decimal('5.203317')),
#  ('Northeast', 'UnitedHealth Group', Decimal('4.996325')),
#  ('Northeast', 'UnitedHealth Group', Decimal('5.388178')),
#  ('Northeast', 'UnitedHealth Group', Decimal('5.078483')),
#  ('Northeast', 'UnitedHealth Group', Decimal('5.001227')),
#  ('Northeast', 'CVS Health', Decimal('5.543245')),
#  ('Northeast', 'CVS Health', Decimal('5.215494')),
#  ('Northeast', 'CVS Health', Decimal('5.327233')),
#  ('Northeast', 'General Motors', Decimal('5.150514')),
#  ('Northeast', 'Ford Motor', Decimal('5.601537')),
#  ('Northeast', 'Ford Motor', Decimal('5.224125')),
#  ('Northeast', 'Ford Motor', Decimal('5.318459')),
#  ('Northeast', 'Ford Motor', Decimal('5.407441')),
#  ('Northeast', 'Ford Motor', Decimal('5.720084')),
#  ('Northeast', 'Ford Motor', Decimal('5.511822')),
#  ('Northeast', 'Ford Motor', Decimal('5.257023')),
#  ('Northeast', 'Ford Motor', Decimal('5.391009')),
#  ('Northeast', 'Ford Motor', Decimal('5.376737')),
#  ('Northeast', 'Ford Motor', Decimal('5.274691')),
#  ('Northeast', 'Ford Motor', Decimal('6.283316')),
#  ('Northeast', 'Ford Motor', Decimal('5.400304')),
#  ('Northeast', 'Ford Motor', Decimal('5.567637')),
#  ('Northeast', 'Ford Motor', Decimal('5.196454')),
#  ('Northeast', 'Ford Motor', Decimal('5.723279')),
#  ('Northeast', 'Ford Motor', Decimal('5.332718')),
#  ('Northeast', 'Ford Motor', Decimal('5.508440')),
#  ('Northeast', 'Ford Motor', Decimal('5.468120')),
#  ('Northeast', 'Ford Motor', Decimal('5.911658')),
#  ('Northeast', 'Ford Motor', Decimal('5.201323')),
#  ('Northeast', 'Ford Motor', Decimal('5.319939')),
#  ('Northeast', 'Ford Motor', Decimal('5.214993')),
#  ('Northeast', 'AT&T', Decimal('5.341577')),
#  ('Northeast', 'AT&T', Decimal('5.608680')),
#  ('Northeast', 'AT&T', Decimal('6.437321')),
#  ('Northeast', 'AT&T', Decimal('5.441766')),
#  ('Northeast', 'AT&T', Decimal('5.334939')),
#  ('Northeast', 'AT&T', Decimal('6.266068')),
#  ('Northeast', 'AT&T', Decimal('5.414653')),
#  ('Northeast', 'AT&T', Decimal('5.203528')),
#  ('Northeast', 'AT&T', Decimal('5.172586')),
#  ('Northeast', 'AT&T', Decimal('5.088025')),
#  ('Northeast', 'AT&T', Decimal('5.585653')),
#  ('Northeast', 'AT&T', Decimal('5.322164')),
#  ('Northeast', 'AT&T', Decimal('5.164744')),
#  ('Northeast', 'AT&T', Decimal('5.175419')),
#  ('Northeast', 'AT&T', Decimal('5.447050')),
#  ('Northeast', 'AT&T', Decimal('5.962569')),
#  ('Northeast', 'AT&T', Decimal('5.418070')),
#  ('Northeast', 'AT&T', Decimal('5.283107')),
#  ('Northeast', 'AT&T', Decimal('5.195857')),
#  ('Northeast', 'AT&T', Decimal('5.117063')),
#  ('Northeast', 'AT&T', Decimal('5.780112')),
#  ('Northeast', 'AT&T', Decimal('5.304367')),
#  ('Northeast', 'AT&T', Decimal('5.240789')),
#  ('Northeast', 'AT&T', Decimal('5.149926')),
#  ('Northeast', 'AT&T', Decimal('5.068925')),
#  ('Northeast', 'AT&T', Decimal('5.234805')),
#  ('Northeast', 'General Electric', Decimal('6.664058')),
#  ('Northeast', 'General Electric', Decimal('5.501285')),
#  ('Northeast', 'General Electric', Decimal('4.989641')),
#  ('Northeast', 'General Electric', Decimal('5.312163')),
#  ('Northeast', 'General Electric', Decimal('5.602701')),
#  ('Northeast', 'General Electric', Decimal('5.632470')),
#  ('Northeast', 'General Electric', Decimal('5.268478')),
#  ('Northeast', 'General Electric', Decimal('5.040933')),
#  ('Northeast', 'General Electric', Decimal('5.216976')),
#  ('Northeast', 'General Electric', Decimal('5.531317')),
#  ('Northeast', 'General Electric', Decimal('5.221530')),
#  ('Northeast', 'AmerisourceBergen', Decimal('5.649435')),
#  ('Northeast', 'AmerisourceBergen', Decimal('5.252686')),
#  ('Northeast', 'Verizon', Decimal('5.336815')),
#  ('Northeast', 'Verizon', Decimal('5.431839')),
#  ('Northeast', 'Verizon', Decimal('5.656130')),
#  ('Northeast', 'Verizon', Decimal('5.288250')),
#  ('Northeast', 'Verizon', Decimal('5.152959')),
#  ('Northeast', 'Verizon', Decimal('5.620015')),
#  ('Northeast', 'Verizon', Decimal('5.408454')),
#  ('Northeast', 'Verizon', Decimal('5.192963')),
#  ('Northeast', 'Verizon', Decimal('5.195887')),
#  ('Northeast', 'Verizon', Decimal('5.480068')),
#  ('Northeast', 'Verizon', Decimal('5.260360')),
#  ('Northeast', 'Verizon', Decimal('5.100598')),
#  ('Northeast', 'Verizon', Decimal('5.136446')),
#  ('Northeast', 'Verizon', Decimal('6.044141')),
#  ('Northeast', 'Verizon', Decimal('5.551963')),
#  ('Northeast', 'Verizon', Decimal('5.324556')),
#  ('Northeast', 'Chevron', Decimal('5.278027')),
#  ('Northeast', 'Chevron', Decimal('5.415160')),
#  ('Northeast', 'Chevron', Decimal('5.812953')),
#  ('Northeast', 'Chevron', Decimal('5.148455')),
#  ('Northeast', 'Chevron', Decimal('5.452700')),
#  ('Northeast', 'Chevron', Decimal('5.201323')),
#  ('Northeast', 'Costco', Decimal('4.989741')),
#  ('Northeast', 'Costco', Decimal('5.501370')),
#  ('Northeast', 'Costco', Decimal('5.129227')),
#  ('Northeast', 'Costco', Decimal('7.789352')),
#  ('Northeast', 'Fannie Mae', Decimal('5.303465')),
#  ('Northeast', 'Kroger', Decimal('5.299510')),
#  ('Northeast', 'Kroger', Decimal('5.083263')),
#  ('Northeast', 'Kroger', Decimal('5.163775')),
#  ('Northeast', 'Kroger', Decimal('5.501820')),
#  ('Northeast', 'Kroger', Decimal('5.067556')),
#  ('Northeast', 'Kroger', Decimal('5.157473')),
#  ('Northeast', 'Kroger', Decimal('5.173693')),
#  ('Northeast', 'Kroger', Decimal('5.189732')),
#  ('Northeast', 'Kroger', Decimal('5.024350')),
#  ('Northeast', 'Kroger', Decimal('5.186140')),
#  ('Northeast', 'Kroger', Decimal('5.059405')),
#  ('Northeast', 'Amazon.com', Decimal('5.309992')),
#  ('Northeast', 'Amazon.com', Decimal('5.557375')),
#  ('Northeast', 'Amazon.com', Decimal('5.395732')),
#  ('Northeast', 'Amazon.com', Decimal('5.461857')),
#  ('Northeast', 'Amazon.com', Decimal('5.786983')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('4.989853')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.151333')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.121471')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.150585')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.502939')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.231842')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.023752')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('4.989899')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.100155')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.081248')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.314747')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.047949')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.015979')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.002992')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.071125')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.200979')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.051362')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.089148')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.042585')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('4.989898')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.039192')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.047706')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.270806')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.026740')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.115180')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.182755')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.009900')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.087216')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.042170')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.062226')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.079023')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.010060')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.160940')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.183404')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.038540')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.170311')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.442049')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.142908')),
#  ('Northeast', 'HP', Decimal('5.092426')),
#  ('Northeast', 'HP', Decimal('5.178766')),
#  ('Northeast', 'HP', Decimal('5.531106')),
#  ('Northeast', 'HP', Decimal('5.163029')),
#  ('Northeast', 'HP', Decimal('5.008568')),
#  ('Northeast', 'HP', Decimal('5.030511')),
#  ('Northeast', 'HP', Decimal('5.062412')),
#  ('Northeast', 'HP', Decimal('5.132488')),
#  ('Northeast', 'HP', Decimal('5.270952')),
#  ('Northeast', 'HP', Decimal('5.054968')),
#  ('Northeast', 'HP', Decimal('5.021262')),
#  ('Northeast', 'Cardinal Health', Decimal('4.989898')),
#  ('Northeast', 'Cardinal Health', Decimal('5.055987')),
#  ('Northeast', 'Express Scripts Holding', Decimal('5.454423')),
#  ('Northeast', 'Express Scripts Holding', Decimal('5.241451')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.059207')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.501737')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.056242')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.129274')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.238064')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.167183')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.188819')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.137718')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.047763')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.177848')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.093422')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('4.989914')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.089794')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('6.842059')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.008136')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.078878')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.194669')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.623648')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.415237')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.069646')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('4.989902')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.132488')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.039503')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.483336')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.248992')),
#  ('Northeast', 'Boeing', Decimal('5.025467')),
#  ('Northeast', 'Boeing', Decimal('5.135514')),
#  ('Northeast', 'Boeing', Decimal('5.072452')),
#  ('Northeast', 'Boeing', Decimal('5.058433')),
#  ('Northeast', 'Boeing', Decimal('5.131107')),
#  ('Northeast', 'Boeing', Decimal('5.542594')),
#  ('Northeast', 'Boeing', Decimal('5.167812')),
#  ('Northeast', 'Boeing', Decimal('5.052535')),
#  ('Northeast', 'Boeing', Decimal('7.270149')),
#  ('Northeast', 'Boeing', Decimal('4.989901')),
#  ('Northeast', 'Microsoft', Decimal('5.374271')),
#  ('Northeast', 'Microsoft', Decimal('5.109297')),
#  ('Northeast', 'Microsoft', Decimal('5.529288')),
#  ('Northeast', 'Microsoft', Decimal('5.172294')),
#  ('Northeast', 'Microsoft', Decimal('6.307081')),
#  ('Northeast', 'Microsoft', Decimal('5.271661')),
#  ('Northeast', 'Microsoft', Decimal('5.615670')),
#  ('Northeast', 'Bank of America Corp.', Decimal('5.931267')),
#  ('Northeast', 'Bank of America Corp.', Decimal('5.879538')),
#  ('Northeast', 'Bank of America Corp.', Decimal('5.892090')),
#  ('Northeast', 'Bank of America Corp.', Decimal('6.124906')),
#  ('Northeast', 'Bank of America Corp.', Decimal('5.863708')),
#  ('Northeast', 'Bank of America Corp.', Decimal('5.408765')),
#  ('Northeast', 'Bank of America Corp.', Decimal('6.246445')),
#  ('Northeast', 'Wells Fargo', Decimal('5.403403')),
#  ('Northeast', 'Wells Fargo', Decimal('5.423982')),
#  ('Northeast', 'Wells Fargo', Decimal('5.351069')),
#  ('Northeast', 'Wells Fargo', Decimal('5.106850')),
#  ('Northeast', 'Wells Fargo', Decimal('6.726313')),
#  ('Northeast', 'Wells Fargo', Decimal('5.247181')),
#  ('Northeast', 'Wells Fargo', Decimal('5.259737')),
#  ('Northeast', 'Wells Fargo', Decimal('5.474829')),
#  ('Northeast', 'Wells Fargo', Decimal('5.214326')),
#  ('Northeast', 'Wells Fargo', Decimal('5.505888')),
#  ('Northeast', 'Wells Fargo', Decimal('5.664071')),
#  ('Northeast', 'Wells Fargo', Decimal('5.063125')),
#  ('Northeast', 'Wells Fargo', Decimal('5.646109')),
#  ('Northeast', 'Wells Fargo', Decimal('5.498593')),
#  ('Northeast', 'Wells Fargo', Decimal('5.427258')),
#  ('Northeast', 'Wells Fargo', Decimal('5.180569')),
#  ('Northeast', 'Wells Fargo', Decimal('5.494559')),
#  ('Northeast', 'Wells Fargo', Decimal('5.619837')),
#  ('Northeast', 'Wells Fargo', Decimal('5.508945')),
#  ('Northeast', 'Wells Fargo', Decimal('5.406281')),
#  ('Northeast', 'Wells Fargo', Decimal('5.348868')),
#  ('Northeast', 'Wells Fargo', Decimal('5.138873')),
#  ('Northeast', 'Wells Fargo', Decimal('5.127637')),
#  ('Northeast', 'Wells Fargo', Decimal('5.463717')),
#  ('Northeast', 'Wells Fargo', Decimal('5.441204')),
#  ('Northeast', 'Wells Fargo', Decimal('5.703632')),
#  ('Northeast', 'Home Depot', Decimal('6.230713')),
#  ('Northeast', 'Citigroup', Decimal('5.312915')),
#  ('Northeast', 'Citigroup', Decimal('5.059207')),
#  ('Northeast', 'Citigroup', Decimal('5.890765')),
#  ('Northeast', 'Citigroup', Decimal('6.179003')),
#  ('Northeast', 'Citigroup', Decimal('5.186155')),
#  ('Northeast', 'Citigroup', Decimal('5.363698')),
#  ('Northeast', 'Citigroup', Decimal('5.079527')),
#  ('Northeast', 'Citigroup', Decimal('5.028351')),
#  ('Northeast', 'Citigroup', Decimal('5.072446')),
#  ('Northeast', 'Citigroup', Decimal('4.989923')),
#  ('Northeast', 'Citigroup', Decimal('6.646222')),
#  ('Northeast', 'Citigroup', Decimal('5.020080')),
#  ('Northeast', 'Citigroup', Decimal('5.042196')),
#  ('Northeast', 'Citigroup', Decimal('5.073502')),
#  ('Northeast', 'Citigroup', Decimal('6.050384')),
#  ('Northeast', 'Citigroup', Decimal('5.161663')),
#  ('Northeast', 'Citigroup', Decimal('5.204077')),
#  ('Northeast', 'Citigroup', Decimal('5.117986')),
#  ('Northeast', 'Citigroup', Decimal('5.496349')),
#  ('Northeast', 'Citigroup', Decimal('4.996260')),
#  ('Northeast', 'Citigroup', Decimal('5.460688')),
#  ('Northeast', 'Citigroup', Decimal('4.989897')),
#  ('Northeast', 'Citigroup', Decimal('5.061180')),
#  ('Northeast', 'Citigroup', Decimal('5.919668')),
#  ('Northeast', 'Citigroup', Decimal('5.151528')),
#  ('Northeast', 'Citigroup', Decimal('5.358370')),
#  ('Northeast', 'Citigroup', Decimal('5.249528')),
#  ('Northeast', 'Citigroup', Decimal('5.015937')),
#  ('Northeast', 'Citigroup', Decimal('5.060906')),
#  ('Northeast', 'Citigroup', Decimal('4.989900')),
#  ('Northeast', 'Citigroup', Decimal('5.534252')),
#  ('Northeast', 'Citigroup', Decimal('5.019840')),
#  ('Northeast', 'Citigroup', Decimal('5.273081')),
#  ('Northeast', 'Citigroup', Decimal('5.848606')),
#  ('Northeast', 'Citigroup', Decimal('5.158198')),
#  ('Northeast', 'Citigroup', Decimal('6.018041')),
#  ('Northeast', 'Citigroup', Decimal('5.176682')),
#  ('Northeast', 'Citigroup', Decimal('5.141168')),
#  ('Northeast', 'Phillips 66', Decimal('5.113338')),
#  ('Northeast', 'Phillips 66', Decimal('5.667840')),
#  ('Northeast', 'Phillips 66', Decimal('5.442996')),
#  ('Northeast', 'Phillips 66', Decimal('6.021696')),
#  ('Northeast', 'Phillips 66', Decimal('5.196336')),
#  ('Northeast', 'Phillips 66', Decimal('5.390404')),
#  ('Northeast', 'Phillips 66', Decimal('5.387994')),
#  ('Northeast', 'Phillips 66', Decimal('5.336849')),
#  ('Northeast', 'Phillips 66', Decimal('5.500340')),
#  ('Northeast', 'Phillips 66', Decimal('5.494946')),
#  ('Northeast', 'Phillips 66', Decimal('5.688705')),
#  ('Northeast', 'Phillips 66', Decimal('5.139737')),
#  ('Northeast', 'Phillips 66', Decimal('5.272991')),
#  ('Northeast', 'Phillips 66', Decimal('5.305143')),
#  ('Northeast', 'Phillips 66', Decimal('5.209839')),
#  ('Northeast', 'Phillips 66', Decimal('5.473831')),
#  ('Northeast', 'Phillips 66', Decimal('5.358127')),
#  ('Northeast', 'Phillips 66', Decimal('5.433102')),
#  ('Northeast', 'Phillips 66', Decimal('5.336184')),
#  ('Northeast', 'Phillips 66', Decimal('5.694459')),
#  ('Northeast', 'IBM', Decimal('5.443675')),
#  ('Northeast', 'IBM', Decimal('5.721231')),
#  ('Northeast', 'IBM', Decimal('5.918550')),
#  ('Northeast', 'IBM', Decimal('5.985797')),
#  ('Northeast', 'IBM', Decimal('5.604995')),
#  ('Northeast', 'IBM', Decimal('6.045142')),
#  ('Northeast', 'IBM', Decimal('5.722612')),
#  ('Northeast', 'IBM', Decimal('5.865265')),
#  ('Northeast', 'IBM', Decimal('8.089906')),
#  ('Northeast', 'IBM', Decimal('5.602542')),
#  ('Northeast', 'IBM', Decimal('5.862565')),
#  ('Northeast', 'IBM', Decimal('5.789945')),
#  ('Northeast', 'IBM', Decimal('5.337354')),
#  ('Northeast', 'IBM', Decimal('5.999124')),
#  ('Northeast', 'IBM', Decimal('5.846765')),
#  ('Northeast', 'IBM', Decimal('5.981415')),
#  ('Northeast', 'IBM', Decimal('5.726050')),
#  ('Northeast', 'IBM', Decimal('6.577740')),
#  ('Northeast', 'Valero Energy', Decimal('5.051408')),
#  ('Northeast', 'Valero Energy', Decimal('5.465838')),
#  ('Northeast', 'Valero Energy', Decimal('5.291941')),
#  ('Northeast', 'Valero Energy', Decimal('5.724540')),
#  ('Northeast', 'Valero Energy', Decimal('5.532925')),
#  ('Northeast', 'Valero Energy', Decimal('5.467744')),
#  ('Northeast', 'Anthem', Decimal('5.082314')),
#  ('Northeast', 'Anthem', Decimal('5.065655')),
#  ('Northeast', 'Anthem', Decimal('5.134706')),
#  ('Northeast', 'Anthem', Decimal('5.025881')),
#  ('Northeast', 'Anthem', Decimal('5.181417')),
#  ('Northeast', 'Anthem', Decimal('5.154085')),
#  ('Northeast', 'Anthem', Decimal('5.033632')),
#  ('Northeast', 'Anthem', Decimal('5.074793')),
#  ('Northeast', 'Anthem', Decimal('5.128282')),
#  ('Northeast', 'Anthem', Decimal('4.989898')),
#  ('Northeast', 'Anthem', Decimal('5.084186')),
#  ('Northeast', 'Anthem', Decimal('5.135054')),
#  ('Northeast', 'Anthem', Decimal('4.989901')),
#  ('Northeast', 'Anthem', Decimal('5.071665')),
#  ('Northeast', 'Procter & Gamble', Decimal('6.183245')),
#  ('Northeast', 'Procter & Gamble', Decimal('5.336835')),
#  ('Northeast', 'Procter & Gamble', Decimal('6.025827')),
#  ('Northeast', 'State Farm Insurance Cos.', Decimal('5.199532')),
#  ('Northeast', 'State Farm Insurance Cos.', Decimal('5.955916')),
#  ('Northeast', 'State Farm Insurance Cos.', Decimal('5.374616')),
#  ('Northeast', 'State Farm Insurance Cos.', Decimal('5.167826')),
#  ('Northeast', 'Alphabet', Decimal('5.435160')),
#  ('Northeast', 'Alphabet', Decimal('5.548505')),
#  ('Northeast', 'Alphabet', Decimal('5.964847')),
#  ('Northeast', 'Comcast', Decimal('5.218928')),
#  ('Northeast', 'Comcast', Decimal('5.046691')),
#  ('Northeast', 'Comcast', Decimal('4.989896')),
#  ('Northeast', 'Comcast', Decimal('5.445104')),
#  ('Northeast', 'Target', Decimal('5.557886')),
#  ('Northeast', 'Target', Decimal('5.247974')),
#  ('Northeast', 'Target', Decimal('5.180116')),
#  ('Northeast', 'Target', Decimal('5.269511')),
#  ('Northeast', 'Target', Decimal('5.420516')),
#  ('Northeast', 'Target', Decimal('5.562266')),
#  ('Northeast', 'Target', Decimal('5.243067')),
#  ('Northeast', 'Target', Decimal('5.758809')),
#  ('Northeast', 'Target', Decimal('5.106109')),
#  ('Northeast', 'Target', Decimal('5.782979')),
#  ('Northeast', 'Target', Decimal('5.632564')),
#  ('Northeast', 'Target', Decimal('5.073781')),
#  ('Northeast', 'Target', Decimal('6.414162')),
#  ('Northeast', 'Target', Decimal('5.514551')),
#  ('Northeast', 'Target', Decimal('5.257023')),
#  ('Northeast', 'Target', Decimal('5.382257')),
#  ('Northeast', 'Target', Decimal('5.406046')),
#  ('Northeast', 'Target', Decimal('5.221599')),
#  ('Northeast', 'Johnson & Johnson', Decimal('5.329676')),
#  ('Northeast', 'Johnson & Johnson', Decimal('5.253516')),
#  ('Northeast', 'MetLife', Decimal('4.989903')),
#  ('Northeast', 'MetLife', Decimal('5.030833')),
#  ('Northeast', 'MetLife', Decimal('5.049899')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.495697')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.214806')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.529445')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.309961')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.469324')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.525821')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.325870')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.425245')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.638831')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('6.068937')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.402052')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.437167')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('6.828641')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.578050')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('6.030992')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.494095')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.462353')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.228347')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.203466')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.499905')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.191852')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.472026')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.739561')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.682705')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.126054')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('6.273823')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.263396')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.186740')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.719979')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.357069')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.295367')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.395879')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.567313')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.436645')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.273900')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.409341')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.631321')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.249749')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.180071')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.171553')),
#  ('Northeast', 'Marathon Petroleum', Decimal('4.996051')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.355139')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.438938')),
#  ('Northeast', 'Marathon Petroleum', Decimal('4.989895')),
#  ('Northeast', 'Marathon Petroleum', Decimal('4.999235')),
#  ('Northeast', 'Marathon Petroleum', Decimal('4.994181')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.192774')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.132065')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.058602')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.173826')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.217645')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.367775')),
#  ('Northeast', 'Marathon Petroleum', Decimal('6.231923')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.061311')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.221022')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.087671')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.156795')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.923959')),
#  ('Northeast', 'Marathon Petroleum', Decimal('4.996185')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.048956')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.678458')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.046921')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.467072')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.235179')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.756604')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.869531')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.004030')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.130617')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.247661')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.002176')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.126199')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.110984')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.707946')),
#  ('Northeast', 'Marathon Petroleum', Decimal('4.996430')),
#  ('Northeast', 'Freddie Mac', Decimal('5.511086')),
#  ('Northeast', 'Freddie Mac', Decimal('6.017059')),
#  ('Northeast', 'Freddie Mac', Decimal('5.145852')),
#  ('Northeast', 'Freddie Mac', Decimal('5.352564')),
#  ('Northeast', 'Freddie Mac', Decimal('5.439168')),
#  ('Northeast', 'Freddie Mac', Decimal('5.498465')),
#  ('Northeast', 'Freddie Mac', Decimal('5.686412')),
#  ('Northeast', 'Freddie Mac', Decimal('5.234423')),
#  ('Northeast', 'Freddie Mac', Decimal('4.989820')),
#  ('Northeast', 'Freddie Mac', Decimal('5.581027')),
#  ('Northeast', 'Freddie Mac', Decimal('5.306722')),
#  ('Northeast', 'Freddie Mac', Decimal('5.594876')),
#  ('Northeast', 'Freddie Mac', Decimal('5.542914')),
#  ('Northeast', 'Freddie Mac', Decimal('5.385032')),
#  ('Northeast', 'Freddie Mac', Decimal('5.353880')),
#  ('Northeast', 'Freddie Mac', Decimal('5.298962')),
#  ('Northeast', 'Freddie Mac', Decimal('5.556686')),
#  ('Northeast', 'Freddie Mac', Decimal('5.346141')),
#  ('Northeast', 'Freddie Mac', Decimal('5.367853')),
#  ('Northeast', 'Freddie Mac', Decimal('5.420539')),
#  ('Northeast', 'Freddie Mac', Decimal('5.686652')),
#  ('Northeast', 'Freddie Mac', Decimal('4.989830')),
#  ('Northeast', 'Freddie Mac', Decimal('5.215529')),
#  ('Northeast', 'Freddie Mac', Decimal('5.515093')),
#  ('Northeast', 'Freddie Mac', Decimal('5.696883')),
#  ('Northeast', 'Freddie Mac', Decimal('5.258932')),
#  ('Northeast', 'Freddie Mac', Decimal('5.437167')),
#  ('Northeast', 'Freddie Mac', Decimal('5.415953')),
#  ('Northeast', 'Freddie Mac', Decimal('5.283923')),
#  ('Northeast', 'Freddie Mac', Decimal('5.578601')),
#  ('Northeast', 'Freddie Mac', Decimal('5.593895')),
#  ('Northeast', 'Freddie Mac', Decimal('5.336500')),
#  ('Northeast', 'Freddie Mac', Decimal('5.006445')),
#  ('Northeast', 'Freddie Mac', Decimal('5.430275')),
#  ('Northeast', 'Freddie Mac', Decimal('5.342878')),
#  ('Northeast', 'Freddie Mac', Decimal('5.162062')),
#  ('Northeast', 'PepsiCo', Decimal('5.835828')),
#  ('Northeast', 'PepsiCo', Decimal('5.947441')),
#  ('Northeast', 'PepsiCo', Decimal('5.332963')),
#  ('Northeast', 'United Technologies', Decimal('5.247379')),
#  ('Northeast', 'United Technologies', Decimal('5.515317')),
#  ('Northeast', 'United Technologies', Decimal('5.400681')),
#  ('Northeast', 'United Technologies', Decimal('5.166606')),
#  ('Northeast', 'United Technologies', Decimal('5.652020')),
#  ('Northeast', 'United Technologies', Decimal('5.183711')),
#  ('Northeast', 'United Technologies', Decimal('5.445665')),
#  ('Northeast', 'United Technologies', Decimal('5.382342')),
#  ('Northeast', 'United Technologies', Decimal('5.213728')),
#  ('Northeast', 'United Technologies', Decimal('5.415217')),
#  ('Northeast', 'United Technologies', Decimal('5.360076')),
#  ('Northeast', 'United Technologies', Decimal('5.030618')),
#  ('Northeast', 'United Technologies', Decimal('5.357319')),
#  ('Northeast', 'United Technologies', Decimal('5.572584')),
#  ('Northeast', 'United Technologies', Decimal('5.267628')),
#  ('Northeast', 'United Technologies', Decimal('5.196535')),
#  ('Northeast', 'United Technologies', Decimal('5.328471')),
#  ('Northeast', 'United Technologies', Decimal('5.593232')),
#  ('Northeast', 'United Technologies', Decimal('6.386602')),
#  ('Northeast', 'United Technologies', Decimal('5.241614')),
#  ('Northeast', 'United Technologies', Decimal('5.223856')),
#  ('Northeast', 'United Technologies', Decimal('5.116383')),
#  ('Northeast', 'United Technologies', Decimal('5.260436')),
#  ('Northeast', 'United Technologies', Decimal('5.516430')),
#  ('Northeast', 'United Technologies', Decimal('5.580512')),
#  ('Northeast', 'United Technologies', Decimal('5.656249')),
#  ('Northeast', 'United Technologies', Decimal('5.550095')),
#  ('Northeast', 'United Technologies', Decimal('5.224094')),
#  ('Northeast', 'United Technologies', Decimal('5.265498')),
#  ('Northeast', 'United Technologies', Decimal('5.367297')),
#  ('Northeast', 'United Technologies', Decimal('5.776712')),
#  ('Northeast', 'United Technologies', Decimal('5.612459')),
#  ('Northeast', 'United Technologies', Decimal('5.354883')),
#  ('Northeast', 'United Technologies', Decimal('5.546795')),
#  ('Northeast', 'United Technologies', Decimal('5.532492')),
#  ('Northeast', 'Aetna', Decimal('5.151715')),
#  ('Northeast', 'Aetna', Decimal('5.316252')),
#  ('Northeast', 'Aetna', Decimal('6.323260')),
#  ('Northeast', 'Aetna', Decimal('5.488385')),
#  ('Northeast', 'Aetna', Decimal('5.373189')),
#  ('Northeast', 'Aetna', Decimal('5.372859')),
#  ('Northeast', 'Aetna', Decimal('5.311991')),
#  ('Northeast', 'Aetna', Decimal('5.299931')),
#  ('Northeast', 'Aetna', Decimal('4.989879')),
#  ('Northeast', 'Aetna', Decimal('5.302670')),
#  ('Northeast', 'Aetna', Decimal('5.301633')),
#  ('Northeast', 'Aetna', Decimal('5.219522')),
#  ('Northeast', 'Aetna', Decimal('5.448252')),
#  ('Northeast', 'Aetna', Decimal('5.516690')),
#  ('Northeast', 'Aetna', Decimal('5.743465')),
#  ('Northeast', 'Aetna', Decimal('6.670767')),
#  ('Northeast', 'Aetna', Decimal('4.989835')),
#  ('Northeast', 'Aetna', Decimal('5.250260')),
#  ('Northeast', 'Aetna', Decimal('5.305034')),
#  ('Northeast', 'Aetna', Decimal('5.492848')),
#  ('Northeast', 'Aetna', Decimal('5.239579')),
#  ('Northeast', 'Aetna', Decimal('5.486671')),
#  ('Northeast', 'Aetna', Decimal('5.375902')),
#  ('Northeast', 'Aetna', Decimal('5.319481')),
#  ('Northeast', 'Aetna', Decimal('5.278860')),
#  ('Northeast', 'Aetna', Decimal('5.402430')),
#  ('Northeast', 'Aetna', Decimal('5.589544')),
#  ('Northeast', 'Aetna', Decimal('6.118063')),
#  ('Northeast', 'Aetna', Decimal('5.263513')),
#  ('Northeast', 'Aetna', Decimal('5.092041')),
#  ('Northeast', 'Aetna', Decimal('5.184177')),
#  ('Northeast', 'Aetna', Decimal('5.297636')),
#  ('Northeast', 'Aetna', Decimal('5.322038')),
#  ('Northeast', "Lowe's", Decimal('5.051154')),
#  ('Northeast', "Lowe's", Decimal('5.004466')),
#  ('Northeast', "Lowe's", Decimal('5.057863')),
#  ('Northeast', "Lowe's", Decimal('6.151962')),
#  ('Northeast', "Lowe's", Decimal('5.109341')),
#  ('Northeast', "Lowe's", Decimal('5.132405')),
#  ('Northeast', "Lowe's", Decimal('5.030714')),
#  ('Northeast', "Lowe's", Decimal('5.100393')),
#  ('Northeast', "Lowe's", Decimal('4.989900')),
#  ('Northeast', "Lowe's", Decimal('5.039999')),
#  ('Northeast', "Lowe's", Decimal('5.078244')),
#  ('Northeast', "Lowe's", Decimal('5.976025')),
#  ('Northeast', "Lowe's", Decimal('5.410306')),
#  ('Northeast', "Lowe's", Decimal('5.220109')),
#  ('Northeast', 'AIG', Decimal('5.858710')),
#  ('Northeast', 'Prudential Financial', Decimal('5.267611')),
#  ('Northeast', 'Prudential Financial', Decimal('6.788217')),
#  ('Northeast', 'Prudential Financial', Decimal('6.625683')),
#  ('Northeast', 'Prudential Financial', Decimal('5.258973')),
#  ('Northeast', 'Prudential Financial', Decimal('5.590333')),
#  ('Northeast', 'Prudential Financial', Decimal('5.569645')),
#  ('Northeast', 'Prudential Financial', Decimal('5.292322')),
#  ('Northeast', 'Prudential Financial', Decimal('5.345360')),
#  ('Northeast', 'Prudential Financial', Decimal('5.676905')),
#  ('Northeast', 'Prudential Financial', Decimal('5.239037')),
#  ('Northeast', 'Prudential Financial', Decimal('6.003745')),
#  ('Northeast', 'Prudential Financial', Decimal('5.376868')),
#  ('Northeast', 'Prudential Financial', Decimal('5.277304')),
#  ('Northeast', 'Prudential Financial', Decimal('5.490795')),
#  ('Northeast', 'Prudential Financial', Decimal('5.339372')),
#  ('Northeast', 'Prudential Financial', Decimal('5.277023')),
#  ('Northeast', 'Prudential Financial', Decimal('5.316261')),
#  ('Northeast', 'Prudential Financial', Decimal('5.263768')),
#  ('Northeast', 'Prudential Financial', Decimal('5.343113')),
#  ('Northeast', 'Prudential Financial', Decimal('5.392123')),
#  ('Northeast', 'Prudential Financial', Decimal('4.989832')),
#  ('Northeast', 'Prudential Financial', Decimal('5.711558')),
#  ('Northeast', 'Prudential Financial', Decimal('5.613256')),
#  ('Northeast', 'Prudential Financial', Decimal('5.229364')),
#  ('Northeast', 'Intel', Decimal('5.494544')),
#  ('Northeast', 'Intel', Decimal('5.356666')),
#  ('Northeast', 'Intel', Decimal('5.477168')),
#  ('Northeast', 'Intel', Decimal('5.298916')),
#  ('Northeast', 'Intel', Decimal('5.339462')),
#  ('Northeast', 'Intel', Decimal('5.634015')),
#  ('Northeast', 'Intel', Decimal('5.290442')),
#  ('Northeast', 'Intel', Decimal('5.788183')),
#  ('Northeast', 'Intel', Decimal('5.491346')),
#  ('Northeast', 'Intel', Decimal('5.419707')),
#  ('Northeast', 'Intel', Decimal('5.266342')),
#  ('Northeast', 'Intel', Decimal('5.086934')),
#  ('Northeast', 'Intel', Decimal('4.989832')),
#  ('Northeast', 'Intel', Decimal('5.327722')),
#  ('Northeast', 'Intel', Decimal('5.635751')),
#  ('Northeast', 'Intel', Decimal('5.394471')),
#  ('Northeast', 'Intel', Decimal('5.165166')),
#  ('Northeast', 'Intel', Decimal('5.279473')),
#  ('Northeast', 'Intel', Decimal('5.335587')),
#  ('Northeast', 'Intel', Decimal('5.464886')),
#  ('Northeast', 'Intel', Decimal('5.412565')),
#  ('Northeast', 'Intel', Decimal('5.521306')),
#  ('Northeast', 'Humana', Decimal('5.170993')),
#  ('Northeast', 'Humana', Decimal('5.043663')),
#  ('Northeast', 'Humana', Decimal('5.100155')),
#  ('Northeast', 'Humana', Decimal('4.989886')),
#  ('Northeast', 'Humana', Decimal('5.189817')),
#  ('Northeast', 'Humana', Decimal('4.989898')),
#  ('Northeast', 'Humana', Decimal('5.071281')),
#  ('Northeast', 'Humana', Decimal('5.156556')),
#  ('Northeast', 'Humana', Decimal('5.151199')),
#  ('Northeast', 'Humana', Decimal('5.166587')),
#  ('Northeast', 'Disney', Decimal('5.268518')),
#  ('Northeast', 'Disney', Decimal('4.996377')),
#  ('Northeast', 'Disney', Decimal('5.039095')),
#  ('Northeast', 'Disney', Decimal('5.063118')),
#  ('Northeast', 'Disney', Decimal('5.418362')),
#  ('Northeast', 'Disney', Decimal('5.183346')),
#  ('Northeast', 'Disney', Decimal('5.229607')),
#  ('Northeast', 'Disney', Decimal('4.994321')),
#  ('Northeast', 'Disney', Decimal('4.989900')),
#  ('Northeast', 'Disney', Decimal('5.069070')),
#  ('Northeast', 'Disney', Decimal('5.030777')),
#  ('Northeast', 'Disney', Decimal('5.403969')),
#  ('Northeast', 'Disney', Decimal('5.049636')),
#  ('Northeast', 'Disney', Decimal('5.028913')),
#  ('Northeast', 'Disney', Decimal('5.166873')),
#  ('Northeast', 'Disney', Decimal('5.339421')),
#  ('Northeast', 'Disney', Decimal('5.246211')),
#  ('Northeast', 'Disney', Decimal('5.109940')),
#  ('Northeast', 'Disney', Decimal('6.119999')),
#  ('Northeast', 'Disney', Decimal('5.000143')),
#  ('Northeast', 'Disney', Decimal('5.087755')),
#  ('Northeast', 'Disney', Decimal('5.134363')),
#  ('Northeast', 'Disney', Decimal('5.302594')),
#  ('Northeast', 'Disney', Decimal('5.985675')),
#  ('Northeast', 'Disney', Decimal('4.989899')),
#  ('Northeast', 'Disney', Decimal('5.383710')),
#  ('Northeast', 'Disney', Decimal('4.989901')),
#  ('Northeast', 'Disney', Decimal('7.381408')),
#  ('Northeast', 'Disney', Decimal('5.134363')),
#  ('Northeast', 'Disney', Decimal('5.204407')),
#  ('Northeast', 'Disney', Decimal('5.297319')),
#  ('Northeast', 'Disney', Decimal('5.069553')),
#  ('Northeast', 'Disney', Decimal('5.196970')),
#  ('Northeast', 'Disney', Decimal('5.042889')),
#  ('Northeast', 'Disney', Decimal('5.770516')),
#  ('Northeast', 'Cisco Systems', Decimal('4.989900')),
#  ('Northeast', 'Cisco Systems', Decimal('5.173284')),
#  ('Northeast', 'Cisco Systems', Decimal('5.114898')),
#  ('Northeast', 'Cisco Systems', Decimal('5.013307')),
#  ('Northeast', 'Cisco Systems', Decimal('5.033592')),
#  ('Northeast', 'Cisco Systems', Decimal('5.132716')),
#  ('Northeast', 'Cisco Systems', Decimal('5.025181')),
#  ('Northeast', 'Cisco Systems', Decimal('5.046465')),
#  ('Northeast', 'Cisco Systems', Decimal('5.060526')),
#  ('Northeast', 'Cisco Systems', Decimal('5.324422')),
#  ('Northeast', 'Cisco Systems', Decimal('5.154135')),
#  ('Northeast', 'Cisco Systems', Decimal('5.140963')),
#  ('Northeast', 'Cisco Systems', Decimal('5.077627')),
#  ('Northeast', 'Cisco Systems', Decimal('5.092229')),
#  ('Northeast', 'Cisco Systems', Decimal('5.507698')),
#  ('Northeast', 'Cisco Systems', Decimal('5.028183')),
#  ('Northeast', 'Cisco Systems', Decimal('5.085169')),
#  ('Northeast', 'Cisco Systems', Decimal('5.144823')),
#  ('Northeast', 'Cisco Systems', Decimal('5.117702')),
#  ('Northeast', 'Cisco Systems', Decimal('5.030221')),
#  ('Northeast', 'Cisco Systems', Decimal('5.162315')),
#  ('Northeast', 'Cisco Systems', Decimal('5.144495')),
#  ('Northeast', 'Cisco Systems', Decimal('5.318950')),
#  ('Northeast', 'Cisco Systems', Decimal('5.164320')),
#  ('Northeast', 'Cisco Systems', Decimal('5.170257')),
#  ('Northeast', 'Cisco Systems', Decimal('5.366839')),
#  ('Northeast', 'Cisco Systems', Decimal('4.989902')),
#  ('Northeast', 'Cisco Systems', Decimal('5.051758')),
#  ('Northeast', 'Cisco Systems', Decimal('5.203354')),
#  ('Northeast', 'Cisco Systems', Decimal('4.999375')),
#  ('Northeast', 'Cisco Systems', Decimal('5.072279')),
#  ('Northeast', 'Cisco Systems', Decimal('5.113032')),
#  ('Northeast', 'Cisco Systems', Decimal('5.078040')),
#  ('Northeast', 'Cisco Systems', Decimal('5.155034')),
#  ('Northeast', 'Cisco Systems', Decimal('5.050758')),
#  ('Northeast', 'Cisco Systems', Decimal('5.061119')),
#  ('Northeast', 'Cisco Systems', Decimal('5.127267')),
#  ('Northeast', 'Cisco Systems', Decimal('5.163435')),
#  ('Northeast', 'Pfizer', Decimal('5.605751')),
#  ('Northeast', 'Pfizer', Decimal('6.037965')),
#  ('Northeast', 'Pfizer', Decimal('5.917287')),
#  ('Northeast', 'Pfizer', Decimal('5.655206')),
#  ('Northeast', 'Dow Chemical', Decimal('5.224962')),
#  ('Northeast', 'Sysco', Decimal('5.547146')),
#  ('Northeast', 'Sysco', Decimal('5.094863')),
#  ('Northeast', 'Sysco', Decimal('5.473661')),
#  ('Northeast', 'Sysco', Decimal('5.325141')),
#  ('Northeast', 'Sysco', Decimal('5.424358')),
#  ('Northeast', 'Sysco', Decimal('5.245417')),
#  ('Northeast', 'Sysco', Decimal('5.333116')),
#  ('Northeast', 'Sysco', Decimal('5.906188')),
#  ('Northeast', 'Sysco', Decimal('5.155110')),
#  ('Northeast', 'Sysco', Decimal('5.360131')),
#  ('Northeast', 'Sysco', Decimal('5.334898')),
#  ('Northeast', 'Sysco', Decimal('5.423147')),
#  ('Northeast', 'Sysco', Decimal('5.431755')),
#  ('Northeast', 'Sysco', Decimal('5.127821')),
#  ('Northeast', 'Sysco', Decimal('5.583084')),
#  ('Northeast', 'Sysco', Decimal('5.621962')),
#  ('Northeast', 'Sysco', Decimal('5.399897')),
#  ('Northeast', 'Sysco', Decimal('5.240329')),
#  ('Northeast', 'Sysco', Decimal('5.670820')),
#  ('Northeast', 'Sysco', Decimal('5.941700')),
#  ('Northeast', 'Sysco', Decimal('5.184637')),
#  ('Northeast', 'Sysco', Decimal('5.433640')),
#  ('Northeast', 'Sysco', Decimal('5.460205')),
#  ('Northeast', 'Sysco', Decimal('5.402774')),
#  ('Northeast', 'Sysco', Decimal('5.443744')),
#  ('Northeast', 'Sysco', Decimal('5.147636')),
#  ('Northeast', 'Sysco', Decimal('5.060818')),
#  ('Northeast', 'Sysco', Decimal('5.641460')),
#  ('Northeast', 'Sysco', Decimal('5.544690')),
#  ('Northeast', 'Sysco', Decimal('5.406192')),
#  ('Northeast', 'Sysco', Decimal('5.536149')),
#  ('Northeast', 'Sysco', Decimal('5.458567')),
#  ('Northeast', 'Sysco', Decimal('5.407218')),
#  ('Northeast', 'Sysco', Decimal('5.533211')),
#  ('Northeast', 'Sysco', Decimal('5.251819')),
#  ('Northeast', 'Sysco', Decimal('5.401694')),
#  ('Northeast', 'Sysco', Decimal('5.824165')),
#  ('Northeast', 'FedEx', Decimal('5.258073')),
#  ('Northeast', 'FedEx', Decimal('5.088325')),
#  ('Northeast', 'FedEx', Decimal('5.048381')),
#  ('Northeast', 'FedEx', Decimal('5.359978')),
#  ('Northeast', 'FedEx', Decimal('5.121998')),
#  ('Northeast', 'FedEx', Decimal('5.340473')),
#  ('Northeast', 'FedEx', Decimal('5.179872')),
#  ('Northeast', 'FedEx', Decimal('5.093482')),
#  ('Northeast', 'FedEx', Decimal('5.153007')),
#  ('Northeast', 'FedEx', Decimal('5.001673')),
#  ('Northeast', 'FedEx', Decimal('5.088036')),
#  ('Northeast', 'FedEx', Decimal('5.136299')),
#  ('Northeast', 'FedEx', Decimal('5.109126')),
#  ('Northeast', 'FedEx', Decimal('5.054686')),
#  ('Northeast', 'FedEx', Decimal('4.989913')),
#  ('Northeast', 'FedEx', Decimal('5.193381')),
#  ('Northeast', 'FedEx', Decimal('5.569465')),
#  ('Northeast', 'FedEx', Decimal('4.989900')),
#  ('Northeast', 'FedEx', Decimal('5.358938')),
#  ('Northeast', 'FedEx', Decimal('5.138858')),
#  ('Northeast', 'FedEx', Decimal('5.045462')),
#  ('Northeast', 'FedEx', Decimal('5.913517')),
#  ('Northeast', 'FedEx', Decimal('5.326170')),
#  ('Northeast', 'FedEx', Decimal('5.080365')),
#  ('Northeast', 'FedEx', Decimal('5.050794')),
#  ('Northeast', 'FedEx', Decimal('5.122835')),
#  ('Northeast', 'FedEx', Decimal('5.068134')),
#  ('Northeast', 'FedEx', Decimal('5.765981')),
#  ('Northeast', 'FedEx', Decimal('5.189792')),
#  ('Northeast', 'FedEx', Decimal('4.989899')),
#  ('Northeast', 'FedEx', Decimal('5.092998')),
#  ('Northeast', 'FedEx', Decimal('5.076844')),
#  ('Northeast', 'FedEx', Decimal('5.194602')),
#  ('Northeast', 'FedEx', Decimal('5.210397')),
#  ('Northeast', 'FedEx', Decimal('5.160896')),
#  ('Northeast', 'FedEx', Decimal('5.461192')),
#  ('Northeast', 'FedEx', Decimal('5.159660')),
#  ('Northeast', 'Caterpillar', Decimal('6.280836')),
#  ('Northeast', 'Caterpillar', Decimal('5.277705')),
#  ('Northeast', 'Caterpillar', Decimal('7.321467')),
#  ('Northeast', 'Caterpillar', Decimal('5.751071')),
#  ('Northeast', 'Caterpillar', Decimal('6.740127')),
#  ('Northeast', 'Caterpillar', Decimal('5.270753')),
#  ('Northeast', 'Lockheed Martin', Decimal('5.115847')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.588439')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.149959')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.160324')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.121314')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.160255')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.509803')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.059839')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.061742')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.031649')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.867323')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.112088')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.061032')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.112815')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.115742')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.140375')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.176265')),
#  ('Northeast', 'New York Life Insurance', Decimal('6.393690')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.057863')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.226162')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.132488')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.011954')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.188881')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.200284')),
#  ('Northeast', 'New York Life Insurance', Decimal('4.989898')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.342442')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.057969')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.085361')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.164008')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.064655')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.193528')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.563952')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.102542')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.247322')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.086995')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.002173')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.087713')),
#  ('Northeast', 'Coca-Cola', Decimal('5.137247')),
#  ('Northeast', 'Coca-Cola', Decimal('4.999880')),
#  ('Northeast', 'Coca-Cola', Decimal('5.078067')),
#  ('Northeast', 'Coca-Cola', Decimal('5.101305')),
#  ('Northeast', 'Coca-Cola', Decimal('5.059351')),
#  ('Northeast', 'Coca-Cola', Decimal('5.168327')),
#  ('Northeast', 'Coca-Cola', Decimal('4.989884')),
#  ('Northeast', 'Coca-Cola', Decimal('5.183854')),
#  ('Northeast', 'Coca-Cola', Decimal('5.054003')),
#  ('Northeast', 'Coca-Cola', Decimal('5.072024')),
#  ('Northeast', 'Coca-Cola', Decimal('5.204940')),
#  ('Northeast', 'Coca-Cola', Decimal('5.423158')),
#  ('Northeast', 'Coca-Cola', Decimal('5.123498')),
#  ('Northeast', 'Coca-Cola', Decimal('5.123608')),
#  ('Northeast', 'Ingram Micro', Decimal('5.859667')),
#  ('Northeast', 'Ingram Micro', Decimal('6.111298')),
#  ('Northeast', 'Ingram Micro', Decimal('4.989546')),
#  ('Northeast', 'Energy Transfer Equity', Decimal('5.299065')),
#  ('Northeast', 'Energy Transfer Equity', Decimal('5.134330')),
#  ('Northeast', 'Energy Transfer Equity', Decimal('5.285294')),
#  ('Northeast', 'Energy Transfer Equity', Decimal('5.369516')),
#  ('Northeast', 'Tyson Foods', Decimal('5.176014')),
#  ('Northeast', 'Tyson Foods', Decimal('5.545024')),
#  ('Northeast', 'Tyson Foods', Decimal('5.259525')),
#  ('Northeast', 'Tyson Foods', Decimal('5.173734')),
#  ('Northeast', 'Tyson Foods', Decimal('5.175806')),
#  ('Northeast', 'Tyson Foods', Decimal('4.989670')),
#  ('Northeast', 'Tyson Foods', Decimal('5.128572')),
#  ('Northeast', 'Tyson Foods', Decimal('5.663775')),
#  ('Northeast', 'Tyson Foods', Decimal('5.487223')),
#  ('Northeast', 'Tyson Foods', Decimal('5.385176')),
#  ('Northeast', 'Tyson Foods', Decimal('5.694803')),
#  ('Northeast', 'Tyson Foods', Decimal('6.430019')),
#  ('Northeast', 'Tyson Foods', Decimal('4.989619')),
#  ('Northeast', 'Tyson Foods', Decimal('5.117550')),
#  ('Northeast', 'Tyson Foods', Decimal('5.187469')),
#  ('Northeast', 'Tyson Foods', Decimal('5.461232')),
#  ('Northeast', 'Tyson Foods', Decimal('5.070318')),
#  ('Northeast', 'Tyson Foods', Decimal('5.201571')),
#  ('Northeast', 'Tyson Foods', Decimal('5.196675')),
#  ('Northeast', 'Tyson Foods', Decimal('5.220978')),
#  ('Northeast', 'Tyson Foods', Decimal('5.342627')),
#  ('Northeast', 'Tyson Foods', Decimal('5.041025')),
#  ('Northeast', 'Tyson Foods', Decimal('6.425416')),
#  ('Northeast', 'Tyson Foods', Decimal('5.240086')),
#  ('Northeast', 'Tyson Foods', Decimal('5.406640')),
#  ('Northeast', 'Tyson Foods', Decimal('5.028096')),
#  ('Northeast', 'American Airlines Group', Decimal('5.486626')),
#  ('Northeast', 'American Airlines Group', Decimal('6.880289')),
#  ('Northeast', 'American Airlines Group', Decimal('5.069219')),
#  ('Northeast', 'American Airlines Group', Decimal('5.063692')),
#  ('Northeast', 'American Airlines Group', Decimal('5.073385')),
#  ('Northeast', 'American Airlines Group', Decimal('5.049877')),
#  ('Northeast', 'American Airlines Group', Decimal('5.084334')),
#  ('Northeast', 'American Airlines Group', Decimal('5.051154')),
#  ('Northeast', 'Delta Air Lines', Decimal('5.241388')),
#  ('Northeast', 'Nationwide', Decimal('5.337241')),
#  ('Northeast', 'Nationwide', Decimal('5.366989')),
#  ('Northeast', 'Nationwide', Decimal('6.426081')),
#  ('Northeast', 'Nationwide', Decimal('5.535369')),
#  ('Northeast', 'Nationwide', Decimal('5.244992')),
#  ('Northeast', 'Nationwide', Decimal('5.565393')),
#  ('Northeast', 'Nationwide', Decimal('5.272630')),
#  ('Northeast', 'Nationwide', Decimal('5.307684')),
#  ('Northeast', 'Nationwide', Decimal('5.161386')),
#  ('Northeast', 'Johnson Controls', Decimal('5.107637')),
#  ('Northeast', 'Johnson Controls', Decimal('5.206168')),
#  ('Northeast', 'Johnson Controls', Decimal('5.191002')),
#  ('Northeast', 'Johnson Controls', Decimal('5.124432')),
#  ('Northeast', 'Johnson Controls', Decimal('4.989901')),
#  ('Northeast', 'Johnson Controls', Decimal('5.038359')),
#  ('Northeast', 'Johnson Controls', Decimal('4.989895')),
#  ('Northeast', 'Johnson Controls', Decimal('5.222950')),
#  ('Northeast', 'Johnson Controls', Decimal('5.039017')),
#  ('Northeast', 'Johnson Controls', Decimal('5.098419')),
#  ('Northeast', 'Johnson Controls', Decimal('4.989899')),
#  ('Northeast', 'Johnson Controls', Decimal('5.073689')),
#  ('Northeast', 'Best Buy', Decimal('6.501609')),
#  ('Northeast', 'Best Buy', Decimal('4.989656')),
#  ('Northeast', 'Best Buy', Decimal('5.509182')),
#  ('Northeast', 'Best Buy', Decimal('5.614972')),
#  ('Northeast', 'Best Buy', Decimal('5.121242')),
#  ('Northeast', 'Best Buy', Decimal('4.989661')),
#  ('Northeast', 'Best Buy', Decimal('5.068963')),
#  ('Northeast', 'Best Buy', Decimal('5.097249')),
#  ('Northeast', 'Best Buy', Decimal('5.440331')),
#  ('Northeast', 'Best Buy', Decimal('5.336512')),
#  ('Northeast', 'Best Buy', Decimal('5.363548')),
#  ('Northeast', 'Best Buy', Decimal('5.650926')),
#  ('Northeast', 'Best Buy', Decimal('5.312042')),
#  ('Northeast', 'Best Buy', Decimal('5.806723')),
#  ('Northeast', 'Best Buy', Decimal('5.361520')),
#  ('Northeast', 'Best Buy', Decimal('5.008895')),
#  ('Northeast', 'Best Buy', Decimal('5.783623')),
#  ('Northeast', 'Best Buy', Decimal('5.103305')),
#  ('Northeast', 'Best Buy', Decimal('5.383021')),
#  ('Northeast', 'Best Buy', Decimal('5.782823')),
#  ('Northeast', 'Best Buy', Decimal('5.587298')),
#  ('Northeast', 'Best Buy', Decimal('5.092885')),
#  ('Northeast', 'Best Buy', Decimal('5.215142')),
#  ('Northeast', 'Best Buy', Decimal('5.133902')),
#  ('Northeast', 'Best Buy', Decimal('6.044945')),
#  ('Northeast', 'Best Buy', Decimal('5.346244')),
#  ('Northeast', 'Best Buy', Decimal('5.165740')),
#  ('Northeast', 'Best Buy', Decimal('5.652096')),
#  ('Northeast', 'Best Buy', Decimal('5.541430')),
#  ('Northeast', 'Best Buy', Decimal('6.271647')),
#  ('Northeast', 'Merck', Decimal('5.145994')),
#  ('Northeast', 'Merck', Decimal('5.398362')),
#  ('Northeast', 'Merck', Decimal('5.092130')),
#  ('Northeast', 'Merck', Decimal('5.115341')),
#  ('Northeast', 'Merck', Decimal('5.092240')),
#  ('Northeast', 'Merck', Decimal('5.101272')),
#  ('Northeast', 'Merck', Decimal('5.109770')),
#  ('Northeast', 'Merck', Decimal('5.296391')),
#  ('Northeast', 'Merck', Decimal('5.246132')),
#  ('Northeast', 'Merck', Decimal('5.027762')),
#  ('Northeast', 'Merck', Decimal('6.528469')),
#  ('Northeast', 'Merck', Decimal('5.094843')),
#  ('Northeast', 'Merck', Decimal('4.989900')),
#  ('Northeast', 'Merck', Decimal('5.107661')),
#  ('Northeast', 'Merck', Decimal('5.030866')),
#  ('Northeast', 'Merck', Decimal('5.264836')),
#  ('Northeast', 'Merck', Decimal('5.036498')),
#  ('Northeast', 'Merck', Decimal('5.199206')),
#  ('Northeast', 'Merck', Decimal('5.064571')),
#  ('Northeast', 'Liberty Mutual Insurance Group', Decimal('5.527811')),
#  ('Northeast', 'Honeywell International', Decimal('5.103364')),
#  ('Northeast', 'Honeywell International', Decimal('5.103331')),
#  ('Northeast', 'Honeywell International', Decimal('5.206375')),
#  ('Northeast', 'Honeywell International', Decimal('5.096775')),
#  ('Northeast', 'Honeywell International', Decimal('4.989908')),
#  ('Northeast', 'Honeywell International', Decimal('5.008136')),
#  ('Northeast', 'Honeywell International', Decimal('5.102802')),
#  ('Northeast', 'Honeywell International', Decimal('5.153997')),
#  ('Northeast', 'Honeywell International', Decimal('5.103338')),
#  ('Northeast', 'Honeywell International', Decimal('5.062671')),
#  ('Northeast', 'Honeywell International', Decimal('5.133304')),
#  ('Northeast', 'Honeywell International', Decimal('5.480494')),
#  ('Northeast', 'Honeywell International', Decimal('5.160633')),
#  ('Northeast', 'Honeywell International', Decimal('5.765003')),
#  ('Northeast', 'Honeywell International', Decimal('5.799685')),
#  ('Northeast', 'Honeywell International', Decimal('5.050038')),
#  ('Northeast', 'Honeywell International', Decimal('5.188078')),
#  ('Northeast', 'Honeywell International', Decimal('7.235316')),
#  ('Northeast', 'Honeywell International', Decimal('6.213421')),
#  ('Northeast', 'Honeywell International', Decimal('5.749764')),
#  ('Northeast', 'Honeywell International', Decimal('5.064950')),
#  ('Northeast', 'Massachusetts Mutual Life Insurance', Decimal('5.051042')),
#  ('Northeast', 'Massachusetts Mutual Life Insurance', Decimal('5.709958')),
#  ('Northeast', 'Massachusetts Mutual Life Insurance', Decimal('5.009140')),
#  ('Northeast', 'Massachusetts Mutual Life Insurance', Decimal('5.053534')),
#  ('Northeast', 'Massachusetts Mutual Life Insurance', Decimal('4.989625')),
#  ('Northeast', 'Oracle', Decimal('6.107637')),
#  ('Northeast', 'Morgan Stanley', Decimal('6.010933')),
#  ...]

# %% [markdown]
# # Task 5: The Art of Pricing.
# Within the expansive sales data landscape, a captivating narrative emerges. This SQL query intricately connects regions, accounts, and orders, with a specific focus on those with a standard quantity exceeding 100 and poster quantities surpassing 50. The results unveil a vital aspect: the unit price, diligently calculated and thoughtfully ordered in ascending fashion.
#
# This is a tale of pricing precision, shining a spotlight on the value of each unit within these complex transactions. It serves as a guide for businesses, helping them comprehend the intricate interplay between value and pricing complexity in the dynamic world of commerce. In this exploration, the data virtuoso plays a pivotal role, unearthing the insights that can shape prosperous decisions for businesses seeking to navigate the value-laden landscape of their sales.
#
# ============
#
# Unit Price Calculation for Orders with Standard Quantity > 100 and Poster Quantity > 50.
# Write SQL query for the following:
#
# For orders with a standard quantity greater than 100 and a poster quantity greater than 50, what is the unit price of each order in each region, along with the associated account names, sorted in ascending order by unit price?
#
# Unit price is calculated dividing the total amount in USD by the sum of the total quantity and a small constant (0.01) to avoid division by zero errors.

# %%
# %%sql
# select region.name as region, accounts.name as account_name, total_amt_usd/(total + 0.01) as unit_price from orders
# JOIN accounts ON accounts.id = orders.account_id
# JOIN sales_reps ON sales_reps.id = accounts.sales_rep_id
# JOIN region ON region.id = sales_reps.region_id
# WHERE orders.standard_qty > 100 and orders.poster_qty > 50
# ORDER BY unit_price ASC;
# Out:
#  * mysql+pymysql://root:***@localhost/Sales_EDA
# 356 rows affected.
# [('West', 'Stanley Black & Decker', Decimal('5.266396')),
#  ('Northeast', 'Citigroup', Decimal('5.273081')),
#  ('Southeast', 'BlackRock', Decimal('5.278270')),
#  ('Southeast', 'Nucor', Decimal('5.289094')),
#  ('Northeast', 'Merck', Decimal('5.296391')),
#  ('Midwest', 'Sears Holdings', Decimal('5.300912')),
#  ('Southeast', 'BlackRock', Decimal('5.301770')),
#  ('Northeast', 'Fannie Mae', Decimal('5.303465')),
#  ('Midwest', 'Aflac', Decimal('5.305558')),
#  ('Northeast', 'Northwestern Mutual', Decimal('5.307969')),
#  ('Northeast', 'TIAA', Decimal('5.310935')),
#  ('Northeast', 'Cisco Systems', Decimal('5.318950')),
#  ('Northeast', 'FedEx', Decimal('5.326170')),
#  ('West', 'Core-Mark Holding', Decimal('5.328663')),
#  ('Midwest', 'Dollar General', Decimal('5.333630')),
#  ('West', 'Thrivent Financial for Lutherans', Decimal('5.337679')),
#  ('Northeast', 'Philip Morris International', Decimal('5.339153')),
#  ('Northeast', 'Philip Morris International', Decimal('5.340240')),
#  ('Southeast', "Land O'Lakes", Decimal('5.340489')),
#  ('West', 'Core-Mark Holding', Decimal('5.343204')),
#  ('Southeast', 'Supervalu', Decimal('5.347728')),
#  ('Southeast', 'ADP', Decimal('5.348600')),
#  ('West', 'Reynolds American', Decimal('5.348768')),
#  ('Midwest', 'AutoNation', Decimal('5.351093')),
#  ('West', 'eBay', Decimal('5.355893')),
#  ('Southeast', 'Ecolab', Decimal('5.357762')),
#  ('Northeast', 'Citigroup', Decimal('5.358370')),
#  ('Northeast', 'FedEx', Decimal('5.358938')),
#  ('West', 'Charter Communications', Decimal('5.361681')),
#  ('West', 'R.R. Donnelley & Sons', Decimal('5.361952')),
#  ('West', 'Charter Communications', Decimal('5.364147')),
#  ('Northeast', 'Cisco Systems', Decimal('5.366839')),
#  ('Southeast', 'Performance Food Group', Decimal('5.370258')),
#  ('West', 'Unum Group', Decimal('5.371478')),
#  ('Southeast', 'Health Net', Decimal('5.377892')),
#  ('Southeast', 'BlackRock', Decimal('5.382070')),
#  ('Southeast', 'Thermo Fisher Scientific', Decimal('5.387129')),
#  ('Southeast', 'Nucor', Decimal('5.388062')),
#  ('Southeast', 'Kellogg', Decimal('5.388562')),
#  ('Southeast', 'Monsanto', Decimal('5.392332')),
#  ('Northeast', 'Merck', Decimal('5.398362')),
#  ('Southeast', 'ADP', Decimal('5.405471')),
#  ('Southeast', 'ADP', Decimal('5.406828')),
#  ('West', 'Thrivent Financial for Lutherans', Decimal('5.408913')),
#  ('Northeast', "Lowe's", Decimal('5.410306')),
#  ('Midwest', 'AutoNation', Decimal('5.414751')),
#  ('West', 'Core-Mark Holding', Decimal('5.414891')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.415237')),
#  ('Northeast', 'Coca-Cola', Decimal('5.423158')),
#  ('Southeast', 'American Electric Power', Decimal('5.430177')),
#  ('Southeast', 'BlackRock', Decimal('5.435965')),
#  ('Midwest', 'Kraft Heinz', Decimal('5.437828')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.442049')),
#  ('Northeast', 'Comcast', Decimal('5.445104')),
#  ('West', 'PayPal Holdings', Decimal('5.445747')),
#  ('West', 'Global Partners', Decimal('5.453343')),
#  ('Northeast', 'Sysco', Decimal('5.458567')),
#  ('Northeast', 'Citigroup', Decimal('5.460688')),
#  ('West', 'Western Refining', Decimal('5.461673')),
#  ('Southeast', 'FirstEnergy', Decimal('5.462148')),
#  ('Southeast', 'Ecolab', Decimal('5.471191')),
#  ('Midwest', 'Alcoa', Decimal('5.473489')),
#  ('Southeast', 'Textron', Decimal('5.473985')),
#  ('Northeast', 'Cigna', Decimal('5.475462')),
#  ('Southeast', 'Kinder Morgan', Decimal('5.479083')),
#  ('Northeast', 'Honeywell International', Decimal('5.480494')),
#  ('Northeast', 'Berkshire Hathaway', Decimal('5.483687')),
#  ('Southeast', 'Nucor', Decimal('5.485892')),
#  ('Northeast', 'American Airlines Group', Decimal('5.486626')),
#  ('Northeast', 'Citigroup', Decimal('5.496349')),
#  ('Northeast', 'Freddie Mac', Decimal('5.498465')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.501737')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.502939')),
#  ('Southeast', 'Thermo Fisher Scientific', Decimal('5.507476')),
#  ('West', 'Jarden', Decimal('5.507753')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.509803')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.510095')),
#  ('Northeast', 'Ford Motor', Decimal('5.511822')),
#  ('Southeast', 'Thermo Fisher Scientific', Decimal('5.512893')),
#  ('Southeast', 'FirstEnergy', Decimal('5.519128')),
#  ('Midwest', 'AutoNation', Decimal('5.523495')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.529445')),
#  ('Northeast', 'Citigroup', Decimal('5.534252')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.535464')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.539121')),
#  ('Northeast', 'Philip Morris International', Decimal('5.541305')),
#  ('Northeast', 'Boeing', Decimal('5.542594')),
#  ('Southeast', 'Ameriprise Financial', Decimal('5.548004')),
#  ('Northeast', 'TJX', Decimal('5.557124')),
#  ('Northeast', 'Amazon.com', Decimal('5.557375')),
#  ('West', 'Univar', Decimal('5.558185')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.560549')),
#  ('Southeast', 'Ecolab', Decimal('5.560885')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.563952')),
#  ('Northeast', 'Nationwide', Decimal('5.565393')),
#  ('Southeast', 'Leucadia National', Decimal('5.565973')),
#  ('Southeast', 'Supervalu', Decimal('5.568782')),
#  ('Southeast', 'Ecolab', Decimal('5.570713')),
#  ('West', 'Fidelity National Financial', Decimal('5.575419')),
#  ('Midwest', 'Kraft Heinz', Decimal('5.581549')),
#  ('Midwest', 'Aflac', Decimal('5.582659')),
#  ('Northeast', 'Sysco', Decimal('5.583084')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.588439')),
#  ('Southeast', 'Kellogg', Decimal('5.589487')),
#  ('Southeast', 'FirstEnergy', Decimal('5.594313')),
#  ('Midwest', 'Altria Group', Decimal('5.608945')),
#  ('Northeast', 'United Technologies', Decimal('5.612459')),
#  ('Midwest', 'Qualcomm', Decimal('5.612945')),
#  ('Midwest', 'Qualcomm', Decimal('5.619908')),
#  ('Southeast', 'Textron', Decimal('5.622030')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.623648')),
#  ('Northeast', 'Target', Decimal('5.632564')),
#  ('Northeast', 'Intel', Decimal('5.634015')),
#  ('Northeast', 'General Dynamics', Decimal('5.634608')),
#  ('Northeast', 'Intel', Decimal('5.635751')),
#  ('West', 'State Street Corp.', Decimal('5.639676')),
#  ('Midwest', 'Raytheon', Decimal('5.640051')),
#  ('West', 'Charter Communications', Decimal('5.640702')),
#  ('Southeast', 'Supervalu', Decimal('5.641298')),
#  ('Northeast', 'Sysco', Decimal('5.641460')),
#  ('West', 'Hormel Foods', Decimal('5.651095')),
#  ('Northeast', 'United Technologies', Decimal('5.652020')),
#  ('Southeast', 'Supervalu', Decimal('5.652329')),
#  ('Northeast', 'United Technologies', Decimal('5.656249')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.661640')),
#  ('Southeast', 'Fluor', Decimal('5.662625')),
#  ('West', 'AutoZone', Decimal('5.663072')),
#  ('Midwest', 'Progressive', Decimal('5.664255')),
#  ('Southeast', 'Kellogg', Decimal('5.667999')),
#  ('Northeast', 'Sysco', Decimal('5.670820')),
#  ('Northeast', 'Prudential Financial', Decimal('5.676905')),
#  ('West', 'State Street Corp.', Decimal('5.678745')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.682705')),
#  ('Midwest', 'Southwest Airlines', Decimal('5.685340')),
#  ('Southeast', 'Thermo Fisher Scientific', Decimal('5.685904')),
#  ('Northeast', 'Freddie Mac', Decimal('5.686652')),
#  ('Southeast', 'Guardian Life Ins. Co. of America', Decimal('5.688580')),
#  ('Southeast', 'Icahn Enterprises', Decimal('5.689341')),
#  ('Southeast', "Toys 'R' Us", Decimal('5.691988')),
#  ('Northeast', 'Phillips 66', Decimal('5.694459')),
#  ('Southeast', 'First Data', Decimal('5.694503')),
#  ('West', 'Navistar International', Decimal('5.698409')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.707946')),
#  ('Midwest', 'AutoNation', Decimal('5.711517')),
#  ('West', 'State Street Corp.', Decimal('5.712669')),
#  ('Northeast', 'McKesson', Decimal('5.713830')),
#  ('Southeast', 'CDW', Decimal('5.714017')),
#  ('West', 'Anadarko Petroleum', Decimal('5.714119')),
#  ('Southeast', 'Texas Instruments', Decimal('5.714805')),
#  ('West', 'Celgene', Decimal('5.714981')),
#  ('Southeast', 'Fluor', Decimal('5.719007')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.719979')),
#  ('Northeast', 'Ford Motor', Decimal('5.720084')),
#  ('Northeast', 'Cigna', Decimal('5.730371')),
#  ('Midwest', 'Union Pacific', Decimal('5.730961')),
#  ('Southeast', 'Goodyear Tire & Rubber', Decimal('5.733232')),
#  ('West', 'BB&T Corp.', Decimal('5.734167')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.736731')),
#  ('Northeast', 'Aetna', Decimal('5.743465')),
#  ('Midwest', 'Centene', Decimal('5.745594')),
#  ('Northeast', 'Honeywell International', Decimal('5.749764')),
#  ('Southeast', 'Supervalu', Decimal('5.753700')),
#  ('West', 'Jarden', Decimal('5.757972')),
#  ('Midwest', "McDonald's", Decimal('5.761834')),
#  ('Midwest', 'AutoNation', Decimal('5.764127')),
#  ('Southeast', 'Leucadia National', Decimal('5.765599')),
#  ('Northeast', 'FedEx', Decimal('5.765981')),
#  ('Southeast', 'Fluor', Decimal('5.769759')),
#  ('Northeast', 'Disney', Decimal('5.770516')),
#  ('Midwest', 'Southwest Airlines', Decimal('5.772775')),
#  ('Northeast', 'General Dynamics', Decimal('5.775077')),
#  ('Northeast', 'United Technologies', Decimal('5.776712')),
#  ('Northeast', 'Target', Decimal('5.782979')),
#  ('Northeast', 'Amazon.com', Decimal('5.786983')),
#  ('Southeast', 'PBF Energy', Decimal('5.787559')),
#  ('Northeast', 'Intel', Decimal('5.788183')),
#  ('Southeast', 'Fluor', Decimal('5.791319')),
#  ('West', 'Western Refining', Decimal('5.796991')),
#  ('Northeast', 'Honeywell International', Decimal('5.799685')),
#  ('Midwest', 'Centene', Decimal('5.801333')),
#  ('Southeast', 'CDW', Decimal('5.803919')),
#  ('Northeast', 'Best Buy', Decimal('5.806723')),
#  ('Midwest', 'Union Pacific', Decimal('5.815923')),
#  ('Northeast', 'Sysco', Decimal('5.824165')),
#  ('Southeast', 'Guardian Life Ins. Co. of America', Decimal('5.829729')),
#  ('West', 'Advance Auto Parts', Decimal('5.832539')),
#  ('West', 'Republic Services', Decimal('5.833185')),
#  ('West', 'Precision Castparts', Decimal('5.837428')),
#  ('Southeast', 'Fluor', Decimal('5.839076')),
#  ('Southeast', 'Ecolab', Decimal('5.842741')),
#  ('Southeast', 'United States Steel', Decimal('5.844669')),
#  ('Southeast', 'Thermo Fisher Scientific', Decimal('5.844885')),
#  ('Midwest', 'Sears Holdings', Decimal('5.851001')),
#  ('West', 'Charter Communications', Decimal('5.851771')),
#  ('Southeast', 'Leucadia National', Decimal('5.852970')),
#  ('Northeast', 'Gilead Sciences', Decimal('5.855053')),
#  ('Southeast', 'Nordstrom', Decimal('5.857152')),
#  ('Northeast', 'Allstate', Decimal('5.857306')),
#  ('Southeast', "Land O'Lakes", Decimal('5.861503')),
#  ('Midwest', 'AutoNation', Decimal('5.862418')),
#  ('Southeast', 'CarMax', Decimal('5.866256')),
#  ('West', 'State Street Corp.', Decimal('5.868867')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.869531')),
#  ('Southeast', 'Principal Financial', Decimal('5.875875')),
#  ('Northeast', 'Exelon', Decimal('5.888153')),
#  ('Northeast', 'Citigroup', Decimal('5.890765')),
#  ('Southeast', 'National Oilwell Varco', Decimal('5.905172')),
#  ('Southeast', 'Western Digital', Decimal('5.907654')),
#  ('Northeast', 'Ford Motor', Decimal('5.911658')),
#  ('Midwest', 'Centene', Decimal('5.916138')),
#  ('Northeast', 'Pfizer', Decimal('5.917287')),
#  ('Northeast', 'Citigroup', Decimal('5.919668')),
#  ('West', 'Celgene', Decimal('5.919836')),
#  ('Midwest', 'Sears Holdings', Decimal('5.921463')),
#  ('Southeast', 'Western Digital', Decimal('5.924160')),
#  ('Midwest', 'Paccar', Decimal('5.927284')),
#  ('Southeast', 'Parker-Hannifin', Decimal('5.927546')),
#  ('Southeast', 'Leucadia National', Decimal('5.933527')),
#  ('Northeast', 'Sysco', Decimal('5.941700')),
#  ('West', 'BB&T Corp.', Decimal('5.943131')),
#  ('Southeast', 'PBF Energy', Decimal('5.946536')),
#  ('Southeast', 'Fluor', Decimal('5.949199')),
#  ('Northeast', 'State Farm Insurance Cos.', Decimal('5.955916')),
#  ('West', 'Hilton Worldwide Holdings', Decimal('5.959148')),
#  ('Southeast', 'Monsanto', Decimal('5.959970')),
#  ('Southeast', "Land O'Lakes", Decimal('5.960155')),
#  ('Northeast', 'AT&T', Decimal('5.962569')),
#  ('Midwest', 'Progressive', Decimal('5.963792')),
#  ('Northeast', 'Walmart', Decimal('5.965175')),
#  ('Southeast', 'Ameriprise Financial', Decimal('5.971716')),
#  ('Southeast', 'Baker Hughes', Decimal('5.972981')),
#  ('West', 'Reynolds American', Decimal('5.973876')),
#  ('Northeast', "Lowe's", Decimal('5.976025')),
#  ('Southeast', 'ADP', Decimal('5.978154')),
#  ('Midwest', 'Altria Group', Decimal('5.978541')),
#  ('Northeast', 'Disney', Decimal('5.985675')),
#  ('Southeast', 'FirstEnergy', Decimal('6.006917')),
#  ('Midwest', 'Whirlpool', Decimal('6.010043')),
#  ('Northeast', 'Citigroup', Decimal('6.018041')),
#  ('Northeast', 'Phillips 66', Decimal('6.021696')),
#  ('West', 'State Street Corp.', Decimal('6.024459')),
#  ('Southeast', 'Monsanto', Decimal('6.029554')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('6.030992')),
#  ('Midwest', 'Arrow Electronics', Decimal('6.040953')),
#  ('Northeast', 'Verizon', Decimal('6.044141')),
#  ('Midwest', 'Paccar', Decimal('6.058514')),
#  ('Midwest', 'Dollar General', Decimal('6.060797')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('6.068937')),
#  ('Southeast', 'FirstEnergy', Decimal('6.071050')),
#  ('Southeast', 'Chesapeake Energy', Decimal('6.079747')),
#  ('West', 'CST Brands', Decimal('6.089752')),
#  ('Northeast', 'Avnet', Decimal('6.093289')),
#  ('Southeast', 'Molina Healthcare', Decimal('6.150524')),
#  ('West', 'Mosaic', Decimal('6.151030')),
#  ('Northeast', "Lowe's", Decimal('6.151962')),
#  ('Midwest', 'Tenet Healthcare', Decimal('6.173701')),
#  ('Northeast', 'Citigroup', Decimal('6.179003')),
#  ('Northeast', 'Procter & Gamble', Decimal('6.183245')),
#  ('Southeast', 'PNC Financial Services Group', Decimal('6.192424')),
#  ('West', 'Assurant', Decimal('6.209788')),
#  ('Northeast', 'Honeywell International', Decimal('6.213421')),
#  ('West', 'PayPal Holdings', Decimal('6.221034')),
#  ('Northeast', 'Home Depot', Decimal('6.230713')),
#  ('Northeast', 'Bank of America Corp.', Decimal('6.246445')),
#  ('West', 'Owens & Minor', Decimal('6.261283')),
#  ('Northeast', 'AT&T', Decimal('6.266068')),
#  ('Midwest', 'Abbott Laboratories', Decimal('6.271437')),
#  ('Southeast', 'NGL Energy Partners', Decimal('6.272485')),
#  ('West', 'CST Brands', Decimal('6.272629')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('6.273823')),
#  ('West', 'MasterCard', Decimal('6.278161')),
#  ('West', 'Baxter International', Decimal('6.281770')),
#  ('Northeast', 'Ford Motor', Decimal('6.283316')),
#  ('Northeast', '3M', Decimal('6.296843')),
#  ('Southeast', 'Fluor', Decimal('6.304053')),
#  ('Southeast', 'Performance Food Group', Decimal('6.306238')),
#  ('Northeast', 'Microsoft', Decimal('6.307081')),
#  ('West', 'EOG Resources', Decimal('6.312122')),
#  ('West', 'Celgene', Decimal('6.316164')),
#  ('Midwest', 'Whirlpool', Decimal('6.321262')),
#  ('Northeast', 'Aetna', Decimal('6.323260')),
#  ('Northeast', 'Travelers Cos.', Decimal('6.324650')),
#  ('Northeast', '3M', Decimal('6.330595')),
#  ('Midwest', 'Altria Group', Decimal('6.334928')),
#  ('West', 'Navistar International', Decimal('6.340684')),
#  ('West', 'EOG Resources', Decimal('6.347395')),
#  ('Southeast', 'PNC Financial Services Group', Decimal('6.401861')),
#  ('Southeast', 'Aramark', Decimal('6.406985')),
#  ('Southeast', 'Lincoln National', Decimal('6.407386')),
#  ('Northeast', 'Target', Decimal('6.414162')),
#  ('Northeast', 'Nationwide', Decimal('6.426081')),
#  ('Northeast', 'Tyson Foods', Decimal('6.430019')),
#  ('Southeast', 'Kellogg', Decimal('6.461704')),
#  ('Southeast', 'Cognizant Technology Solutions', Decimal('6.489107')),
#  ('West', 'EOG Resources', Decimal('6.490461')),
#  ('Southeast', 'Thermo Fisher Scientific', Decimal('6.496018')),
#  ('Northeast', 'Best Buy', Decimal('6.501609')),
#  ('Northeast', 'General Dynamics', Decimal('6.527533')),
#  ('Northeast', 'Merck', Decimal('6.528469')),
#  ('Midwest', 'Lear', Decimal('6.553579')),
#  ('West', 'EOG Resources', Decimal('6.565275')),
#  ('Midwest', 'Paccar', Decimal('6.565311')),
#  ('Southeast', 'Goodyear Tire & Rubber', Decimal('6.576497')),
#  ('Northeast', 'IBM', Decimal('6.577740')),
#  ('Southeast', 'PBF Energy', Decimal('6.623758')),
#  ('Northeast', 'Prudential Financial', Decimal('6.625683')),
#  ('Northeast', 'Walmart', Decimal('6.628910')),
#  ('Northeast', 'General Dynamics', Decimal('6.630860')),
#  ('Northeast', 'Citigroup', Decimal('6.646222')),
#  ('Midwest', 'EMC', Decimal('6.658006')),
#  ('West', 'WestRock', Decimal('6.663090')),
#  ('Northeast', 'Aetna', Decimal('6.670767')),
#  ('Southeast', 'ADP', Decimal('6.687843')),
#  ('Northeast', 'Caterpillar', Decimal('6.740127')),
#  ('Southeast', 'CarMax', Decimal('6.741833')),
#  ('Southeast', 'ADP', Decimal('6.772607')),
#  ('Midwest', 'Qualcomm', Decimal('6.773283')),
#  ('Midwest', 'Raytheon', Decimal('6.780342')),
#  ('West', 'R.R. Donnelley & Sons', Decimal('6.825782')),
#  ('West', 'CST Brands', Decimal('6.854420')),
#  ('Northeast', 'American Airlines Group', Decimal('6.880289')),
#  ('Southeast', 'Occidental Petroleum', Decimal('6.895003')),
#  ('Southeast', 'National Oilwell Varco', Decimal('6.922538')),
#  ('Midwest', 'AutoNation', Decimal('6.946824')),
#  ('Southeast', 'PBF Energy', Decimal('6.949265')),
#  ('Northeast', 'Twenty-First Century Fox', Decimal('6.999505')),
#  ('West', 'Huntsman', Decimal('7.063634')),
#  ('Midwest', 'USAA', Decimal('7.069544')),
#  ('West', 'EOG Resources', Decimal('7.078284')),
#  ('Midwest', 'Arrow Electronics', Decimal('7.172409')),
#  ('West', 'Charter Communications', Decimal('7.175698')),
#  ('West', 'eBay', Decimal('7.180694')),
#  ('Northeast', 'Honeywell International', Decimal('7.235316')),
#  ('West', 'BB&T Corp.', Decimal('7.259396')),
#  ('Northeast', 'Boeing', Decimal('7.270149')),
#  ('Southeast', 'DaVita HealthCare Partners', Decimal('7.295310')),
#  ('Southeast', 'Cognizant Technology Solutions', Decimal('7.298833')),
#  ('Southeast', 'CBS', Decimal('7.316410')),
#  ('Northeast', 'General Dynamics', Decimal('7.331228')),
#  ('Northeast', 'TJX', Decimal('7.392951')),
#  ('Midwest', 'Time Warner Cable', Decimal('7.394556')),
#  ('Southeast', 'Bristol-Myers Squibb', Decimal('7.401323')),
#  ('Midwest', 'Aflac', Decimal('7.459659')),
#  ('Southeast', 'Edison International', Decimal('7.530563')),
#  ('Southeast', 'CSX', Decimal('7.560279')),
#  ('Northeast', 'Mondelez International', Decimal('7.592776')),
#  ('Southeast', 'Aramark', Decimal('7.635793')),
#  ('Midwest', 'Amgen', Decimal('7.753831')),
#  ('Northeast', 'Costco', Decimal('7.789352')),
#  ('Southeast', 'PNC Financial Services Group', Decimal('7.895139')),
#  ('Midwest', 'Paccar', Decimal('7.986962')),
#  ('West', 'Fidelity National Financial', Decimal('7.992802')),
#  ('Northeast', 'CHS', Decimal('8.018849')),
#  ('West', 'Pacific Life', Decimal('8.063023')),
#  ('West', 'Mosaic', Decimal('8.066329')),
#  ('Northeast', 'IBM', Decimal('8.089906'))]

# %% [markdown]
# # Task 6: Cracking the Sales Code.
# In the world of sales analysis, this query is a compass guiding us toward hidden treasures. By isolating orders with specific quantity criteria, we unearth valuable insights into pricing dynamics. The descending order of unit prices exposes products and accounts with the highest worth. This knowledge empowers businesses to optimize pricing strategies and enhance profitability. In a data-rich landscape, such queries are the key to deciphering the complex maze of commerce, shaping the path for smarter decisions in sales.
#
# =======================
#
# Unit Price Calculation for High-Quantity Orders.
# Write SQL query for the following:
#
# For orders with a standard quantity greater than 100 and a poster quantity greater than 50, what is the unit price of each order in each region, along with the associated account names, sorted in descending order by unit price?
#
# Unit price is calculated dividing the total amount in USD by the sum of the total quantity and a small constant (0.01) to avoid division by zero errors.

# %%
# %%sql
# select region.name as region, accounts.name as account_name, total_amt_usd/(total + 0.01) as unit_price from orders
# JOIN accounts ON accounts.id = orders.account_id
# JOIN sales_reps ON sales_reps.id = accounts.sales_rep_id
# JOIN region ON region.id = sales_reps.region_id
# WHERE orders.standard_qty > 100 and orders.poster_qty > 50
# ORDER BY unit_price DESC;
# Out:
#  * mysql+pymysql://root:***@localhost/Sales_EDA
# 356 rows affected.
# [('Northeast', 'IBM', Decimal('8.089906')),
#  ('West', 'Mosaic', Decimal('8.066329')),
#  ('West', 'Pacific Life', Decimal('8.063023')),
#  ('Northeast', 'CHS', Decimal('8.018849')),
#  ('West', 'Fidelity National Financial', Decimal('7.992802')),
#  ('Midwest', 'Paccar', Decimal('7.986962')),
#  ('Southeast', 'PNC Financial Services Group', Decimal('7.895139')),
#  ('Northeast', 'Costco', Decimal('7.789352')),
#  ('Midwest', 'Amgen', Decimal('7.753831')),
#  ('Southeast', 'Aramark', Decimal('7.635793')),
#  ('Northeast', 'Mondelez International', Decimal('7.592776')),
#  ('Southeast', 'CSX', Decimal('7.560279')),
#  ('Southeast', 'Edison International', Decimal('7.530563')),
#  ('Midwest', 'Aflac', Decimal('7.459659')),
#  ('Southeast', 'Bristol-Myers Squibb', Decimal('7.401323')),
#  ('Midwest', 'Time Warner Cable', Decimal('7.394556')),
#  ('Northeast', 'TJX', Decimal('7.392951')),
#  ('Northeast', 'General Dynamics', Decimal('7.331228')),
#  ('Southeast', 'CBS', Decimal('7.316410')),
#  ('Southeast', 'Cognizant Technology Solutions', Decimal('7.298833')),
#  ('Southeast', 'DaVita HealthCare Partners', Decimal('7.295310')),
#  ('Northeast', 'Boeing', Decimal('7.270149')),
#  ('West', 'BB&T Corp.', Decimal('7.259396')),
#  ('Northeast', 'Honeywell International', Decimal('7.235316')),
#  ('West', 'eBay', Decimal('7.180694')),
#  ('West', 'Charter Communications', Decimal('7.175698')),
#  ('Midwest', 'Arrow Electronics', Decimal('7.172409')),
#  ('West', 'EOG Resources', Decimal('7.078284')),
#  ('Midwest', 'USAA', Decimal('7.069544')),
#  ('West', 'Huntsman', Decimal('7.063634')),
#  ('Northeast', 'Twenty-First Century Fox', Decimal('6.999505')),
#  ('Southeast', 'PBF Energy', Decimal('6.949265')),
#  ('Midwest', 'AutoNation', Decimal('6.946824')),
#  ('Southeast', 'National Oilwell Varco', Decimal('6.922538')),
#  ('Southeast', 'Occidental Petroleum', Decimal('6.895003')),
#  ('Northeast', 'American Airlines Group', Decimal('6.880289')),
#  ('West', 'CST Brands', Decimal('6.854420')),
#  ('West', 'R.R. Donnelley & Sons', Decimal('6.825782')),
#  ('Midwest', 'Raytheon', Decimal('6.780342')),
#  ('Midwest', 'Qualcomm', Decimal('6.773283')),
#  ('Southeast', 'ADP', Decimal('6.772607')),
#  ('Southeast', 'CarMax', Decimal('6.741833')),
#  ('Northeast', 'Caterpillar', Decimal('6.740127')),
#  ('Southeast', 'ADP', Decimal('6.687843')),
#  ('Northeast', 'Aetna', Decimal('6.670767')),
#  ('West', 'WestRock', Decimal('6.663090')),
#  ('Midwest', 'EMC', Decimal('6.658006')),
#  ('Northeast', 'Citigroup', Decimal('6.646222')),
#  ('Northeast', 'General Dynamics', Decimal('6.630860')),
#  ('Northeast', 'Walmart', Decimal('6.628910')),
#  ('Northeast', 'Prudential Financial', Decimal('6.625683')),
#  ('Southeast', 'PBF Energy', Decimal('6.623758')),
#  ('Northeast', 'IBM', Decimal('6.577740')),
#  ('Southeast', 'Goodyear Tire & Rubber', Decimal('6.576497')),
#  ('Midwest', 'Paccar', Decimal('6.565311')),
#  ('West', 'EOG Resources', Decimal('6.565275')),
#  ('Midwest', 'Lear', Decimal('6.553579')),
#  ('Northeast', 'Merck', Decimal('6.528469')),
#  ('Northeast', 'General Dynamics', Decimal('6.527533')),
#  ('Northeast', 'Best Buy', Decimal('6.501609')),
#  ('Southeast', 'Thermo Fisher Scientific', Decimal('6.496018')),
#  ('West', 'EOG Resources', Decimal('6.490461')),
#  ('Southeast', 'Cognizant Technology Solutions', Decimal('6.489107')),
#  ('Southeast', 'Kellogg', Decimal('6.461704')),
#  ('Northeast', 'Tyson Foods', Decimal('6.430019')),
#  ('Northeast', 'Nationwide', Decimal('6.426081')),
#  ('Northeast', 'Target', Decimal('6.414162')),
#  ('Southeast', 'Lincoln National', Decimal('6.407386')),
#  ('Southeast', 'Aramark', Decimal('6.406985')),
#  ('Southeast', 'PNC Financial Services Group', Decimal('6.401861')),
#  ('West', 'EOG Resources', Decimal('6.347395')),
#  ('West', 'Navistar International', Decimal('6.340684')),
#  ('Midwest', 'Altria Group', Decimal('6.334928')),
#  ('Northeast', '3M', Decimal('6.330595')),
#  ('Northeast', 'Travelers Cos.', Decimal('6.324650')),
#  ('Northeast', 'Aetna', Decimal('6.323260')),
#  ('Midwest', 'Whirlpool', Decimal('6.321262')),
#  ('West', 'Celgene', Decimal('6.316164')),
#  ('West', 'EOG Resources', Decimal('6.312122')),
#  ('Northeast', 'Microsoft', Decimal('6.307081')),
#  ('Southeast', 'Performance Food Group', Decimal('6.306238')),
#  ('Southeast', 'Fluor', Decimal('6.304053')),
#  ('Northeast', '3M', Decimal('6.296843')),
#  ('Northeast', 'Ford Motor', Decimal('6.283316')),
#  ('West', 'Baxter International', Decimal('6.281770')),
#  ('West', 'MasterCard', Decimal('6.278161')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('6.273823')),
#  ('West', 'CST Brands', Decimal('6.272629')),
#  ('Southeast', 'NGL Energy Partners', Decimal('6.272485')),
#  ('Midwest', 'Abbott Laboratories', Decimal('6.271437')),
#  ('Northeast', 'AT&T', Decimal('6.266068')),
#  ('West', 'Owens & Minor', Decimal('6.261283')),
#  ('Northeast', 'Bank of America Corp.', Decimal('6.246445')),
#  ('Northeast', 'Home Depot', Decimal('6.230713')),
#  ('West', 'PayPal Holdings', Decimal('6.221034')),
#  ('Northeast', 'Honeywell International', Decimal('6.213421')),
#  ('West', 'Assurant', Decimal('6.209788')),
#  ('Southeast', 'PNC Financial Services Group', Decimal('6.192424')),
#  ('Northeast', 'Procter & Gamble', Decimal('6.183245')),
#  ('Northeast', 'Citigroup', Decimal('6.179003')),
#  ('Midwest', 'Tenet Healthcare', Decimal('6.173701')),
#  ('Northeast', "Lowe's", Decimal('6.151962')),
#  ('West', 'Mosaic', Decimal('6.151030')),
#  ('Southeast', 'Molina Healthcare', Decimal('6.150524')),
#  ('Northeast', 'Avnet', Decimal('6.093289')),
#  ('West', 'CST Brands', Decimal('6.089752')),
#  ('Southeast', 'Chesapeake Energy', Decimal('6.079747')),
#  ('Southeast', 'FirstEnergy', Decimal('6.071050')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('6.068937')),
#  ('Midwest', 'Dollar General', Decimal('6.060797')),
#  ('Midwest', 'Paccar', Decimal('6.058514')),
#  ('Northeast', 'Verizon', Decimal('6.044141')),
#  ('Midwest', 'Arrow Electronics', Decimal('6.040953')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('6.030992')),
#  ('Southeast', 'Monsanto', Decimal('6.029554')),
#  ('West', 'State Street Corp.', Decimal('6.024459')),
#  ('Northeast', 'Phillips 66', Decimal('6.021696')),
#  ('Northeast', 'Citigroup', Decimal('6.018041')),
#  ('Midwest', 'Whirlpool', Decimal('6.010043')),
#  ('Southeast', 'FirstEnergy', Decimal('6.006917')),
#  ('Northeast', 'Disney', Decimal('5.985675')),
#  ('Midwest', 'Altria Group', Decimal('5.978541')),
#  ('Southeast', 'ADP', Decimal('5.978154')),
#  ('Northeast', "Lowe's", Decimal('5.976025')),
#  ('West', 'Reynolds American', Decimal('5.973876')),
#  ('Southeast', 'Baker Hughes', Decimal('5.972981')),
#  ('Southeast', 'Ameriprise Financial', Decimal('5.971716')),
#  ('Northeast', 'Walmart', Decimal('5.965175')),
#  ('Midwest', 'Progressive', Decimal('5.963792')),
#  ('Northeast', 'AT&T', Decimal('5.962569')),
#  ('Southeast', "Land O'Lakes", Decimal('5.960155')),
#  ('Southeast', 'Monsanto', Decimal('5.959970')),
#  ('West', 'Hilton Worldwide Holdings', Decimal('5.959148')),
#  ('Northeast', 'State Farm Insurance Cos.', Decimal('5.955916')),
#  ('Southeast', 'Fluor', Decimal('5.949199')),
#  ('Southeast', 'PBF Energy', Decimal('5.946536')),
#  ('West', 'BB&T Corp.', Decimal('5.943131')),
#  ('Northeast', 'Sysco', Decimal('5.941700')),
#  ('Southeast', 'Leucadia National', Decimal('5.933527')),
#  ('Southeast', 'Parker-Hannifin', Decimal('5.927546')),
#  ('Midwest', 'Paccar', Decimal('5.927284')),
#  ('Southeast', 'Western Digital', Decimal('5.924160')),
#  ('Midwest', 'Sears Holdings', Decimal('5.921463')),
#  ('West', 'Celgene', Decimal('5.919836')),
#  ('Northeast', 'Citigroup', Decimal('5.919668')),
#  ('Northeast', 'Pfizer', Decimal('5.917287')),
#  ('Midwest', 'Centene', Decimal('5.916138')),
#  ('Northeast', 'Ford Motor', Decimal('5.911658')),
#  ('Southeast', 'Western Digital', Decimal('5.907654')),
#  ('Southeast', 'National Oilwell Varco', Decimal('5.905172')),
#  ('Northeast', 'Citigroup', Decimal('5.890765')),
#  ('Northeast', 'Exelon', Decimal('5.888153')),
#  ('Southeast', 'Principal Financial', Decimal('5.875875')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.869531')),
#  ('West', 'State Street Corp.', Decimal('5.868867')),
#  ('Southeast', 'CarMax', Decimal('5.866256')),
#  ('Midwest', 'AutoNation', Decimal('5.862418')),
#  ('Southeast', "Land O'Lakes", Decimal('5.861503')),
#  ('Northeast', 'Allstate', Decimal('5.857306')),
#  ('Southeast', 'Nordstrom', Decimal('5.857152')),
#  ('Northeast', 'Gilead Sciences', Decimal('5.855053')),
#  ('Southeast', 'Leucadia National', Decimal('5.852970')),
#  ('West', 'Charter Communications', Decimal('5.851771')),
#  ('Midwest', 'Sears Holdings', Decimal('5.851001')),
#  ('Southeast', 'Thermo Fisher Scientific', Decimal('5.844885')),
#  ('Southeast', 'United States Steel', Decimal('5.844669')),
#  ('Southeast', 'Ecolab', Decimal('5.842741')),
#  ('Southeast', 'Fluor', Decimal('5.839076')),
#  ('West', 'Precision Castparts', Decimal('5.837428')),
#  ('West', 'Republic Services', Decimal('5.833185')),
#  ('West', 'Advance Auto Parts', Decimal('5.832539')),
#  ('Southeast', 'Guardian Life Ins. Co. of America', Decimal('5.829729')),
#  ('Northeast', 'Sysco', Decimal('5.824165')),
#  ('Midwest', 'Union Pacific', Decimal('5.815923')),
#  ('Northeast', 'Best Buy', Decimal('5.806723')),
#  ('Southeast', 'CDW', Decimal('5.803919')),
#  ('Midwest', 'Centene', Decimal('5.801333')),
#  ('Northeast', 'Honeywell International', Decimal('5.799685')),
#  ('West', 'Western Refining', Decimal('5.796991')),
#  ('Southeast', 'Fluor', Decimal('5.791319')),
#  ('Northeast', 'Intel', Decimal('5.788183')),
#  ('Southeast', 'PBF Energy', Decimal('5.787559')),
#  ('Northeast', 'Amazon.com', Decimal('5.786983')),
#  ('Northeast', 'Target', Decimal('5.782979')),
#  ('Northeast', 'United Technologies', Decimal('5.776712')),
#  ('Northeast', 'General Dynamics', Decimal('5.775077')),
#  ('Midwest', 'Southwest Airlines', Decimal('5.772775')),
#  ('Northeast', 'Disney', Decimal('5.770516')),
#  ('Southeast', 'Fluor', Decimal('5.769759')),
#  ('Northeast', 'FedEx', Decimal('5.765981')),
#  ('Southeast', 'Leucadia National', Decimal('5.765599')),
#  ('Midwest', 'AutoNation', Decimal('5.764127')),
#  ('Midwest', "McDonald's", Decimal('5.761834')),
#  ('West', 'Jarden', Decimal('5.757972')),
#  ('Southeast', 'Supervalu', Decimal('5.753700')),
#  ('Northeast', 'Honeywell International', Decimal('5.749764')),
#  ('Midwest', 'Centene', Decimal('5.745594')),
#  ('Northeast', 'Aetna', Decimal('5.743465')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.736731')),
#  ('West', 'BB&T Corp.', Decimal('5.734167')),
#  ('Southeast', 'Goodyear Tire & Rubber', Decimal('5.733232')),
#  ('Midwest', 'Union Pacific', Decimal('5.730961')),
#  ('Northeast', 'Cigna', Decimal('5.730371')),
#  ('Northeast', 'Ford Motor', Decimal('5.720084')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.719979')),
#  ('Southeast', 'Fluor', Decimal('5.719007')),
#  ('West', 'Celgene', Decimal('5.714981')),
#  ('Southeast', 'Texas Instruments', Decimal('5.714805')),
#  ('West', 'Anadarko Petroleum', Decimal('5.714119')),
#  ('Southeast', 'CDW', Decimal('5.714017')),
#  ('Northeast', 'McKesson', Decimal('5.713830')),
#  ('West', 'State Street Corp.', Decimal('5.712669')),
#  ('Midwest', 'AutoNation', Decimal('5.711517')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.707946')),
#  ('West', 'Navistar International', Decimal('5.698409')),
#  ('Southeast', 'First Data', Decimal('5.694503')),
#  ('Northeast', 'Phillips 66', Decimal('5.694459')),
#  ('Southeast', "Toys 'R' Us", Decimal('5.691988')),
#  ('Southeast', 'Icahn Enterprises', Decimal('5.689341')),
#  ('Southeast', 'Guardian Life Ins. Co. of America', Decimal('5.688580')),
#  ('Northeast', 'Freddie Mac', Decimal('5.686652')),
#  ('Southeast', 'Thermo Fisher Scientific', Decimal('5.685904')),
#  ('Midwest', 'Southwest Airlines', Decimal('5.685340')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.682705')),
#  ('West', 'State Street Corp.', Decimal('5.678745')),
#  ('Northeast', 'Prudential Financial', Decimal('5.676905')),
#  ('Northeast', 'Sysco', Decimal('5.670820')),
#  ('Southeast', 'Kellogg', Decimal('5.667999')),
#  ('Midwest', 'Progressive', Decimal('5.664255')),
#  ('West', 'AutoZone', Decimal('5.663072')),
#  ('Southeast', 'Fluor', Decimal('5.662625')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.661640')),
#  ('Northeast', 'United Technologies', Decimal('5.656249')),
#  ('Southeast', 'Supervalu', Decimal('5.652329')),
#  ('Northeast', 'United Technologies', Decimal('5.652020')),
#  ('West', 'Hormel Foods', Decimal('5.651095')),
#  ('Northeast', 'Sysco', Decimal('5.641460')),
#  ('Southeast', 'Supervalu', Decimal('5.641298')),
#  ('West', 'Charter Communications', Decimal('5.640702')),
#  ('Midwest', 'Raytheon', Decimal('5.640051')),
#  ('West', 'State Street Corp.', Decimal('5.639676')),
#  ('Northeast', 'Intel', Decimal('5.635751')),
#  ('Northeast', 'General Dynamics', Decimal('5.634608')),
#  ('Northeast', 'Intel', Decimal('5.634015')),
#  ('Northeast', 'Target', Decimal('5.632564')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.623648')),
#  ('Southeast', 'Textron', Decimal('5.622030')),
#  ('Midwest', 'Qualcomm', Decimal('5.619908')),
#  ('Midwest', 'Qualcomm', Decimal('5.612945')),
#  ('Northeast', 'United Technologies', Decimal('5.612459')),
#  ('Midwest', 'Altria Group', Decimal('5.608945')),
#  ('Southeast', 'FirstEnergy', Decimal('5.594313')),
#  ('Southeast', 'Kellogg', Decimal('5.589487')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.588439')),
#  ('Northeast', 'Sysco', Decimal('5.583084')),
#  ('Midwest', 'Aflac', Decimal('5.582659')),
#  ('Midwest', 'Kraft Heinz', Decimal('5.581549')),
#  ('West', 'Fidelity National Financial', Decimal('5.575419')),
#  ('Southeast', 'Ecolab', Decimal('5.570713')),
#  ('Southeast', 'Supervalu', Decimal('5.568782')),
#  ('Southeast', 'Leucadia National', Decimal('5.565973')),
#  ('Northeast', 'Nationwide', Decimal('5.565393')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.563952')),
#  ('Southeast', 'Ecolab', Decimal('5.560885')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.560549')),
#  ('West', 'Univar', Decimal('5.558185')),
#  ('Northeast', 'Amazon.com', Decimal('5.557375')),
#  ('Northeast', 'TJX', Decimal('5.557124')),
#  ('Southeast', 'Ameriprise Financial', Decimal('5.548004')),
#  ('Northeast', 'Boeing', Decimal('5.542594')),
#  ('Northeast', 'Philip Morris International', Decimal('5.541305')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.539121')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.535464')),
#  ('Northeast', 'Citigroup', Decimal('5.534252')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.529445')),
#  ('Midwest', 'AutoNation', Decimal('5.523495')),
#  ('Southeast', 'FirstEnergy', Decimal('5.519128')),
#  ('Southeast', 'Thermo Fisher Scientific', Decimal('5.512893')),
#  ('Northeast', 'Ford Motor', Decimal('5.511822')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.510095')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.509803')),
#  ('West', 'Jarden', Decimal('5.507753')),
#  ('Southeast', 'Thermo Fisher Scientific', Decimal('5.507476')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.502939')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.501737')),
#  ('Northeast', 'Freddie Mac', Decimal('5.498465')),
#  ('Northeast', 'Citigroup', Decimal('5.496349')),
#  ('Northeast', 'American Airlines Group', Decimal('5.486626')),
#  ('Southeast', 'Nucor', Decimal('5.485892')),
#  ('Northeast', 'Berkshire Hathaway', Decimal('5.483687')),
#  ('Northeast', 'Honeywell International', Decimal('5.480494')),
#  ('Southeast', 'Kinder Morgan', Decimal('5.479083')),
#  ('Northeast', 'Cigna', Decimal('5.475462')),
#  ('Southeast', 'Textron', Decimal('5.473985')),
#  ('Midwest', 'Alcoa', Decimal('5.473489')),
#  ('Southeast', 'Ecolab', Decimal('5.471191')),
#  ('Southeast', 'FirstEnergy', Decimal('5.462148')),
#  ('West', 'Western Refining', Decimal('5.461673')),
#  ('Northeast', 'Citigroup', Decimal('5.460688')),
#  ('Northeast', 'Sysco', Decimal('5.458567')),
#  ('West', 'Global Partners', Decimal('5.453343')),
#  ('West', 'PayPal Holdings', Decimal('5.445747')),
#  ('Northeast', 'Comcast', Decimal('5.445104')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.442049')),
#  ('Midwest', 'Kraft Heinz', Decimal('5.437828')),
#  ('Southeast', 'BlackRock', Decimal('5.435965')),
#  ('Southeast', 'American Electric Power', Decimal('5.430177')),
#  ('Northeast', 'Coca-Cola', Decimal('5.423158')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.415237')),
#  ('West', 'Core-Mark Holding', Decimal('5.414891')),
#  ('Midwest', 'AutoNation', Decimal('5.414751')),
#  ('Northeast', "Lowe's", Decimal('5.410306')),
#  ('West', 'Thrivent Financial for Lutherans', Decimal('5.408913')),
#  ('Southeast', 'ADP', Decimal('5.406828')),
#  ('Southeast', 'ADP', Decimal('5.405471')),
#  ('Northeast', 'Merck', Decimal('5.398362')),
#  ('Southeast', 'Monsanto', Decimal('5.392332')),
#  ('Southeast', 'Kellogg', Decimal('5.388562')),
#  ('Southeast', 'Nucor', Decimal('5.388062')),
#  ('Southeast', 'Thermo Fisher Scientific', Decimal('5.387129')),
#  ('Southeast', 'BlackRock', Decimal('5.382070')),
#  ('Southeast', 'Health Net', Decimal('5.377892')),
#  ('West', 'Unum Group', Decimal('5.371478')),
#  ('Southeast', 'Performance Food Group', Decimal('5.370258')),
#  ('Northeast', 'Cisco Systems', Decimal('5.366839')),
#  ('West', 'Charter Communications', Decimal('5.364147')),
#  ('West', 'R.R. Donnelley & Sons', Decimal('5.361952')),
#  ('West', 'Charter Communications', Decimal('5.361681')),
#  ('Northeast', 'FedEx', Decimal('5.358938')),
#  ('Northeast', 'Citigroup', Decimal('5.358370')),
#  ('Southeast', 'Ecolab', Decimal('5.357762')),
#  ('West', 'eBay', Decimal('5.355893')),
#  ('Midwest', 'AutoNation', Decimal('5.351093')),
#  ('West', 'Reynolds American', Decimal('5.348768')),
#  ('Southeast', 'ADP', Decimal('5.348600')),
#  ('Southeast', 'Supervalu', Decimal('5.347728')),
#  ('West', 'Core-Mark Holding', Decimal('5.343204')),
#  ('Southeast', "Land O'Lakes", Decimal('5.340489')),
#  ('Northeast', 'Philip Morris International', Decimal('5.340240')),
#  ('Northeast', 'Philip Morris International', Decimal('5.339153')),
#  ('West', 'Thrivent Financial for Lutherans', Decimal('5.337679')),
#  ('Midwest', 'Dollar General', Decimal('5.333630')),
#  ('West', 'Core-Mark Holding', Decimal('5.328663')),
#  ('Northeast', 'FedEx', Decimal('5.326170')),
#  ('Northeast', 'Cisco Systems', Decimal('5.318950')),
#  ('Northeast', 'TIAA', Decimal('5.310935')),
#  ('Northeast', 'Northwestern Mutual', Decimal('5.307969')),
#  ('Midwest', 'Aflac', Decimal('5.305558')),
#  ('Northeast', 'Fannie Mae', Decimal('5.303465')),
#  ('Southeast', 'BlackRock', Decimal('5.301770')),
#  ('Midwest', 'Sears Holdings', Decimal('5.300912')),
#  ('Northeast', 'Merck', Decimal('5.296391')),
#  ('Southeast', 'Nucor', Decimal('5.289094')),
#  ('Southeast', 'BlackRock', Decimal('5.278270')),
#  ('Northeast', 'Citigroup', Decimal('5.273081')),
#  ('West', 'Stanley Black & Decker', Decimal('5.266396'))]

# %% [markdown]
# # Task 7: Efficiency through Precision.
# In the world of data analysis, concise queries like this serve a vital role. With a specific focus on orders surpassing defined quantities, this query uncovers the essence of sales - the unit price. Ordering it in descending fashion highlights the most valuable products and accounts, streamlining pricing strategies and profitability.
#
# The query's brevity is intentional, as it succinctly delivers precise, actionable insights. It allows businesses to efficiently navigate the intricate landscape of sales, saving time and resources. In a fast-paced environment, such succinct queries offer the tools needed for informed decision-making, unlocking the potential of sales data with minimal complexity.
#
# =========
#
# Unit Price Calculation for Moderate-Quantity Orders.
# Write SQL query for the following:
#
# For orders with a standard quantity greater than 50 and a poster quantity greater than 25, what is the unit price of each order in each region, along with the associated account names, sorted in descending order by unit price?
#
# Unit price is calculated dividing the total amount in USD by the sum of the total quantity and a small constant (0.01) to avoid division by zero errors.

# %%
# %%sql
# select region.name as region, accounts.name as account_name, total_amt_usd/(total + 0.01) as unit_price from orders
# JOIN accounts ON accounts.id = orders.account_id
# JOIN sales_reps ON sales_reps.id = accounts.sales_rep_id
# JOIN region ON region.id = sales_reps.region_id
# WHERE orders.standard_qty > 50 and orders.poster_qty > 25
# ORDER BY unit_price DESC;
# Out:
#  * mysql+pymysql://root:***@localhost/Sales_EDA
# 1129 rows affected.
# [('Northeast', 'IBM', Decimal('8.089906')),
#  ('West', 'Mosaic', Decimal('8.066329')),
#  ('West', 'Pacific Life', Decimal('8.063023')),
#  ('Northeast', 'CHS', Decimal('8.018849')),
#  ('West', 'Fidelity National Financial', Decimal('7.992802')),
#  ('Midwest', 'Paccar', Decimal('7.986962')),
#  ('Southeast', 'PNC Financial Services Group', Decimal('7.895139')),
#  ('Northeast', 'Costco', Decimal('7.789352')),
#  ('Midwest', 'Amgen', Decimal('7.753831')),
#  ('Southeast', 'Aramark', Decimal('7.635793')),
#  ('Northeast', 'Mondelez International', Decimal('7.592776')),
#  ('Southeast', 'CSX', Decimal('7.560279')),
#  ('Southeast', 'Edison International', Decimal('7.530563')),
#  ('Midwest', 'Aflac', Decimal('7.459659')),
#  ('Southeast', 'Bristol-Myers Squibb', Decimal('7.401323')),
#  ('Midwest', 'Time Warner Cable', Decimal('7.394556')),
#  ('Northeast', 'TJX', Decimal('7.392951')),
#  ('Northeast', 'Disney', Decimal('7.381408')),
#  ('West', 'Crown Holdings', Decimal('7.354299')),
#  ('Northeast', 'General Dynamics', Decimal('7.331228')),
#  ('Northeast', 'Caterpillar', Decimal('7.321467')),
#  ('Southeast', 'CBS', Decimal('7.316410')),
#  ('Southeast', 'Cognizant Technology Solutions', Decimal('7.298833')),
#  ('Southeast', 'DaVita HealthCare Partners', Decimal('7.295310')),
#  ('Northeast', 'Boeing', Decimal('7.270149')),
#  ('West', 'BB&T Corp.', Decimal('7.259396')),
#  ('Northeast', 'Honeywell International', Decimal('7.235316')),
#  ('West', 'eBay', Decimal('7.180694')),
#  ('West', 'Charter Communications', Decimal('7.175698')),
#  ('Midwest', 'Arrow Electronics', Decimal('7.172409')),
#  ('Northeast', 'Oracle', Decimal('7.130414')),
#  ('West', 'EOG Resources', Decimal('7.078284')),
#  ('Midwest', 'USAA', Decimal('7.069544')),
#  ('West', 'Huntsman', Decimal('7.063634')),
#  ('Northeast', 'Walmart', Decimal('7.003857')),
#  ('Northeast', 'Twenty-First Century Fox', Decimal('6.999505')),
#  ('Southeast', 'PBF Energy', Decimal('6.949265')),
#  ('Midwest', 'AutoNation', Decimal('6.946824')),
#  ('Southeast', 'National Oilwell Varco', Decimal('6.922538')),
#  ('Southeast', 'PG&E Corp.', Decimal('6.912882')),
#  ('Southeast', 'Occidental Petroleum', Decimal('6.895003')),
#  ('Northeast', 'American Airlines Group', Decimal('6.880289')),
#  ('West', 'CST Brands', Decimal('6.854420')),
#  ('Northeast', 'Ingram Micro', Decimal('6.843097')),
#  ('Northeast', 'Time Warner', Decimal('6.833305')),
#  ('West', 'R.R. Donnelley & Sons', Decimal('6.825782')),
#  ('Northeast', 'Pfizer', Decimal('6.821645')),
#  ('Southeast', 'Bristol-Myers Squibb', Decimal('6.820476')),
#  ('Northeast', 'Walmart', Decimal('6.780654')),
#  ('Midwest', 'Raytheon', Decimal('6.780342')),
#  ('Midwest', 'Qualcomm', Decimal('6.773283')),
#  ('Southeast', 'ADP', Decimal('6.772607')),
#  ('Southeast', 'CarMax', Decimal('6.741833')),
#  ('Midwest', 'Halliburton', Decimal('6.740173')),
#  ('Northeast', 'Caterpillar', Decimal('6.740127')),
#  ('Southeast', 'Genuine Parts', Decimal('6.737586')),
#  ('Northeast', 'Wells Fargo', Decimal('6.726313')),
#  ('Southeast', 'Illinois Tool Works', Decimal('6.720566')),
#  ('Midwest', 'U.S. Bancorp', Decimal('6.711285')),
#  ('Southeast', 'ADP', Decimal('6.687843')),
#  ('Midwest', 'EMC', Decimal('6.685576')),
#  ('Northeast', 'Aetna', Decimal('6.670767')),
#  ('West', 'WestRock', Decimal('6.663090')),
#  ('Midwest', 'EMC', Decimal('6.658006')),
#  ('Northeast', 'Citigroup', Decimal('6.646222')),
#  ('Southeast', 'Occidental Petroleum', Decimal('6.632428')),
#  ('Northeast', 'General Dynamics', Decimal('6.630860')),
#  ('Northeast', 'Walmart', Decimal('6.628910')),
#  ('Northeast', 'Prudential Financial', Decimal('6.625683')),
#  ('Southeast', 'PBF Energy', Decimal('6.623758')),
#  ('West', 'HD Supply Holdings', Decimal('6.616061')),
#  ('Southeast', 'CSX', Decimal('6.614873')),
#  ('Northeast', 'HCA Holdings', Decimal('6.607278')),
#  ('Northeast', 'Avnet', Decimal('6.605179')),
#  ('Midwest', 'Capital One Financial', Decimal('6.597974')),
#  ('Northeast', 'IBM', Decimal('6.581529')),
#  ('Northeast', 'IBM', Decimal('6.577740')),
#  ('Southeast', 'Goodyear Tire & Rubber', Decimal('6.576497')),
#  ('Northeast', 'Bank of America Corp.', Decimal('6.568658')),
#  ('Midwest', 'Paccar', Decimal('6.565311')),
#  ('West', 'EOG Resources', Decimal('6.565275')),
#  ('Northeast', 'IBM', Decimal('6.555992')),
#  ('Midwest', 'Lear', Decimal('6.553579')),
#  ('Midwest', 'Amgen', Decimal('6.549459')),
#  ('Midwest', 'EMC', Decimal('6.539256')),
#  ('Northeast', 'Merck', Decimal('6.528469')),
#  ('Northeast', 'General Dynamics', Decimal('6.527533')),
#  ('Southeast', 'Occidental Petroleum', Decimal('6.520148')),
#  ('Northeast', 'Best Buy', Decimal('6.501609')),
#  ('Southeast', 'Thermo Fisher Scientific', Decimal('6.496018')),
#  ('Northeast', 'Avnet', Decimal('6.493013')),
#  ('West', 'EOG Resources', Decimal('6.490461')),
#  ('Southeast', 'Cognizant Technology Solutions', Decimal('6.489107')),
#  ('Northeast', 'Oracle', Decimal('6.483295')),
#  ('Midwest', 'U.S. Bancorp', Decimal('6.481515')),
#  ('Northeast', 'IBM', Decimal('6.467572')),
#  ('Northeast', '3M', Decimal('6.465003')),
#  ('Southeast', 'Kellogg', Decimal('6.461704')),
#  ('Southeast', 'NGL Energy Partners', Decimal('6.450968')),
#  ('Northeast', 'Caterpillar', Decimal('6.436538')),
#  ('Northeast', 'Tyson Foods', Decimal('6.430019')),
#  ('Northeast', 'Nationwide', Decimal('6.426081')),
#  ('West', 'EOG Resources', Decimal('6.414887')),
#  ('Northeast', 'Target', Decimal('6.414162')),
#  ('Midwest', 'International Paper', Decimal('6.412339')),
#  ('Southeast', 'Lincoln National', Decimal('6.407386')),
#  ('Southeast', 'Aramark', Decimal('6.406985')),
#  ('Southeast', 'PNC Financial Services Group', Decimal('6.401861')),
#  ('West', 'EOG Resources', Decimal('6.398257')),
#  ('Northeast', 'IBM', Decimal('6.397723')),
#  ('Midwest', 'Abbott Laboratories', Decimal('6.382295')),
#  ('Northeast', 'IBM', Decimal('6.375660')),
#  ('Northeast', '3M', Decimal('6.371196')),
#  ('Northeast', 'Pfizer', Decimal('6.369590')),
#  ('Northeast', 'Pfizer', Decimal('6.368773')),
#  ('Northeast', 'Pfizer', Decimal('6.356293')),
#  ('West', 'Sempra Energy', Decimal('6.355115')),
#  ('Northeast', 'Pfizer', Decimal('6.354321')),
#  ('Northeast', 'IBM', Decimal('6.349250')),
#  ('Midwest', 'International Paper', Decimal('6.348108')),
#  ('West', 'EOG Resources', Decimal('6.347395')),
#  ('Southeast', 'Synnex', Decimal('6.347372')),
#  ('West', 'Crown Holdings', Decimal('6.343901')),
#  ('West', 'Navistar International', Decimal('6.340684')),
#  ('Northeast', 'Pfizer', Decimal('6.338980')),
#  ('Northeast', 'Pfizer', Decimal('6.338901')),
#  ('Southeast', 'Bristol-Myers Squibb', Decimal('6.338579')),
#  ('Midwest', 'Abbott Laboratories', Decimal('6.337014')),
#  ('Midwest', 'Altria Group', Decimal('6.334928')),
#  ('Southeast', 'Bristol-Myers Squibb', Decimal('6.332357')),
#  ('Northeast', '3M', Decimal('6.330595')),
#  ('Northeast', 'World Fuel Services', Decimal('6.328922')),
#  ('Northeast', 'Travelers Cos.', Decimal('6.324650')),
#  ('Northeast', 'Aetna', Decimal('6.323260')),
#  ('West', 'Ally Financial', Decimal('6.323117')),
#  ('Midwest', 'Whirlpool', Decimal('6.321262')),
#  ('West', 'EOG Resources', Decimal('6.320043')),
#  ('Northeast', 'Time Warner', Decimal('6.317876')),
#  ('West', 'Celgene', Decimal('6.316164')),
#  ('West', 'EOG Resources', Decimal('6.312122')),
#  ('Northeast', 'Microsoft', Decimal('6.307081')),
#  ('Southeast', 'Performance Food Group', Decimal('6.306238')),
#  ('Southeast', 'Fluor', Decimal('6.304053')),
#  ('Southeast', 'Occidental Petroleum', Decimal('6.300039')),
#  ('Midwest', 'Community Health Systems', Decimal('6.298087')),
#  ('Northeast', '3M', Decimal('6.296843')),
#  ('West', "Peter Kiewit Sons'", Decimal('6.294896')),
#  ('Northeast', 'IBM', Decimal('6.283355')),
#  ('Northeast', 'Ford Motor', Decimal('6.283316')),
#  ('West', 'Baxter International', Decimal('6.281770')),
#  ('Northeast', 'Caterpillar', Decimal('6.280836')),
#  ('West', 'MasterCard', Decimal('6.278161')),
#  ('West', 'Crown Holdings', Decimal('6.277152')),
#  ('Midwest', 'Community Health Systems', Decimal('6.276288')),
#  ('Midwest', 'Amgen', Decimal('6.275390')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('6.273823')),
#  ('West', 'CST Brands', Decimal('6.272629')),
#  ('Southeast', 'NGL Energy Partners', Decimal('6.272485')),
#  ('Northeast', 'Bank of America Corp.', Decimal('6.272121')),
#  ('West', 'Hormel Foods', Decimal('6.271578')),
#  ('Midwest', 'Abbott Laboratories', Decimal('6.271437')),
#  ('Northeast', 'AT&T', Decimal('6.266068')),
#  ('Northeast', 'IBM', Decimal('6.263764')),
#  ('West', 'Owens & Minor', Decimal('6.261283')),
#  ('West', "Peter Kiewit Sons'", Decimal('6.255647')),
#  ('Midwest', 'Time Warner Cable', Decimal('6.252336')),
#  ('Midwest', 'US Foods Holding', Decimal('6.250357')),
#  ('West', 'MasterCard', Decimal('6.248241')),
#  ('Midwest', 'Abbott Laboratories', Decimal('6.247115')),
#  ('Northeast', 'Bank of America Corp.', Decimal('6.246445')),
#  ('Southeast', 'NGL Energy Partners', Decimal('6.245740')),
#  ('Southeast', 'L Brands', Decimal('6.237244')),
#  ('Midwest', 'Capital One Financial', Decimal('6.236755')),
#  ('Northeast', 'Home Depot', Decimal('6.230713')),
#  ('West', 'PayPal Holdings', Decimal('6.221034')),
#  ('West', 'Ally Financial', Decimal('6.216829')),
#  ('Northeast', 'Honeywell International', Decimal('6.213421')),
#  ('West', 'Assurant', Decimal('6.209788')),
#  ('Northeast', 'Travelers Cos.', Decimal('6.205719')),
#  ('Northeast', 'Travelers Cos.', Decimal('6.200629')),
#  ('Southeast', 'Bristol-Myers Squibb', Decimal('6.200048')),
#  ('Northeast', '3M', Decimal('6.199929')),
#  ('Northeast', 'IBM', Decimal('6.194651')),
#  ('Southeast', 'CenturyLink', Decimal('6.193480')),
#  ('Southeast', 'PNC Financial Services Group', Decimal('6.192424')),
#  ('Midwest', "Kohl's", Decimal('6.190507')),
#  ('West', 'HD Supply Holdings', Decimal('6.190146')),
#  ('Southeast', 'Genuine Parts', Decimal('6.184879')),
#  ('Northeast', 'Pfizer', Decimal('6.184540')),
#  ('Northeast', '3M', Decimal('6.183989')),
#  ('Northeast', 'Procter & Gamble', Decimal('6.183245')),
#  ('Northeast', 'Travelers Cos.', Decimal('6.181639')),
#  ('Southeast', 'Synnex', Decimal('6.179794')),
#  ('Northeast', 'Citigroup', Decimal('6.179003')),
#  ('West', 'EOG Resources', Decimal('6.176164')),
#  ('Northeast', 'Bank of America Corp.', Decimal('6.174696')),
#  ('Midwest', 'Tenet Healthcare', Decimal('6.173701')),
#  ('Southeast', 'NGL Energy Partners', Decimal('6.173324')),
#  ('Northeast', 'Walmart', Decimal('6.168719')),
#  ('Northeast', 'IBM', Decimal('6.166728')),
#  ('Midwest', 'Abbott Laboratories', Decimal('6.164118')),
#  ('West', 'Mosaic', Decimal('6.162033')),
#  ('Southeast', 'United States Steel', Decimal('6.159121')),
#  ('Northeast', '3M', Decimal('6.156417')),
#  ('Southeast', 'Genuine Parts', Decimal('6.154266')),
#  ('Northeast', "Lowe's", Decimal('6.151962')),
#  ('West', 'Mosaic', Decimal('6.151030')),
#  ('Southeast', 'Molina Healthcare', Decimal('6.150524')),
#  ('West', 'Air Products & Chemicals', Decimal('6.147406')),
#  ('Midwest', 'Capital One Financial', Decimal('6.140392')),
#  ('West', 'EOG Resources', Decimal('6.139805')),
#  ('Northeast', 'Bank of America Corp.', Decimal('6.124906')),
#  ('Midwest', 'Abbott Laboratories', Decimal('6.123908')),
#  ('West', 'EOG Resources', Decimal('6.123354')),
#  ('Northeast', 'Pfizer', Decimal('6.120654')),
#  ('Northeast', 'Aetna', Decimal('6.118063')),
#  ('Midwest', 'Abbott Laboratories', Decimal('6.113388')),
#  ('Northeast', 'IBM', Decimal('6.113122')),
#  ('Southeast', 'PG&E Corp.', Decimal('6.111390')),
#  ('Northeast', 'Ingram Micro', Decimal('6.111298')),
#  ('Northeast', 'Walmart', Decimal('6.109804')),
#  ('West', 'EOG Resources', Decimal('6.109292')),
#  ('Northeast', 'Oracle', Decimal('6.107637')),
#  ('Midwest', 'Capital One Financial', Decimal('6.105374')),
#  ('Midwest', 'Tenet Healthcare', Decimal('6.102209')),
#  ('Southeast', 'Bristol-Myers Squibb', Decimal('6.101807')),
#  ('Northeast', 'Deere', Decimal('6.097112')),
#  ('Midwest', 'Halliburton', Decimal('6.093417')),
#  ('Northeast', 'Avnet', Decimal('6.093289')),
#  ('West', 'CST Brands', Decimal('6.089752')),
#  ('Midwest', 'Amgen', Decimal('6.089318')),
#  ('West', 'HD Supply Holdings', Decimal('6.089025')),
#  ('Southeast', 'Bristol-Myers Squibb', Decimal('6.085173')),
#  ('Northeast', 'Pfizer', Decimal('6.084418')),
#  ('Northeast', 'UPS', Decimal('6.083328')),
#  ('Southeast', 'Chesapeake Energy', Decimal('6.079747')),
#  ('Northeast', 'Travelers Cos.', Decimal('6.079458')),
#  ('Southeast', 'Bristol-Myers Squibb', Decimal('6.078131')),
#  ('Northeast', 'Travelers Cos.', Decimal('6.075824')),
#  ('Midwest', 'Time Warner Cable', Decimal('6.074798')),
#  ('Northeast', 'Liberty Mutual Insurance Group', Decimal('6.072035')),
#  ('Southeast', 'FirstEnergy', Decimal('6.071050')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('6.068937')),
#  ('Southeast', 'Occidental Petroleum', Decimal('6.068157')),
#  ('Northeast', 'Alphabet', Decimal('6.065133')),
#  ('Southeast', 'Cognizant Technology Solutions', Decimal('6.063580')),
#  ('Midwest', 'Abbott Laboratories', Decimal('6.062710')),
#  ('Midwest', 'Dollar General', Decimal('6.060797')),
#  ('Southeast', 'Synnex', Decimal('6.060170')),
#  ('Southeast', 'PG&E Corp.', Decimal('6.059286')),
#  ('West', 'EOG Resources', Decimal('6.058861')),
#  ('Midwest', 'Paccar', Decimal('6.058514')),
#  ('Midwest', 'International Paper', Decimal('6.058122')),
#  ('Southeast', 'VF', Decimal('6.054945')),
#  ('Northeast', 'Citigroup', Decimal('6.050384')),
#  ('West', 'EOG Resources', Decimal('6.048861')),
#  ('Southeast', 'Bristol-Myers Squibb', Decimal('6.045741')),
#  ('Northeast', 'IBM', Decimal('6.045142')),
#  ('Northeast', 'Verizon', Decimal('6.044141')),
#  ('Northeast', 'Time Warner', Decimal('6.043314')),
#  ('Midwest', 'Arrow Electronics', Decimal('6.040953')),
#  ('Northeast', 'Pfizer', Decimal('6.037965')),
#  ('Midwest', 'Capital One Financial', Decimal('6.036344')),
#  ('West', 'EOG Resources', Decimal('6.035803')),
#  ('Northeast', 'Walmart', Decimal('6.033417')),
#  ('Northeast', 'Time Warner', Decimal('6.032076')),
#  ('Midwest', 'International Paper', Decimal('6.031240')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('6.030992')),
#  ('Southeast', 'Monsanto', Decimal('6.029554')),
#  ('Northeast', 'Procter & Gamble', Decimal('6.025827')),
#  ('West', 'State Street Corp.', Decimal('6.024459')),
#  ('Northeast', 'Phillips 66', Decimal('6.021696')),
#  ('Northeast', 'Walmart', Decimal('6.019492')),
#  ('Northeast', 'Citigroup', Decimal('6.018041')),
#  ('Southeast', 'Las Vegas Sands', Decimal('6.017459')),
#  ('Southeast', 'Facebook', Decimal('6.017380')),
#  ('Southeast', 'Cognizant Technology Solutions', Decimal('6.016757')),
#  ('Northeast', 'Pfizer', Decimal('6.015732')),
#  ('Northeast', 'Travelers Cos.', Decimal('6.015232')),
#  ('Midwest', 'EMC', Decimal('6.013817')),
#  ('West', 'EOG Resources', Decimal('6.012221')),
#  ('Midwest', 'Whirlpool', Decimal('6.010043')),
#  ('Southeast', 'Bristol-Myers Squibb', Decimal('6.008231')),
#  ('West', 'EOG Resources', Decimal('6.007987')),
#  ('Southeast', 'FirstEnergy', Decimal('6.006917')),
#  ('Midwest', 'Abbott Laboratories', Decimal('6.005982')),
#  ('Northeast', 'Prudential Financial', Decimal('6.003745')),
#  ('Northeast', '3M', Decimal('6.002839')),
#  ('Midwest', 'EMC', Decimal('6.002839')),
#  ('Midwest', 'U.S. Bancorp', Decimal('6.002312')),
#  ('Southeast', 'CSX', Decimal('6.000464')),
#  ('Northeast', 'Ingram Micro', Decimal('6.000140')),
#  ('Northeast', 'IBM', Decimal('5.999124')),
#  ('Northeast', 'Ingram Micro', Decimal('5.999067')),
#  ('Midwest', 'Amgen', Decimal('5.996434')),
#  ('Southeast', 'CenturyLink', Decimal('5.991555')),
#  ('Northeast', '3M', Decimal('5.987706')),
#  ('Northeast', 'IBM', Decimal('5.985797')),
#  ('Northeast', 'Disney', Decimal('5.985675')),
#  ('Midwest', 'AbbVie', Decimal('5.983355')),
#  ('Midwest', 'Altria Group', Decimal('5.978541')),
#  ('Southeast', 'ADP', Decimal('5.978154')),
#  ('Northeast', "Lowe's", Decimal('5.976025')),
#  ('West', 'Reynolds American', Decimal('5.973876')),
#  ('Southeast', 'Bristol-Myers Squibb', Decimal('5.973194')),
#  ('Southeast', 'Baker Hughes', Decimal('5.972981')),
#  ('Southeast', 'Ameriprise Financial', Decimal('5.971716')),
#  ('Northeast', 'Home Depot', Decimal('5.971153')),
#  ('West', 'Eastman Chemical', Decimal('5.970366')),
#  ('Northeast', 'Walmart', Decimal('5.965175')),
#  ('Northeast', 'Alphabet', Decimal('5.964847')),
#  ('Midwest', 'Progressive', Decimal('5.963792')),
#  ('Northeast', 'AT&T', Decimal('5.962569')),
#  ('Northeast', 'Walmart', Decimal('5.960184')),
#  ('Southeast', "Land O'Lakes", Decimal('5.960155')),
#  ('Southeast', 'Monsanto', Decimal('5.959970')),
#  ('West', 'Hilton Worldwide Holdings', Decimal('5.959148')),
#  ('Northeast', 'State Farm Insurance Cos.', Decimal('5.955916')),
#  ('West', 'EOG Resources', Decimal('5.955263')),
#  ('Northeast', 'IBM', Decimal('5.955003')),
#  ('West', 'HD Supply Holdings', Decimal('5.951930')),
#  ('Southeast', 'Fluor', Decimal('5.949199')),
#  ('Southeast', 'PBF Energy', Decimal('5.946536')),
#  ('West', 'BB&T Corp.', Decimal('5.943131')),
#  ('West', 'D.R. Horton', Decimal('5.942566')),
#  ('Northeast', 'Sysco', Decimal('5.941700')),
#  ('West', 'EOG Resources', Decimal('5.940250')),
#  ('Southeast', 'Devon Energy', Decimal('5.939165')),
#  ('Southeast', 'Synnex', Decimal('5.939052')),
#  ('Midwest', 'Time Warner Cable', Decimal('5.937330')),
#  ('West', 'EOG Resources', Decimal('5.935361')),
#  ('Southeast', 'Health Net', Decimal('5.934457')),
#  ('West', 'EOG Resources', Decimal('5.933930')),
#  ('Southeast', 'Leucadia National', Decimal('5.933527')),
#  ('Northeast', 'Bank of America Corp.', Decimal('5.931267')),
#  ('Southeast', 'NGL Energy Partners', Decimal('5.928199')),
#  ('Southeast', 'Parker-Hannifin', Decimal('5.927546')),
#  ('Midwest', 'Paccar', Decimal('5.927284')),
#  ('West', 'EOG Resources', Decimal('5.925818')),
#  ('Southeast', 'Leucadia National', Decimal('5.924470')),
#  ('Southeast', 'Western Digital', Decimal('5.924160')),
#  ('Midwest', 'Sears Holdings', Decimal('5.921463')),
#  ('West', 'Celgene', Decimal('5.919836')),
#  ('Northeast', 'Citigroup', Decimal('5.919668')),
#  ('Northeast', 'IBM', Decimal('5.918550')),
#  ('Northeast', 'Pfizer', Decimal('5.917287')),
#  ('Midwest', 'Centene', Decimal('5.916138')),
#  ('Northeast', 'Ford Motor', Decimal('5.911658')),
#  ('Southeast', 'Western Digital', Decimal('5.907654')),
#  ('Southeast', 'Synnex', Decimal('5.905947')),
#  ('Southeast', 'National Oilwell Varco', Decimal('5.905172')),
#  ('Southeast', 'Synnex', Decimal('5.903140')),
#  ('Southeast', 'Bristol-Myers Squibb', Decimal('5.902476')),
#  ('Southeast', 'Dollar Tree', Decimal('5.899769')),
#  ('Southeast', 'Genuine Parts', Decimal('5.898914')),
#  ('Southeast', 'NGL Energy Partners', Decimal('5.898321')),
#  ('West', 'Crown Holdings', Decimal('5.897715')),
#  ('Southeast', 'Fluor', Decimal('5.896255')),
#  ('Northeast', 'Bank of America Corp.', Decimal('5.892090')),
#  ('Northeast', 'Citigroup', Decimal('5.890765')),
#  ('Southeast', 'Illinois Tool Works', Decimal('5.890160')),
#  ('Northeast', '3M', Decimal('5.888425')),
#  ('Northeast', 'Exelon', Decimal('5.888153')),
#  ('Southeast', 'Principal Financial', Decimal('5.875875')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.869531')),
#  ('West', 'State Street Corp.', Decimal('5.868867')),
#  ('Southeast', 'CarMax', Decimal('5.866256')),
#  ('Northeast', 'IBM', Decimal('5.862565')),
#  ('Midwest', 'AutoNation', Decimal('5.862418')),
#  ('Southeast', "Land O'Lakes", Decimal('5.861503')),
#  ('Northeast', 'Ingram Micro', Decimal('5.859667')),
#  ('Midwest', 'Time Warner Cable', Decimal('5.858069')),
#  ('Northeast', 'Allstate', Decimal('5.857306')),
#  ('Southeast', 'Nordstrom', Decimal('5.857152')),
#  ('Northeast', 'Gilead Sciences', Decimal('5.855053')),
#  ('Southeast', 'Leucadia National', Decimal('5.852970')),
#  ('West', 'EOG Resources', Decimal('5.852769')),
#  ('West', 'Charter Communications', Decimal('5.851771')),
#  ('Midwest', 'Sears Holdings', Decimal('5.851001')),
#  ('Northeast', 'Time Warner', Decimal('5.846530')),
#  ('Southeast', 'Cognizant Technology Solutions', Decimal('5.845144')),
#  ('Southeast', 'Thermo Fisher Scientific', Decimal('5.844885')),
#  ('Southeast', 'United States Steel', Decimal('5.844669')),
#  ('Southeast', 'Ecolab', Decimal('5.842741')),
#  ('Southeast', 'Fluor', Decimal('5.839076')),
#  ('West', 'Norfolk Southern', Decimal('5.838448')),
#  ('West', 'Precision Castparts', Decimal('5.837428')),
#  ('West', 'Republic Services', Decimal('5.833185')),
#  ('West', 'Advance Auto Parts', Decimal('5.832539')),
#  ('Southeast', 'Bristol-Myers Squibb', Decimal('5.830304')),
#  ('Southeast', 'Guardian Life Ins. Co. of America', Decimal('5.829729')),
#  ('West', 'EOG Resources', Decimal('5.826773')),
#  ('Northeast', 'Sysco', Decimal('5.824165')),
#  ('Northeast', 'Twenty-First Century Fox', Decimal('5.823042')),
#  ('West', 'Crown Holdings', Decimal('5.822977')),
#  ('Midwest', 'Union Pacific', Decimal('5.815923')),
#  ('Southeast', 'Occidental Petroleum', Decimal('5.810749')),
#  ('Southeast', 'HollyFrontier', Decimal('5.809050')),
#  ('Northeast', 'Exelon', Decimal('5.808773')),
#  ('Southeast', 'Chesapeake Energy', Decimal('5.808229')),
#  ('Northeast', 'Best Buy', Decimal('5.806723')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.806431')),
#  ('Southeast', 'CDW', Decimal('5.803919')),
#  ('Southeast', 'Western Digital', Decimal('5.801731')),
#  ('Midwest', 'Centene', Decimal('5.801333')),
#  ('Southeast', 'Cognizant Technology Solutions', Decimal('5.800718')),
#  ('Northeast', 'Honeywell International', Decimal('5.799685')),
#  ('West', 'Western Refining', Decimal('5.796991')),
#  ('Southeast', 'Fluor', Decimal('5.791319')),
#  ('Northeast', 'Intel', Decimal('5.788183')),
#  ('Southeast', 'PBF Energy', Decimal('5.787559')),
#  ('Northeast', 'Amazon.com', Decimal('5.786983')),
#  ('Midwest', 'Southwest Airlines', Decimal('5.786727')),
#  ('Northeast', 'Best Buy', Decimal('5.783623')),
#  ('West', 'AutoZone', Decimal('5.783143')),
#  ('Northeast', 'Target', Decimal('5.782979')),
#  ('Northeast', 'Best Buy', Decimal('5.782823')),
#  ('Northeast', 'Twenty-First Century Fox', Decimal('5.782342')),
#  ('Northeast', 'AT&T', Decimal('5.780112')),
#  ('Midwest', 'Paccar', Decimal('5.778705')),
#  ('West', 'EOG Resources', Decimal('5.778206')),
#  ('Southeast', 'Bristol-Myers Squibb', Decimal('5.777570')),
#  ('Northeast', 'United Technologies', Decimal('5.776712')),
#  ('Northeast', 'General Dynamics', Decimal('5.775077')),
#  ('Midwest', 'Southwest Airlines', Decimal('5.772775')),
#  ('Northeast', 'AT&T', Decimal('5.772063')),
#  ('Northeast', 'General Dynamics', Decimal('5.771505')),
#  ('Northeast', 'Disney', Decimal('5.770516')),
#  ('Southeast', 'Fluor', Decimal('5.769759')),
#  ('Northeast', 'FedEx', Decimal('5.765981')),
#  ('Southeast', 'Leucadia National', Decimal('5.765599')),
#  ('Midwest', 'AutoNation', Decimal('5.764127')),
#  ('Midwest', "McDonald's", Decimal('5.761834')),
#  ('Southeast', 'Bristol-Myers Squibb', Decimal('5.761073')),
#  ('Northeast', 'Target', Decimal('5.758809')),
#  ('West', 'Jarden', Decimal('5.757972')),
#  ('Southeast', 'Guardian Life Ins. Co. of America', Decimal('5.757329')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.756604')),
#  ('Northeast', '3M', Decimal('5.755681')),
#  ('West', 'D.R. Horton', Decimal('5.754828')),
#  ('Southeast', 'Supervalu', Decimal('5.753700')),
#  ('Northeast', 'Caterpillar', Decimal('5.751071')),
#  ('Northeast', 'Honeywell International', Decimal('5.749764')),
#  ('Midwest', 'Lear', Decimal('5.749436')),
#  ('West', 'Air Products & Chemicals', Decimal('5.746288')),
#  ('Northeast', 'Procter & Gamble', Decimal('5.745938')),
#  ('Midwest', 'Centene', Decimal('5.745594')),
#  ('Northeast', 'Aetna', Decimal('5.743465')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.736731')),
#  ('West', 'BB&T Corp.', Decimal('5.734167')),
#  ('Southeast', 'Goodyear Tire & Rubber', Decimal('5.733232')),
#  ('Midwest', 'Union Pacific', Decimal('5.730961')),
#  ('Northeast', 'Cigna', Decimal('5.730371')),
#  ('Southeast', 'Illinois Tool Works', Decimal('5.728919')),
#  ('Northeast', 'IBM', Decimal('5.726050')),
#  ('Northeast', 'Valero Energy', Decimal('5.724540')),
#  ('Northeast', 'Ford Motor', Decimal('5.723279')),
#  ('Northeast', 'IBM', Decimal('5.722612')),
#  ('Southeast', 'Jacobs Engineering Group', Decimal('5.722158')),
#  ('Northeast', 'IBM', Decimal('5.721231')),
#  ('Northeast', 'Ford Motor', Decimal('5.720084')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.719979')),
#  ('Southeast', 'Fluor', Decimal('5.719007')),
#  ('Southeast', 'PNC Financial Services Group', Decimal('5.718974')),
#  ('Southeast', 'Leucadia National', Decimal('5.718059')),
#  ('Northeast', 'Avnet', Decimal('5.718005')),
#  ('West', 'Celgene', Decimal('5.714981')),
#  ('Southeast', 'Texas Instruments', Decimal('5.714805')),
#  ('West', 'Anadarko Petroleum', Decimal('5.714119')),
#  ('Southeast', 'CDW', Decimal('5.714017')),
#  ('Northeast', 'McKesson', Decimal('5.713830')),
#  ('West', 'State Street Corp.', Decimal('5.712669')),
#  ('West', 'Hilton Worldwide Holdings', Decimal('5.711635')),
#  ('Midwest', 'AutoNation', Decimal('5.711517')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.707946')),
#  ('Northeast', 'Wells Fargo', Decimal('5.703632')),
#  ('West', 'Navistar International', Decimal('5.698409')),
#  ('Northeast', 'Freddie Mac', Decimal('5.696883')),
#  ('Northeast', 'Twenty-First Century Fox', Decimal('5.695148')),
#  ('Southeast', 'First Data', Decimal('5.694503')),
#  ('Northeast', 'Phillips 66', Decimal('5.694459')),
#  ('Southeast', "Toys 'R' Us", Decimal('5.691988')),
#  ('Southeast', 'Icahn Enterprises', Decimal('5.689341')),
#  ('Southeast', 'Guardian Life Ins. Co. of America', Decimal('5.688580')),
#  ('Midwest', 'Paccar', Decimal('5.687137')),
#  ('Northeast', 'Freddie Mac', Decimal('5.686652')),
#  ('Southeast', 'Thermo Fisher Scientific', Decimal('5.685904')),
#  ('Northeast', 'Twenty-First Century Fox', Decimal('5.685397')),
#  ('Midwest', 'Southwest Airlines', Decimal('5.685340')),
#  ('West', 'Owens & Minor', Decimal('5.683488')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.682705')),
#  ('West', 'State Street Corp.', Decimal('5.678745')),
#  ('Midwest', 'Northrop Grumman', Decimal('5.677180')),
#  ('Northeast', 'Prudential Financial', Decimal('5.676905')),
#  ('West', 'Hilton Worldwide Holdings', Decimal('5.675657')),
#  ('Midwest', 'AbbVie', Decimal('5.674244')),
#  ('Northeast', 'Sysco', Decimal('5.670820')),
#  ('Southeast', 'Kellogg', Decimal('5.667999')),
#  ('Northeast', 'Phillips 66', Decimal('5.667840')),
#  ('Northeast', 'United Continental Holdings', Decimal('5.666104')),
#  ('Southeast', 'Bristol-Myers Squibb', Decimal('5.665627')),
#  ('Midwest', 'Progressive', Decimal('5.664255')),
#  ('Northeast', 'Tyson Foods', Decimal('5.663775')),
#  ('West', 'AutoZone', Decimal('5.663072')),
#  ('West', 'Republic Services', Decimal('5.662778')),
#  ('Southeast', 'Fluor', Decimal('5.662625')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.661640')),
#  ('Southeast', 'Guardian Life Ins. Co. of America', Decimal('5.656358')),
#  ('Northeast', 'United Technologies', Decimal('5.656249')),
#  ('Northeast', 'Verizon', Decimal('5.656130')),
#  ('Northeast', 'Pfizer', Decimal('5.655206')),
#  ('Northeast', 'Twenty-First Century Fox', Decimal('5.653079')),
#  ('Southeast', 'Supervalu', Decimal('5.652329')),
#  ('Northeast', 'United Technologies', Decimal('5.652020')),
#  ('West', 'Hormel Foods', Decimal('5.651095')),
#  ('West', 'Jarden', Decimal('5.650454')),
#  ('Northeast', 'Sysco', Decimal('5.641460')),
#  ('Southeast', 'Supervalu', Decimal('5.641298')),
#  ('West', 'Charter Communications', Decimal('5.640702')),
#  ('Midwest', 'Raytheon', Decimal('5.640051')),
#  ('West', 'State Street Corp.', Decimal('5.639676')),
#  ('Southeast', "Toys 'R' Us", Decimal('5.638937')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.638831')),
#  ('Northeast', 'Intel', Decimal('5.635751')),
#  ('Northeast', 'General Dynamics', Decimal('5.634608')),
#  ('Northeast', 'Intel', Decimal('5.634015')),
#  ('Northeast', 'Target', Decimal('5.632564')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.631321')),
#  ('Southeast', 'HollyFrontier', Decimal('5.630381')),
#  ('Southeast', 'NGL Energy Partners', Decimal('5.628393')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.628020')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.623648')),
#  ('Southeast', 'Textron', Decimal('5.622030')),
#  ('Northeast', 'Sysco', Decimal('5.621962')),
#  ('Southeast', 'Western Digital', Decimal('5.621762')),
#  ('Midwest', 'Qualcomm', Decimal('5.619908')),
#  ('Northeast', 'Wells Fargo', Decimal('5.619837')),
#  ('Southeast', 'Icahn Enterprises', Decimal('5.617005')),
#  ('West', 'Hilton Worldwide Holdings', Decimal('5.615688')),
#  ('Northeast', 'Microsoft', Decimal('5.615670')),
#  ('Southeast', 'Icahn Enterprises', Decimal('5.615311')),
#  ('Southeast', 'CarMax', Decimal('5.613810')),
#  ('Midwest', 'Qualcomm', Decimal('5.612945')),
#  ('Northeast', 'Twenty-First Century Fox', Decimal('5.612541')),
#  ('Northeast', 'United Technologies', Decimal('5.612459')),
#  ('Midwest', 'Altria Group', Decimal('5.608945')),
#  ('West', 'Republic Services', Decimal('5.607655')),
#  ('Midwest', 'Emerson Electric', Decimal('5.607096')),
#  ('Northeast', 'General Electric', Decimal('5.602701')),
#  ('Southeast', 'Jabil Circuit', Decimal('5.602157')),
#  ('Southeast', 'Dominion Resources', Decimal('5.601839')),
#  ('West', 'Becton Dickinson', Decimal('5.599497')),
#  ('West', 'Jarden', Decimal('5.598920')),
#  ('Southeast', 'PBF Energy', Decimal('5.595445')),
#  ('Southeast', 'FirstEnergy', Decimal('5.594313')),
#  ('Northeast', 'Freddie Mac', Decimal('5.593895')),
#  ('Northeast', 'United Technologies', Decimal('5.593232')),
#  ('Southeast', 'Illinois Tool Works', Decimal('5.592401')),
#  ('Southeast', 'Icahn Enterprises', Decimal('5.590513')),
#  ('Northeast', 'Prudential Financial', Decimal('5.590333')),
#  ('Northeast', 'Aetna', Decimal('5.589544')),
#  ('Southeast', 'Kellogg', Decimal('5.589487')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.588439')),
#  ('Southeast', 'Western Digital', Decimal('5.586561')),
#  ('Southeast', 'Nordstrom', Decimal('5.585437')),
#  ('Northeast', 'Sysco', Decimal('5.583084')),
#  ('Midwest', 'Aflac', Decimal('5.582659')),
#  ('Southeast', 'PNC Financial Services Group', Decimal('5.582456')),
#  ('Midwest', 'Kraft Heinz', Decimal('5.581549')),
#  ('Northeast', 'Freddie Mac', Decimal('5.581027')),
#  ('Northeast', 'Freddie Mac', Decimal('5.578601')),
#  ('Southeast', 'Jacobs Engineering Group', Decimal('5.576281')),
#  ('West', 'State Street Corp.', Decimal('5.575726')),
#  ('West', 'Fidelity National Financial', Decimal('5.575419')),
#  ('Northeast', 'United Technologies', Decimal('5.572584')),
#  ('Southeast', 'Ecolab', Decimal('5.570713')),
#  ('Midwest', 'USAA', Decimal('5.570437')),
#  ('Midwest', 'Sears Holdings', Decimal('5.569686')),
#  ('Northeast', 'Prudential Financial', Decimal('5.569645')),
#  ('Southeast', 'Supervalu', Decimal('5.568782')),
#  ('West', 'Hormel Foods', Decimal('5.567971')),
#  ('West', 'Jarden', Decimal('5.567645')),
#  ('Northeast', 'Ford Motor', Decimal('5.567637')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.567313')),
#  ('Southeast', 'Leucadia National', Decimal('5.565973')),
#  ('Northeast', 'Nationwide', Decimal('5.565393')),
#  ('Southeast', 'Thermo Fisher Scientific', Decimal('5.565260')),
#  ('West', 'Autoliv', Decimal('5.564753')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.563952')),
#  ('Midwest', 'Duke Energy', Decimal('5.563548')),
#  ('Northeast', 'Target', Decimal('5.562266')),
#  ('Southeast', 'United States Steel', Decimal('5.562127')),
#  ('Southeast', 'Ecolab', Decimal('5.560885')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.560549')),
#  ('Southeast', 'Leucadia National', Decimal('5.559282')),
#  ('Midwest', 'AutoNation', Decimal('5.559171')),
#  ('West', 'Univar', Decimal('5.558185')),
#  ('Northeast', 'Target', Decimal('5.557886')),
#  ('West', 'Mosaic', Decimal('5.557627')),
#  ('Northeast', 'Amazon.com', Decimal('5.557375')),
#  ('Northeast', 'TJX', Decimal('5.557124')),
#  ('Northeast', 'Freddie Mac', Decimal('5.556686')),
#  ('West', 'Public Service Enterprise Group', Decimal('5.556686')),
#  ('West', 'Republic Services', Decimal('5.556373')),
#  ('Southeast', 'ConAgra Foods', Decimal('5.556319')),
#  ('Midwest', 'Raytheon', Decimal('5.552281')),
#  ('Northeast', 'Verizon', Decimal('5.551963')),
#  ('Northeast', 'United Technologies', Decimal('5.550095')),
#  ('Northeast', 'CHS', Decimal('5.549276')),
#  ('Northeast', 'General Dynamics', Decimal('5.548950')),
#  ('Northeast', 'Alphabet', Decimal('5.548505')),
#  ('Midwest', 'Centene', Decimal('5.548323')),
#  ('Southeast', 'Ameriprise Financial', Decimal('5.548004')),
#  ('Northeast', 'United Technologies', Decimal('5.546795')),
#  ('Northeast', 'Tyson Foods', Decimal('5.545024')),
#  ('Northeast', 'Sysco', Decimal('5.544690')),
#  ('Northeast', 'Boeing', Decimal('5.542594')),
#  ('Northeast', 'Philip Morris International', Decimal('5.541305')),
#  ('West', 'Becton Dickinson', Decimal('5.540039')),
#  ('West', 'Discover Financial Services', Decimal('5.539958')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.539121')),
#  ('Southeast', 'Jabil Circuit', Decimal('5.536212')),
#  ('Northeast', 'Sysco', Decimal('5.536149')),
#  ('Midwest', 'Emerson Electric', Decimal('5.535622')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.535464')),
#  ('West', 'Mosaic', Decimal('5.534283')),
#  ('Northeast', 'Citigroup', Decimal('5.534252')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.534160')),
#  ('Northeast', 'Sysco', Decimal('5.533211')),
#  ('Northeast', 'Valero Energy', Decimal('5.532925')),
#  ('Southeast', 'United States Steel', Decimal('5.532228')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.529445')),
#  ('Southeast', 'Western Digital', Decimal('5.529229')),
#  ('Southeast', 'United States Steel', Decimal('5.529225')),
#  ('Southeast', 'Goodyear Tire & Rubber', Decimal('5.527460')),
#  ('Southeast', 'Synnex', Decimal('5.527330')),
#  ('Midwest', 'Centene', Decimal('5.525013')),
#  ('Southeast', 'CarMax', Decimal('5.524063')),
#  ('Midwest', 'AutoNation', Decimal('5.523495')),
#  ('West', 'Becton Dickinson', Decimal('5.522618')),
#  ('Southeast', 'National Oilwell Varco', Decimal('5.521617')),
#  ('West', 'Jarden', Decimal('5.521572')),
#  ('Northeast', 'Intel', Decimal('5.521306')),
#  ('Northeast', 'Enterprise Products Partners', Decimal('5.519986')),
#  ('Midwest', 'Abbott Laboratories', Decimal('5.519917')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.519879')),
#  ('West', 'D.R. Horton', Decimal('5.519802')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.519363')),
#  ('West', 'Republic Services', Decimal('5.519270')),
#  ('Southeast', 'FirstEnergy', Decimal('5.519128')),
#  ('Midwest', 'Duke Energy', Decimal('5.518302')),
#  ('Midwest', 'Sears Holdings', Decimal('5.517194')),
#  ('Northeast', 'Aetna', Decimal('5.516690')),
#  ('Northeast', 'United Technologies', Decimal('5.516430')),
#  ('West', 'Republic Services', Decimal('5.515433')),
#  ('Northeast', 'United Technologies', Decimal('5.515317')),
#  ('Northeast', 'Freddie Mac', Decimal('5.515093')),
#  ('Southeast', 'Lincoln National', Decimal('5.512922')),
#  ('Southeast', 'Thermo Fisher Scientific', Decimal('5.512893')),
#  ('Northeast', 'Ford Motor', Decimal('5.511822')),
#  ('Northeast', 'Freddie Mac', Decimal('5.511086')),
#  ('Northeast', 'General Dynamics', Decimal('5.510836')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.510095')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.509803')),
#  ('Northeast', 'Wells Fargo', Decimal('5.508945')),
#  ('Southeast', 'Western Digital', Decimal('5.508926')),
#  ('Northeast', 'General Dynamics', Decimal('5.508301')),
#  ('West', 'Jarden', Decimal('5.507753')),
#  ('Southeast', 'Thermo Fisher Scientific', Decimal('5.507476')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.506972')),
#  ('Northeast', 'ConocoPhillips', Decimal('5.506903')),
#  ('Southeast', 'Supervalu', Decimal('5.506644')),
#  ('West', 'Mosaic', Decimal('5.506418')),
#  ('Northeast', 'Wells Fargo', Decimal('5.505888')),
#  ('Southeast', 'Synnex', Decimal('5.504096')),
#  ('Northeast', 'TJX', Decimal('5.503800')),
#  ('Southeast', 'Western Digital', Decimal('5.503615')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.502939')),
#  ('Midwest', 'Emerson Electric', Decimal('5.502613')),
#  ('Southeast', 'National Oilwell Varco', Decimal('5.502103')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.501737')),
#  ('Northeast', 'Costco', Decimal('5.501370')),
#  ('Northeast', 'Phillips 66', Decimal('5.500340')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.499905')),
#  ('Northeast', 'Wells Fargo', Decimal('5.498593')),
#  ('Northeast', 'Freddie Mac', Decimal('5.498465')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.497648')),
#  ('Southeast', 'First Data', Decimal('5.496460')),
#  ('Northeast', 'Citigroup', Decimal('5.496349')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.495697')),
#  ('Northeast', 'General Dynamics', Decimal('5.495411')),
#  ('Northeast', 'Phillips 66', Decimal('5.494946')),
#  ('West', 'D.R. Horton', Decimal('5.494482')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.494095')),
#  ('Southeast', 'Guardian Life Ins. Co. of America', Decimal('5.493581')),
#  ('Northeast', 'Aetna', Decimal('5.492848')),
#  ('Southeast', "Land O'Lakes", Decimal('5.492266')),
#  ('Southeast', 'ADP', Decimal('5.491498')),
#  ('Northeast', 'Intel', Decimal('5.491346')),
#  ('Northeast', 'Prudential Financial', Decimal('5.490795')),
#  ('Northeast', 'Aetna', Decimal('5.488385')),
#  ('Northeast', 'Aetna', Decimal('5.486671')),
#  ('Northeast', 'American Airlines Group', Decimal('5.486626')),
#  ('Midwest', 'Emerson Electric', Decimal('5.486162')),
#  ('Southeast', 'Supervalu', Decimal('5.485992')),
#  ('Southeast', 'Nucor', Decimal('5.485892')),
#  ('Northeast', 'Berkshire Hathaway', Decimal('5.483687')),
#  ('Southeast', 'Leucadia National', Decimal('5.483158')),
#  ('Southeast', 'CDW', Decimal('5.482412')),
#  ('Northeast', 'Honeywell International', Decimal('5.480494')),
#  ('Northeast', 'Verizon', Decimal('5.480068')),
#  ('West', 'Mosaic', Decimal('5.479932')),
#  ('Southeast', 'Kinder Morgan', Decimal('5.479083')),
#  ('Northeast', 'Enterprise Products Partners', Decimal('5.478273')),
#  ('Southeast', 'Computer Sciences', Decimal('5.476977')),
#  ('Southeast', 'DaVita HealthCare Partners', Decimal('5.476468')),
#  ('Northeast', 'Cigna', Decimal('5.475462')),
#  ('West', 'Anadarko Petroleum', Decimal('5.475397')),
#  ('West', 'W.W. Grainger', Decimal('5.475341')),
#  ('Northeast', 'Wells Fargo', Decimal('5.474829')),
#  ('Southeast', 'Textron', Decimal('5.473985')),
#  ('Northeast', 'Sysco', Decimal('5.473661')),
#  ('Midwest', 'Alcoa', Decimal('5.473489')),
#  ('West', 'Anadarko Petroleum', Decimal('5.473470')),
#  ('Southeast', 'Illinois Tool Works', Decimal('5.472178')),
#  ('Southeast', 'Leucadia National', Decimal('5.471818')),
#  ('West', 'Mosaic', Decimal('5.471588')),
#  ('Southeast', 'CDW', Decimal('5.471565')),
#  ('Southeast', 'Ecolab', Decimal('5.471191')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.469324')),
#  ('Midwest', 'Southwest Airlines', Decimal('5.468611')),
#  ('Northeast', 'Ford Motor', Decimal('5.468120')),
#  ('Northeast', 'Valero Energy', Decimal('5.467744')),
#  ('Northeast', 'Intel', Decimal('5.464886')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.462353')),
#  ('Southeast', 'FirstEnergy', Decimal('5.462148')),
#  ('West', 'Republic Services', Decimal('5.461977')),
#  ('Northeast', 'Amazon.com', Decimal('5.461857')),
#  ('West', 'Western Refining', Decimal('5.461673')),
#  ('Northeast', 'FedEx', Decimal('5.461192')),
#  ('West', 'Hormel Foods', Decimal('5.460709')),
#  ('Northeast', 'Citigroup', Decimal('5.460688')),
#  ('Southeast', 'Supervalu', Decimal('5.459020')),
#  ('Northeast', 'Sysco', Decimal('5.458567')),
#  ('Southeast', 'Dominion Resources', Decimal('5.458358')),
#  ('Midwest', 'Sears Holdings', Decimal('5.458286')),
#  ('Midwest', 'Centene', Decimal('5.457090')),
#  ('West', 'Celgene', Decimal('5.456827')),
#  ('Southeast', 'CDW', Decimal('5.455881')),
#  ('West', 'Global Partners', Decimal('5.453343')),
#  ('Northeast', 'Chevron', Decimal('5.452700')),
#  ('West', 'Hormel Foods', Decimal('5.451480')),
#  ('Southeast', 'United States Steel', Decimal('5.449038')),
#  ('Northeast', 'Aetna', Decimal('5.448252')),
#  ('Southeast', 'United States Steel', Decimal('5.446077')),
#  ('West', 'PayPal Holdings', Decimal('5.445747')),
#  ('West', 'Sempra Energy', Decimal('5.445374')),
#  ('Northeast', 'Comcast', Decimal('5.445104')),
#  ('Southeast', 'Fluor', Decimal('5.444031')),
#  ('Southeast', 'DISH Network', Decimal('5.443749')),
#  ('Northeast', 'Sysco', Decimal('5.443744')),
#  ('Northeast', 'Phillips 66', Decimal('5.442996')),
#  ('Southeast', 'United States Steel', Decimal('5.442829')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.442049')),
#  ('West', 'Republic Services', Decimal('5.441420')),
#  ('Northeast', 'Wells Fargo', Decimal('5.441204')),
#  ('Northeast', 'General Dynamics', Decimal('5.438529')),
#  ('Southeast', 'Jabil Circuit', Decimal('5.438291')),
#  ('Southeast', 'Western Digital', Decimal('5.437866')),
#  ('Midwest', 'Kraft Heinz', Decimal('5.437828')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.437167')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.436645')),
#  ('Southeast', 'PPG Industries', Decimal('5.436184')),
#  ('West', 'Liberty Interactive', Decimal('5.436113')),
#  ('Southeast', 'BlackRock', Decimal('5.435965')),
#  ('Northeast', 'Phillips 66', Decimal('5.433102')),
#  ('West', 'Hilton Worldwide Holdings', Decimal('5.432176')),
#  ('West', 'Advance Auto Parts', Decimal('5.432129')),
#  ('Southeast', 'Supervalu', Decimal('5.431007')),
#  ('Northeast', 'Freddie Mac', Decimal('5.430275')),
#  ('Southeast', 'American Electric Power', Decimal('5.430177')),
#  ('Northeast', 'Wells Fargo', Decimal('5.427258')),
#  ('Southeast', 'Colgate-Palmolive', Decimal('5.423938')),
#  ('Northeast', 'Coca-Cola', Decimal('5.423158')),
#  ('West', 'Mosaic', Decimal('5.421594')),
#  ('Southeast', 'Goodyear Tire & Rubber', Decimal('5.420927')),
#  ('Northeast', 'Intel', Decimal('5.419707')),
#  ('Southeast', 'United States Steel', Decimal('5.418695')),
#  ('West', 'State Street Corp.', Decimal('5.417586')),
#  ('Midwest', 'Cummins', Decimal('5.415961')),
#  ('Southeast', 'Marsh & McLennan', Decimal('5.415877')),
#  ('Midwest', 'Centene', Decimal('5.415311')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.415237')),
#  ('Northeast', 'United Technologies', Decimal('5.415217')),
#  ('West', 'Core-Mark Holding', Decimal('5.414891')),
#  ('Midwest', 'AutoNation', Decimal('5.414751')),
#  ('Southeast', 'Goodyear Tire & Rubber', Decimal('5.412267')),
#  ('West', 'Henry Schein', Decimal('5.411144')),
#  ('Northeast', "Lowe's", Decimal('5.410306')),
#  ('Midwest', 'Centene', Decimal('5.409534')),
#  ('Southeast', 'BlackRock', Decimal('5.408915')),
#  ('West', 'Thrivent Financial for Lutherans', Decimal('5.408913')),
#  ('Southeast', 'Leucadia National', Decimal('5.407772')),
#  ('Southeast', 'ADP', Decimal('5.406828')),
#  ('West', 'Discover Financial Services', Decimal('5.405908')),
#  ('Southeast', 'United States Steel', Decimal('5.405665')),
#  ('Midwest', 'Emerson Electric', Decimal('5.405588')),
#  ('Southeast', 'ADP', Decimal('5.405471')),
#  ('West', 'Biogen', Decimal('5.404484')),
#  ('Northeast', 'Disney', Decimal('5.403969')),
#  ('Northeast', 'Sysco', Decimal('5.402774')),
#  ('West', 'Biogen', Decimal('5.401641')),
#  ('Northeast', 'United Technologies', Decimal('5.400681')),
#  ('Midwest', 'Southwest Airlines', Decimal('5.398693')),
#  ('Northeast', 'Merck', Decimal('5.398362')),
#  ('Southeast', 'Supervalu', Decimal('5.398114')),
#  ('Southeast', 'United States Steel', Decimal('5.396576')),
#  ('Southeast', 'NRG Energy', Decimal('5.396228')),
#  ('Northeast', 'Amazon.com', Decimal('5.395732')),
#  ('West', 'R.R. Donnelley & Sons', Decimal('5.394343')),
#  ('Southeast', 'Monsanto', Decimal('5.392332')),
#  ('Southeast', "Land O'Lakes", Decimal('5.391193')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.391092')),
#  ('Southeast', 'Fluor', Decimal('5.390249')),
#  ('Southeast', 'Dominion Resources', Decimal('5.390192')),
#  ('Southeast', 'Kellogg', Decimal('5.388562')),
#  ('Southeast', 'Nucor', Decimal('5.388062')),
#  ('Northeast', 'Phillips 66', Decimal('5.387994')),
#  ('Southeast', 'Thermo Fisher Scientific', Decimal('5.387800')),
#  ('West', 'Republic Services', Decimal('5.387310')),
#  ('Southeast', 'Thermo Fisher Scientific', Decimal('5.387129')),
#  ('Southeast', 'Jabil Circuit', Decimal('5.385561')),
#  ('Midwest', 'Duke Energy', Decimal('5.383110')),
#  ('Southeast', 'Colgate-Palmolive', Decimal('5.382385')),
#  ('Northeast', 'Target', Decimal('5.382257')),
#  ('Southeast', 'BlackRock', Decimal('5.382070')),
#  ('Southeast', 'Western Digital', Decimal('5.379961')),
#  ('Northeast', 'General Dynamics', Decimal('5.378588')),
#  ('Southeast', 'Health Net', Decimal('5.377892')),
#  ('Northeast', 'General Dynamics', Decimal('5.377541')),
#  ('Southeast', 'Performance Food Group', Decimal('5.377088')),
#  ('Northeast', 'State Farm Insurance Cos.', Decimal('5.374616')),
#  ('Midwest', 'Raytheon', Decimal('5.371536')),
#  ('West', 'Unum Group', Decimal('5.371478')),
#  ('West', 'Mosaic', Decimal('5.371301')),
#  ('Southeast', 'Kellogg', Decimal('5.370701')),
#  ('Southeast', 'Performance Food Group', Decimal('5.370258')),
#  ('Northeast', 'Energy Transfer Equity', Decimal('5.369516')),
#  ('Southeast', 'Jacobs Engineering Group', Decimal('5.369231')),
#  ('Southeast', 'CDW', Decimal('5.369111')),
#  ('Northeast', 'Freddie Mac', Decimal('5.367853')),
#  ('West', 'Hormel Foods', Decimal('5.367807')),
#  ('Southeast', 'Goodyear Tire & Rubber', Decimal('5.367591')),
#  ('Northeast', 'Cisco Systems', Decimal('5.366839')),
#  ('Southeast', 'Entergy', Decimal('5.366772')),
#  ('Midwest', 'Emerson Electric', Decimal('5.365919')),
#  ('West', 'Charter Communications', Decimal('5.364147')),
#  ('West', 'R.R. Donnelley & Sons', Decimal('5.361952')),
#  ('West', 'Charter Communications', Decimal('5.361681')),
#  ('Southeast', 'BlackRock', Decimal('5.361535')),
#  ('Northeast', 'FedEx', Decimal('5.358938')),
#  ('Northeast', 'Citigroup', Decimal('5.358370')),
#  ('Northeast', 'Phillips 66', Decimal('5.358127')),
#  ('Northeast', 'Travelers Cos.', Decimal('5.357802')),
#  ('Southeast', 'Ecolab', Decimal('5.357762')),
#  ('Southeast', 'Dominion Resources', Decimal('5.356350')),
#  ('West', 'eBay', Decimal('5.355893')),
#  ('West', 'News Corp.', Decimal('5.352728')),
#  ('Southeast', 'Entergy', Decimal('5.352683')),
#  ('Midwest', 'Sears Holdings', Decimal('5.351609')),
#  ('Midwest', 'AutoNation', Decimal('5.351093')),
#  ('Northeast', 'Wells Fargo', Decimal('5.351069')),
#  ('West', 'Reynolds American', Decimal('5.348768')),
#  ('Southeast', 'ADP', Decimal('5.348600')),
#  ('Southeast', 'Supervalu', Decimal('5.347728')),
#  ('Southeast', 'Visa', Decimal('5.347364')),
#  ('Northeast', 'Prudential Financial', Decimal('5.345360')),
#  ('Southeast', 'First Data', Decimal('5.343377')),
#  ('West', 'Core-Mark Holding', Decimal('5.343204')),
#  ('Northeast', 'Prudential Financial', Decimal('5.343113')),
#  ('West', 'CST Brands', Decimal('5.340655')),
#  ('Southeast', "Land O'Lakes", Decimal('5.340489')),
#  ('Northeast', 'FedEx', Decimal('5.340473')),
#  ('Northeast', 'Philip Morris International', Decimal('5.340240')),
#  ('Northeast', 'DuPont', Decimal('5.340188')),
#  ('Northeast', 'Philip Morris International', Decimal('5.339153')),
#  ('Northeast', 'CHS', Decimal('5.338940')),
#  ('West', 'Thrivent Financial for Lutherans', Decimal('5.337679')),
#  ('Southeast', 'Guardian Life Ins. Co. of America', Decimal('5.336701')),
#  ('Northeast', 'Freddie Mac', Decimal('5.336500')),
#  ('Midwest', 'AutoNation', Decimal('5.336298')),
#  ('Southeast', 'Farmers Insurance Exchange', Decimal('5.335868')),
#  ('Southeast', 'Guardian Life Ins. Co. of America', Decimal('5.334680')),
#  ('Midwest', 'Arrow Electronics', Decimal('5.334514')),
#  ('Southeast', 'Icahn Enterprises', Decimal('5.334229')),
#  ('Midwest', 'Dollar General', Decimal('5.333630')),
#  ('Southeast', 'Ecolab', Decimal('5.330652')),
#  ('Southeast', 'Entergy', Decimal('5.330491')),
#  ('Northeast', 'Johnson & Johnson', Decimal('5.329676')),
#  ('Midwest', 'AutoNation', Decimal('5.329012')),
#  ('West', 'Core-Mark Holding', Decimal('5.328663')),
#  ('Northeast', 'United Technologies', Decimal('5.328471')),
#  ('West', 'Jarden', Decimal('5.328030')),
#  ('Northeast', 'FedEx', Decimal('5.326170')),
#  ('Northeast', 'Archer Daniels Midland', Decimal('5.325870')),
#  ('Southeast', 'United States Steel', Decimal('5.324667')),
#  ('Northeast', 'General Dynamics', Decimal('5.324204')),
#  ('West', 'State Street Corp.', Decimal('5.324097')),
#  ('Northeast', 'United Continental Holdings', Decimal('5.323874')),
#  ('Southeast', 'Office Depot', Decimal('5.322043')),
#  ('Northeast', 'United Continental Holdings', Decimal('5.320581')),
#  ('Midwest', 'Altria Group', Decimal('5.319632')),
#  ('Northeast', 'Cisco Systems', Decimal('5.318950')),
#  ('Northeast', 'Gilead Sciences', Decimal('5.318727')),
#  ('Midwest', 'Centene', Decimal('5.314916')),
#  ('Southeast', 'Ecolab', Decimal('5.313321')),
#  ('Northeast', 'Aetna', Decimal('5.311991')),
#  ('Northeast', 'TIAA', Decimal('5.310935')),
#  ('Midwest', 'AutoNation', Decimal('5.310269')),
#  ('Southeast', 'Leucadia National', Decimal('5.309420')),
#  ('Northeast', 'Northwestern Mutual', Decimal('5.307969')),
#  ('Southeast', 'Leucadia National', Decimal('5.306557')),
#  ('Southeast', 'Texas Instruments', Decimal('5.306286')),
#  ('Midwest', 'Aflac', Decimal('5.305558')),
#  ('Midwest', 'USAA', Decimal('5.303969')),
#  ('Northeast', 'Fannie Mae', Decimal('5.303465')),
#  ('Northeast', 'Cigna', Decimal('5.303376')),
#  ('Southeast', 'BlackRock', Decimal('5.301770')),
#  ('Midwest', 'Sears Holdings', Decimal('5.300912')),
#  ('Northeast', 'Aetna', Decimal('5.299931')),
#  ('Southeast', 'CarMax', Decimal('5.297872')),
#  ('Northeast', 'Merck', Decimal('5.296391')),
#  ('Midwest', 'Penske Automotive Group', Decimal('5.295326')),
#  ('West', 'CST Brands', Decimal('5.295187')),
#  ('Southeast', 'Nucor', Decimal('5.289094')),
#  ('Southeast', 'Western Digital', Decimal('5.288827')),
#  ('Southeast', 'Western Digital', Decimal('5.286985')),
#  ('Southeast', 'DISH Network', Decimal('5.286009')),
#  ('West', 'Discover Financial Services', Decimal('5.284963')),
#  ('West', 'Murphy USA', Decimal('5.283893')),
#  ('West', 'Western Refining', Decimal('5.281447')),
#  ('West', 'eBay', Decimal('5.280189')),
#  ('Northeast', 'Aetna', Decimal('5.278860')),
#  ('Southeast', 'BlackRock', Decimal('5.278270')),
#  ('Northeast', 'Chevron', Decimal('5.278027')),
#  ('Southeast', 'Omnicom Group', Decimal('5.277712')),
#  ('West', 'Hormel Foods', Decimal('5.275300')),
#  ('West', 'Genworth Financial', Decimal('5.274013')),
#  ('Midwest', 'Plains GP Holdings', Decimal('5.273359')),
#  ('Northeast', 'Citigroup', Decimal('5.273081')),
#  ('Southeast', 'Ameriprise Financial', Decimal('5.272753')),
#  ('Northeast', 'Walgreens Boots Alliance', Decimal('5.270806')),
#  ('West', 'PayPal Holdings', Decimal('5.270170')),
#  ('Southeast', 'ADP', Decimal('5.270015')),
#  ('Southeast', 'Entergy', Decimal('5.269686')),
#  ('Southeast', 'DISH Network', Decimal('5.268641')),
#  ('Southeast', 'Colgate-Palmolive', Decimal('5.268605')),
#  ('Northeast', 'Disney', Decimal('5.268518')),
#  ('Southeast', 'Jabil Circuit', Decimal('5.268274')),
#  ('West', 'Republic Services', Decimal('5.266577')),
#  ('West', 'Stanley Black & Decker', Decimal('5.266396')),
#  ('Northeast', 'Intel', Decimal('5.266342')),
#  ('West', 'State Street Corp.', Decimal('5.265432')),
#  ('Northeast', 'Merck', Decimal('5.264836')),
#  ('Midwest', 'Emerson Electric', Decimal('5.264568')),
#  ('West', 'Global Partners', Decimal('5.263896')),
#  ('Southeast', 'BlackRock', Decimal('5.263295')),
#  ('Midwest', 'Altria Group', Decimal('5.263228')),
#  ('Southeast', 'Kellogg', Decimal('5.260253')),
#  ('Northeast', 'Philip Morris International', Decimal('5.260249')),
#  ('Southeast', 'Ross Stores', Decimal('5.259604')),
#  ('Southeast', 'FirstEnergy', Decimal('5.259461')),
#  ('Northeast', 'FedEx', Decimal('5.258073')),
#  ('West', 'CST Brands', Decimal('5.256892')),
#  ('West', 'eBay', Decimal('5.255533')),
#  ('West', 'Cameron International', Decimal('5.253787')),
#  ('Southeast', 'Ecolab', Decimal('5.252847')),
#  ('Southeast', 'Colgate-Palmolive', Decimal('5.251153')),
#  ('Northeast', 'Citigroup', Decimal('5.249528')),
#  ('Northeast', 'J.P. Morgan Chase', Decimal('5.248992')),
#  ('Southeast', 'FirstEnergy', Decimal('5.248561')),
#  ('West', 'Cameron International', Decimal('5.247959')),
#  ('Northeast', 'Marathon Petroleum', Decimal('5.247661')),
#  ('Northeast', 'TJX', Decimal('5.247399')),
#  ('Northeast', 'New York Life Insurance', Decimal('5.247322')),
#  ('Northeast', 'Disney', Decimal('5.246211')),
#  ('West', 'R.R. Donnelley & Sons', Decimal('5.245815')),
#  ('Southeast', 'Texas Instruments', Decimal('5.245779')),
#  ('Northeast', 'United Continental Holdings', Decimal('5.244170')),
#  ('Southeast', 'First Data', Decimal('5.244141')),
#  ('Northeast', 'Gilead Sciences', Decimal('5.243323')),
#  ('Southeast', 'FirstEnergy', Decimal('5.242785')),
#  ('Southeast', 'AECOM', Decimal('5.241733')),
#  ('Southeast', 'Omnicom Group', Decimal('5.241377')),
#  ('Southeast', 'Western Digital', Decimal('5.239137')),
#  ('Southeast', 'Colgate-Palmolive', Decimal('5.238727')),
#  ('Southeast', 'Office Depot', Decimal('5.238042')),
#  ('West', 'eBay', Decimal('5.237868')),
#  ('Southeast', 'Colgate-Palmolive', Decimal('5.236043')),
#  ('Midwest', 'Southwest Airlines', Decimal('5.235723')),
#  ...]

# %% [markdown]
# # Task 8: Efficiency in Action.
# By summarizing key sales figures for each account, this query provides a quick, actionable overview of business performance. Its brevity is designed to streamline data analysis, allowing decision-makers to efficiently uncover insights without unnecessary complexity.
#
# In the fast-paced business environment, time is of the essence, and succinct queries enable rapid decision-making. By focusing on essentials, they help businesses access valuable information in a way that's both time-efficient and results-oriented. This query, with its precision and brevity, exemplifies the power of efficient data analysis, shaping success and driving informed decisions.
#
# ===========
#
# Average Order Amounts by Account.
# Write SQL query for the following:
#
# What are the average amounts spent on standard, gloss, and poster orders for each account?

# %%
# %%sql
# select accounts.name as account_name, avg(orders.standard_amt_usd) as avg_standard_amt_usd, avg(orders.gloss_amt_usd) as gloss_amt_usd, avg(orders.poster_amt_usd) as avg_poster_amt_usd from accounts
# JOIN orders ON orders.account_id = accounts.id
# GROUP BY accounts.name;
# Out:
#  * mysql+pymysql://root:***@localhost/Sales_EDA
# 328 rows affected.
# [('3M', Decimal('841.438750'), Decimal('225.168125'), Decimal('268.467500')),
#  ('Abbott Laboratories', Decimal('489.269500'), Decimal('244.174000'), Decimal('217.210000')),
#  ('AbbVie', Decimal('503.990000'), Decimal('108.605000'), Decimal('223.300000')),
#  ('Univar', Decimal('2485.020000'), Decimal('71.904000'), Decimal('237.104000')),
#  ('Universal Health Services', Decimal('2582.325000'), Decimal('52.430000'), Decimal('0.000000')),
#  ('Unum Group', Decimal('2544.900000'), Decimal('611.683333'), Decimal('166.460000')),
#  ('UPS', Decimal('484.030000'), Decimal('239.680000'), Decimal('243.600000')),
#  ('US Foods Holding', Decimal('326.346000'), Decimal('1520.470000'), Decimal('144.536000')),
#  ('USAA', Decimal('1663.666000'), Decimal('353.528000'), Decimal('1151.416000')),
#  ('Valero Energy', Decimal('1241.797143'), Decimal('266.430000'), Decimal('190.240000')),
#  ('Veritiv', Decimal('713.570000'), Decimal('12.483333'), Decimal('59.546667')),
#  ('Verizon', Decimal('1468.931250'), Decimal('232.190000'), Decimal('173.565000')),
#  ('VF', Decimal('573.850000'), Decimal('243.425000'), Decimal('125.860000')),
#  ('Viacom', Decimal('2356.527500'), Decimal('231.565833'), Decimal('98.793333')),
#  ('Visa', Decimal('1803.607778'), Decimal('225.532222'), Decimal('68.568889')),
#  ('Voya Financial', Decimal('2638.712000'), Decimal('64.414000'), Decimal('99.064000')),
#  ('W.W. Grainger', Decimal('1452.090000'), Decimal('269.640000'), Decimal('211.120000')),
#  ('Walgreens Boots Alliance', Decimal('2695.125263'), Decimal('88.697368'), Decimal('104.277895')),
#  ('Walmart', Decimal('564.493750'), Decimal('339.390625'), Decimal('318.710000')),
#  ('Waste Management', Decimal('2939.110000'), Decimal('0.000000'), Decimal('162.400000')),
#  ('WellCare Health Plans', Decimal('484.030000'), Decimal('0.000000'), Decimal('194.880000')),
#  ('Wells Fargo', Decimal('1481.105926'), Decimal('416.943333'), Decimal('154.881481')),
#  ('Western Digital', Decimal('1470.342895'), Decimal('258.207895'), Decimal('219.881053')),
#  ('Western Refining', Decimal('2488.901111'), Decimal('658.842593'), Decimal('123.604444')),
#  ('WestRock', Decimal('748.500000'), Decimal('93.090000'), Decimal('212.280000')),
#  ('Whirlpool', Decimal('2221.658889'), Decimal('120.672222'), Decimal('248.111111')),
#  ('Whole Foods Market', Decimal('2589.810000'), Decimal('67.410000'), Decimal('71.456000')),
#  ('World Fuel Services', Decimal('485.693333'), Decimal('307.090000'), Decimal('162.400000')),
#  ('Xcel Energy', Decimal('2456.078000'), Decimal('1376.662000'), Decimal('86.072000')),
#  ('Xerox', Decimal('2624.740000'), Decimal('41.195000'), Decimal('81.200000')),
#  ('Yum Brands', Decimal('2241.064444'), Decimal('62.416667'), Decimal('59.546667'))]

# %% [markdown]
# # Task 9: Streamlining Insights.
# By calculating and summarizing average sales amounts for various product types and generating a total, this query provides a swift, yet comprehensive view of account performance. Its brevity is intentional, designed to streamline data analysis while offering quick access to actionable insights.
#
# In a rapidly evolving business landscape, time efficiency is paramount. Such succinct queries empower decision-makers to swiftly access valuable information and make informed choices without delving into complexity. This query, with its precision and efficiency, exemplifies the power of streamlined data analysis, shaping success and driving effective decisions in a fast-paced environment.
#
# ============
#
# Average Order Amounts and Total Spending by Account.
# Write SQL query for the following:
#
# For each account, what are the average amounts spent on standard, gloss, and poster orders, as well as the total spending across all order types?

# %%
# %%sql
# select accounts.name as account_name, avg(orders.standard_amt_usd) as avg_standard_amt_usd, avg(orders.gloss_amt_usd) as gloss_amt_usd, avg(orders.poster_amt_usd) as avg_poster_amt_usd, (avg(orders.standard_amt_usd) + avg(orders.gloss_amt_usd) + avg(orders.poster_amt_usd)) as total from accounts
# JOIN orders ON orders.account_id = accounts.id
# GROUP BY accounts.name;
# Out:
#  * mysql+pymysql://root:***@localhost/Sales_EDA
# 328 rows affected.
# [('3M', Decimal('841.438750'), Decimal('225.168125'), Decimal('268.467500'), Decimal('1335.074375')),
#  ('Abbott Laboratories', Decimal('489.269500'), Decimal('244.174000'), Decimal('217.210000'), Decimal('950.653500')),
#  ('AbbVie', Decimal('503.990000'), Decimal('108.605000'), Decimal('223.300000'), Decimal('835.895000')),
#  ('ADP', Decimal('2428.160263'), Decimal('130.680789'), Decimal('442.540000'), Decimal('3001.381053')),
#  ('Advance Auto Parts', Decimal('1367.260000'), Decimal('147.927500'), Decimal('225.330000'), Decimal('1740.517500')),
#  ('AECOM', Decimal('2305.380000'), Decimal('88.810000'), Decimal('126.440000'), Decimal('2520.630000')),
#  ('AES', Decimal('1734.025000'), Decimal('1554.175000'), Decimal('12.180000'), Decimal('3300.380000')),
#  ('Aetna', Decimal('1567.011212'), Decimal('260.334242'), Decimal('304.376970'), Decimal('2131.722424')),
#  ('Aflac', Decimal('2556.223462'), Decimal('194.163846'), Decimal('745.166154'), Decimal('3495.553462')),
#  ('AIG', Decimal('523.950000'), Decimal('232.190000'), Decimal('146.160000'), Decimal('902.300000')),
#  ('Air Products & Chemicals', Decimal('545.573333'), Decimal('132.323333'), Decimal('249.013333'), Decimal('926.910000')),
#  ('Alcoa', Decimal('2126.987500'), Decimal('48.685000'), Decimal('149.205000'), Decimal('2324.877500')),
#  ('Allstate', Decimal('1463.733333'), Decimal('242.676000'), Decimal('145.618667'), Decimal('1852.028000')),
#  ('Ally Financial', Decimal('460.327500'), Decimal('76.772500'), Decimal('300.440000'), Decimal('837.540000')),
#  ('Alphabet', Decimal('670.656000'), Decimal('166.278000'), Decimal('183.512000'), Decimal('1020.446000')),
#  ('Altria Group', Decimal('2479.262308'), Decimal('112.157949'), Decimal('176.349744'), Decimal('2767.770000')),
#  ('Amazon.com', Decimal('1443.108000'), Decimal('175.266000'), Decimal('315.056000'), Decimal('1933.430000')),
#  ('American Airlines Group', Decimal('2525.563750'), Decimal('38.386250'), Decimal('889.140000'), Decimal('3453.090000')),
#  ('American Electric Power', Decimal('2492.006000'), Decimal('62.916000'), Decimal('136.416000'), Decimal('2691.338000')),
#  ('American Express', Decimal('2473.257857'), Decimal('222.560000'), Decimal('70.180000'), Decimal('2765.997857')),
#  ('Ameriprise Financial', Decimal('2618.869412'), Decimal('121.161765'), Decimal('222.105882'), Decimal('2962.137059')),
#  ('AmerisourceBergen', Decimal('1621.750000'), Decimal('441.910000'), Decimal('93.380000'), Decimal('2157.040000')),
#  ('Voya Financial', Decimal('2638.712000'), Decimal('64.414000'), Decimal('99.064000'), Decimal('2802.190000')),
#  ('W.W. Grainger', Decimal('1452.090000'), Decimal('269.640000'), Decimal('211.120000'), Decimal('1932.850000')),
#  ('Walgreens Boots Alliance', Decimal('2695.125263'), Decimal('88.697368'), Decimal('104.277895'), Decimal('2888.100526')),
#  ('Walmart', Decimal('564.493750'), Decimal('339.390625'), Decimal('318.710000'), Decimal('1222.594375')),
#  ('Waste Management', Decimal('2939.110000'), Decimal('0.000000'), Decimal('162.400000'), Decimal('3101.510000')),
#  ('WellCare Health Plans', Decimal('484.030000'), Decimal('0.000000'), Decimal('194.880000'), Decimal('678.910000')),
#  ('Wells Fargo', Decimal('1481.105926'), Decimal('416.943333'), Decimal('154.881481'), Decimal('2052.930741')),
#  ('Western Digital', Decimal('1470.342895'), Decimal('258.207895'), Decimal('219.881053'), Decimal('1948.431842')),
#  ('Western Refining', Decimal('2488.901111'), Decimal('658.842593'), Decimal('123.604444'), Decimal('3271.348148')),
#  ('WestRock', Decimal('748.500000'), Decimal('93.090000'), Decimal('212.280000'), Decimal('1053.870000')),
#  ('Whirlpool', Decimal('2221.658889'), Decimal('120.672222'), Decimal('248.111111'), Decimal('2590.442222')),
#  ('Whole Foods Market', Decimal('2589.810000'), Decimal('67.410000'), Decimal('71.456000'), Decimal('2728.676000')),
#  ('World Fuel Services', Decimal('485.693333'), Decimal('307.090000'), Decimal('162.400000'), Decimal('955.183333')),
#  ('Xcel Energy', Decimal('2456.078000'), Decimal('1376.662000'), Decimal('86.072000'), Decimal('3918.812000')),
#  ('Xerox', Decimal('2624.740000'), Decimal('41.195000'), Decimal('81.200000'), Decimal('2747.135000')),
#  ('Yum Brands', Decimal('2241.064444'), Decimal('62.416667'), Decimal('59.546667'), Decimal('2363.027778'))]

# %% [markdown]
# # Task 10: Efficiency in Data Insight.
# By counting occurrences of channels associated with sales representatives and sorting them in descending order, this query rapidly reveals the most frequent engagement channels. Its brevity is a strategic choice, aimed at swiftly delivering actionable insights without unnecessary complexity.
#
# In a dynamic business landscape, time efficiency is a critical factor. Such succinct queries empower decision-makers to quickly access valuable information, facilitating informed decisions without cumbersome data analysis. This query, with its precision and brevity, exemplifies the power of streamlined data analysis, optimizing engagement strategies and driving results in a fast-paced environment.
#
# ==========
#
# Number of Web Events by Sales Representative and Channel.
# Write SQL query for the following:
#
# How many web events occurred for each sales representative and channel combination?

# %%
# %%sql
# select sales_reps.name as sales_rep, web_events.channel as channel, COUNT(web_events.account_id) as number_of_occurrences from web_events
# JOIN accounts ON accounts.id = web_events.account_id
# JOIN sales_reps ON sales_reps.id = accounts.sales_rep_id
# GROUP BY sales_reps.name, web_events.channel;
# Out:
#  * mysql+pymysql://root:***@localhost/Sales_EDA
# 294 rows affected.
# [('Akilah Drinkard', 'adwords', 5),
#  ('Akilah Drinkard', 'banner', 9),
#  ('Akilah Drinkard', 'direct', 53),
#  ('Akilah Drinkard', 'facebook', 9),
#  ('Akilah Drinkard', 'organic', 15),
#  ('Akilah Drinkard', 'twitter', 2),
#  ('Arica Stoltzfus', 'adwords', 4),
#  ('Arica Stoltzfus', 'banner', 6),
#  ('Arica Stoltzfus', 'direct', 119),
#  ('Arica Stoltzfus', 'facebook', 7),
#  ('Arica Stoltzfus', 'organic', 5),
#  ('Ayesha Monica', 'adwords', 9),
#  ('Ayesha Monica', 'banner', 7),
#  ('Ayesha Monica', 'direct', 70),
#  ('Ayesha Monica', 'facebook', 15),
#  ('Ayesha Monica', 'organic', 22),
#  ('Ayesha Monica', 'twitter', 9),
#  ('Babette Soukup', 'adwords', 7),
#  ('Babette Soukup', 'banner', 8),
#  ('Babette Soukup', 'direct', 59),
#  ('Babette Soukup', 'facebook', 8),
#  ('Babette Soukup', 'organic', 2),
#  ('Babette Soukup', 'twitter', 3),
#  ('Brandie Riva', 'adwords', 18),
#  ('Brandie Riva', 'banner', 4),
#  ('Brandie Riva', 'direct', 121),
#  ('Brandie Riva', 'facebook', 16),
#  ('Brandie Riva', 'organic', 15),
#  ('Brandie Riva', 'twitter', 9),
#  ('Calvin Ollison', 'adwords', 21),
#  ('Calvin Ollison', 'banner', 10),
#  ('Calvin Ollison', 'direct', 139),
#  ('Calvin Ollison', 'facebook', 22),
#  ('Calvin Ollison', 'organic', 21),
#  ('Calvin Ollison', 'twitter', 8),
#  ('Cara Clarke', 'adwords', 9),
#  ('Cara Clarke', 'banner', 5),
#  ('Cara Clarke', 'direct', 42),
#  ('Cara Clarke', 'facebook', 3),
#  ('Cara Clarke', 'organic', 8),
#  ('Cara Clarke', 'twitter', 1),
#  ('Carletta Kosinski', 'adwords', 11),
#  ('Carletta Kosinski', 'banner', 6),
#  ('Carletta Kosinski', 'direct', 54),
#  ('Carletta Kosinski', 'facebook', 13),
#  ('Carletta Kosinski', 'organic', 14),
#  ('Carletta Kosinski', 'twitter', 4),
#  ('Charles Bidwell', 'adwords', 18),
#  ('Charles Bidwell', 'banner', 16),
#  ('Charles Bidwell', 'direct', 159),
#  ('Charles Bidwell', 'facebook', 27),
#  ('Charles Bidwell', 'organic', 17),
#  ('Charles Bidwell', 'twitter', 15),
#  ('Chau Rowles', 'adwords', 3),
#  ('Chau Rowles', 'banner', 4),
#  ('Chau Rowles', 'direct', 48),
#  ('Chau Rowles', 'facebook', 9),
#  ('Chau Rowles', 'organic', 3),
#  ('Chau Rowles', 'twitter', 5),
#  ('Cliff Meints', 'adwords', 21),
#  ('Cliff Meints', 'banner', 6),
#  ('Cliff Meints', 'direct', 122),
#  ('Cliff Meints', 'facebook', 23),
#  ('Cliff Meints', 'organic', 21),
#  ('Cliff Meints', 'twitter', 12),
#  ('Cordell Rieder', 'adwords', 7),
#  ('Cordell Rieder', 'banner', 3),
#  ('Cordell Rieder', 'direct', 67),
#  ('Cordell Rieder', 'facebook', 6),
#  ('Cordell Rieder', 'organic', 10),
#  ('Cordell Rieder', 'twitter', 2),
#  ('Dawna Agnew', 'adwords', 9),
#  ('Dawna Agnew', 'banner', 5),
#  ('Dawna Agnew', 'direct', 80),
#  ('Dawna Agnew', 'facebook', 8),
#  ('Dawna Agnew', 'organic', 10),
#  ('Dawna Agnew', 'twitter', 4),
#  ('Debroah Wardle', 'adwords', 14),
#  ('Debroah Wardle', 'banner', 10),
#  ('Debroah Wardle', 'direct', 83),
#  ('Debroah Wardle', 'facebook', 26),
#  ('Debroah Wardle', 'organic', 14),
#  ('Debroah Wardle', 'twitter', 11),
#  ('Delilah Krum', 'adwords', 24),
#  ('Delilah Krum', 'banner', 10),
#  ('Delilah Krum', 'direct', 144),
#  ('Delilah Krum', 'facebook', 29),
#  ('Delilah Krum', 'organic', 32),
#  ('Delilah Krum', 'twitter', 21),
#  ('Derrick Boggess', 'adwords', 20),
#  ('Derrick Boggess', 'banner', 3),
#  ('Derrick Boggess', 'direct', 80),
#  ('Derrick Boggess', 'facebook', 15),
#  ('Derrick Boggess', 'organic', 10),
#  ('Derrick Boggess', 'twitter', 7),
#  ('Dorotha Seawell', 'adwords', 25),
#  ('Dorotha Seawell', 'banner', 16),
#  ('Dorotha Seawell', 'direct', 161),
#  ('Dorotha Seawell', 'facebook', 32),
#  ('Dorotha Seawell', 'organic', 36),
#  ('Dorotha Seawell', 'twitter', 14),
#  ('Earlie Schleusner', 'adwords', 26),
#  ('Earlie Schleusner', 'banner', 23),
#  ('Earlie Schleusner', 'direct', 234),
#  ('Earlie Schleusner', 'facebook', 36),
#  ('Earlie Schleusner', 'organic', 31),
#  ('Earlie Schleusner', 'twitter', 12),
#  ('Elba Felder', 'adwords', 17),
#  ('Elba Felder', 'banner', 3),
#  ('Elba Felder', 'direct', 54),
#  ('Elba Felder', 'facebook', 18),
#  ('Elba Felder', 'organic', 19),
#  ('Elba Felder', 'twitter', 12),
#  ('Elna Condello', 'adwords', 26),
#  ('Elna Condello', 'banner', 14),
#  ('Elna Condello', 'direct', 146),
#  ('Elna Condello', 'facebook', 39),
#  ('Elna Condello', 'organic', 31),
#  ('Elna Condello', 'twitter', 11),
#  ('Elwood Shutt', 'adwords', 9),
#  ('Elwood Shutt', 'banner', 5),
#  ('Elwood Shutt', 'direct', 127),
#  ('Elwood Shutt', 'facebook', 5),
#  ('Elwood Shutt', 'organic', 10),
#  ('Elwood Shutt', 'twitter', 6),
#  ('Ernestine Pickron', 'adwords', 20),
#  ('Ernestine Pickron', 'banner', 7),
#  ('Ernestine Pickron', 'direct', 65),
#  ('Ernestine Pickron', 'facebook', 14),
#  ('Ernestine Pickron', 'organic', 14),
#  ('Ernestine Pickron', 'twitter', 3),
#  ('Eugena Esser', 'adwords', 15),
#  ('Eugena Esser', 'banner', 7),
#  ('Eugena Esser', 'direct', 85),
#  ('Eugena Esser', 'facebook', 18),
#  ('Eugena Esser', 'organic', 19),
#  ('Eugena Esser', 'twitter', 8),
#  ('Georgianna Chisholm', 'adwords', 6),
#  ('Georgianna Chisholm', 'banner', 3),
#  ('Georgianna Chisholm', 'direct', 160),
#  ('Georgianna Chisholm', 'facebook', 5),
#  ('Georgianna Chisholm', 'organic', 8),
#  ('Georgianna Chisholm', 'twitter', 1),
#  ('Gianna Dossey', 'adwords', 26),
#  ('Gianna Dossey', 'banner', 10),
#  ('Gianna Dossey', 'direct', 140),
#  ('Gianna Dossey', 'facebook', 25),
#  ('Gianna Dossey', 'organic', 19),
#  ('Gianna Dossey', 'twitter', 12),
#  ('Hilma Busick', 'adwords', 5),
#  ('Hilma Busick', 'banner', 4),
#  ('Hilma Busick', 'direct', 127),
#  ('Hilma Busick', 'facebook', 10),
#  ('Hilma Busick', 'organic', 10),
#  ('Hilma Busick', 'twitter', 5),
#  ('Julia Behrman', 'adwords', 19),
#  ('Julia Behrman', 'banner', 9),
#  ('Julia Behrman', 'direct', 102),
#  ('Julia Behrman', 'facebook', 9),
#  ('Julia Behrman', 'organic', 22),
#  ('Julia Behrman', 'twitter', 13),
#  ('Julie Starr', 'adwords', 3),
#  ('Julie Starr', 'banner', 5),
#  ('Julie Starr', 'direct', 28),
#  ('Julie Starr', 'facebook', 3),
#  ('Julie Starr', 'organic', 2),
#  ('Kathleen Lalonde', 'adwords', 2),
#  ('Kathleen Lalonde', 'banner', 1),
#  ('Kathleen Lalonde', 'direct', 24),
#  ('Kathleen Lalonde', 'facebook', 9),
#  ('Kathleen Lalonde', 'organic', 9),
#  ('Kathleen Lalonde', 'twitter', 2),
#  ('Lavera Oles', 'adwords', 11),
#  ('Lavera Oles', 'banner', 6),
#  ('Lavera Oles', 'direct', 52),
#  ('Lavera Oles', 'facebook', 12),
#  ('Lavera Oles', 'organic', 13),
#  ('Lavera Oles', 'twitter', 4),
#  ('Maren Musto', 'adwords', 35),
#  ('Maren Musto', 'banner', 17),
#  ('Maren Musto', 'direct', 184),
#  ('Maren Musto', 'facebook', 44),
#  ('Maren Musto', 'organic', 49),
#  ('Maren Musto', 'twitter', 21),
#  ('Marquetta Laycock', 'adwords', 5),
#  ('Marquetta Laycock', 'banner', 2),
#  ('Marquetta Laycock', 'direct', 63),
#  ('Marquetta Laycock', 'facebook', 4),
#  ('Marquetta Laycock', 'organic', 6),
#  ('Marquetta Laycock', 'twitter', 2),
#  ('Maryanna Fiorentino', 'adwords', 8),
#  ('Maryanna Fiorentino', 'banner', 3),
#  ('Maryanna Fiorentino', 'direct', 134),
#  ('Maryanna Fiorentino', 'facebook', 5),
#  ('Maryanna Fiorentino', 'organic', 5),
#  ('Maryanna Fiorentino', 'twitter', 1),
#  ('Micha Woodford', 'adwords', 7),
#  ('Micha Woodford', 'banner', 2),
#  ('Micha Woodford', 'direct', 129),
#  ('Micha Woodford', 'facebook', 3),
#  ('Micha Woodford', 'organic', 2),
#  ('Micha Woodford', 'twitter', 4),
#  ('Michel Averette', 'adwords', 24),
#  ('Michel Averette', 'banner', 16),
#  ('Michel Averette', 'direct', 145),
#  ('Michel Averette', 'facebook', 30),
#  ('Michel Averette', 'organic', 25),
#  ('Michel Averette', 'twitter', 10),
#  ('Moon Torian', 'adwords', 31),
#  ('Moon Torian', 'banner', 18),
#  ('Moon Torian', 'direct', 194),
#  ('Moon Torian', 'facebook', 38),
#  ('Moon Torian', 'organic', 34),
#  ('Moon Torian', 'twitter', 18),
#  ('Nakesha Renn', 'banner', 2),
#  ('Nakesha Renn', 'direct', 10),
#  ('Nakesha Renn', 'facebook', 1),
#  ('Nakesha Renn', 'organic', 1),
#  ('Nakesha Renn', 'twitter', 1),
#  ('Necole Victory', 'adwords', 22),
#  ('Necole Victory', 'banner', 8),
#  ('Necole Victory', 'direct', 109),
#  ('Necole Victory', 'facebook', 17),
#  ('Necole Victory', 'organic', 6),
#  ('Necole Victory', 'twitter', 5),
#  ('Nelle Meaux', 'adwords', 30),
#  ('Nelle Meaux', 'banner', 18),
#  ('Nelle Meaux', 'direct', 179),
#  ('Nelle Meaux', 'facebook', 22),
#  ('Nelle Meaux', 'organic', 28),
#  ('Nelle Meaux', 'twitter', 11),
#  ('Renetta Carew', 'adwords', 10),
#  ('Renetta Carew', 'banner', 6),
#  ('Renetta Carew', 'direct', 58),
#  ('Renetta Carew', 'facebook', 14),
#  ('Renetta Carew', 'organic', 11),
#  ('Renetta Carew', 'twitter', 7),
#  ('Retha Sears', 'adwords', 8),
#  ('Retha Sears', 'banner', 2),
#  ('Retha Sears', 'direct', 49),
#  ('Retha Sears', 'facebook', 4),
#  ('Retha Sears', 'organic', 13),
#  ('Retha Sears', 'twitter', 3),
#  ('Samuel Racine', 'adwords', 11),
#  ('Samuel Racine', 'banner', 7),
#  ('Samuel Racine', 'direct', 99),
#  ('Samuel Racine', 'facebook', 11),
#  ('Samuel Racine', 'organic', 10),
#  ('Samuel Racine', 'twitter', 2),
#  ('Saran Ram', 'adwords', 26),
#  ('Saran Ram', 'banner', 18),
#  ('Saran Ram', 'direct', 86),
#  ('Saran Ram', 'facebook', 25),
#  ('Saran Ram', 'organic', 24),
#  ('Saran Ram', 'twitter', 17),
#  ('Shawanda Selke', 'adwords', 2),
#  ('Shawanda Selke', 'banner', 1),
#  ('Shawanda Selke', 'direct', 64),
#  ('Shawanda Selke', 'facebook', 1),
#  ('Shawanda Selke', 'organic', 1),
#  ('Sherlene Wetherington', 'adwords', 12),
#  ('Sherlene Wetherington', 'banner', 8),
#  ('Sherlene Wetherington', 'direct', 50),
#  ('Sherlene Wetherington', 'facebook', 6),
#  ('Sherlene Wetherington', 'organic', 9),
#  ('Sherlene Wetherington', 'twitter', 10),
#  ('Sibyl Lauria', 'adwords', 23),
#  ('Sibyl Lauria', 'banner', 7),
#  ('Sibyl Lauria', 'direct', 147),
#  ('Sibyl Lauria', 'facebook', 26),
#  ('Sibyl Lauria', 'organic', 20),
#  ('Sibyl Lauria', 'twitter', 19),
#  ('Silvana Virden', 'adwords', 2),
#  ('Silvana Virden', 'banner', 2),
#  ('Silvana Virden', 'direct', 42),
#  ('Silvana Virden', 'twitter', 2),
#  ('Soraya Fulton', 'adwords', 7),
#  ('Soraya Fulton', 'banner', 3),
#  ('Soraya Fulton', 'direct', 45),
#  ('Soraya Fulton', 'facebook', 8),
#  ('Soraya Fulton', 'organic', 5),
#  ('Soraya Fulton', 'twitter', 6),
#  ('Tia Amato', 'adwords', 27),
#  ('Tia Amato', 'banner', 17),
#  ('Tia Amato', 'direct', 185),
#  ('Tia Amato', 'facebook', 43),
#  ('Tia Amato', 'organic', 34),
#  ('Tia Amato', 'twitter', 19),
#  ('Vernita Plump', 'adwords', 43),
#  ('Vernita Plump', 'banner', 15),
#  ('Vernita Plump', 'direct', 232),
#  ('Vernita Plump', 'facebook', 36),
#  ('Vernita Plump', 'organic', 40),
#  ('Vernita Plump', 'twitter', 16)]

# %% [markdown]
# # Task 11: Swift Insights.
# By extracting and summing annual sales totals and arranging them in ascending order, this query provides rapid access to key revenue trends. Its brevity is a deliberate choice, crafted for efficient data analysis that delivers quick, actionable insights.
#
# In the fast-paced business environment, time efficiency is a precious asset. Such succinct queries empower decision-makers to promptly uncover valuable information and make informed choices without getting lost in complexity. This query, with its precision and brevity, embodies the power of streamlined data analysis, shaping a more informed approach to business decision-making.
#
# ===============
#
# Total Revenue by Year.
# Write SQL query for the following:
#
# What is the total revenue generated from orders each year, and how does it vary over the years?

# %%
# %%sql
# select SUM(total_amt_usd), YEAR(occurred_at) as Year from orders
# GROUP BY YEAR(occurred_at)
# ORDER BY YEAR ASC;
# Out:
#  * mysql+pymysql://root:***@localhost/Sales_EDA
# 5 rows affected.
# [(Decimal('177253.97'), 2013),
#  (Decimal('1676803.62'), 2014),
#  (Decimal('2659633.12'), 2015),
#  (Decimal('5891837.74'), 2016),
#  (Decimal('23424.03'), 2017)]

# %% [markdown]
# # Task 12: Yearly Revenue Insights.
# By extracting and summing monthly sales totals for specific years and arranging the results by year, it swiftly reveals revenue patterns. Its brevity is strategic, enabling rapid data analysis for quick access to actionable insights.
#
# In the fast-paced business world, time is of the essence. Such succinct queries empower decision-makers to promptly uncover valuable information, streamlining the path to informed choices without unnecessary complexity. This query, with its precision and brevity, showcases the value of streamlined data analysis, facilitating a more agile approach to making business decisions.
#
# ==========
#
# Total Revenue by Year and Month (2013 and 2017).
# Write SQL query for the following:
#
# What is the total revenue generated from orders each month in the years 2013 and 2017?

# %%
# %%sql
# select SUM(total_amt_usd), MONTH(occurred_at) as Month, YEAR(occurred_at) as Year from orders
# WHERE YEAR(occurred_at) = '2013' or YEAR(occurred_at) = '2017'
# GROUP BY MONTH(occurred_at)
# ORDER BY MONTH ASC;
# Out:
#  * mysql+pymysql://root:***@localhost/Sales_EDA
# 2 rows affected.
# [(Decimal('23424.03'), 1, 2017), (Decimal('177253.97'), 12, 2013)]

# %% [markdown]
# # Task 13: Unveiling Daily Sales.
# This compact query serves a specific purpose. It extracts and sums daily sales totals for the year 2017, providing insights into daily revenue trends. Its brevity is intentional, designed for efficient data analysis that offers quick access to granular insights.
#
# In a fast-moving business landscape, time efficiency is invaluable. Such concise queries empower decision-makers to swiftly uncover detailed information and make informed choices without wading through unnecessary complexity. This query, with its precision and brevity, exemplifies the power of streamlined data analysis, revealing daily sales nuances and enabling agile decision-making
#
#
# =============
#
# Total Revenue by Year, Month, and Day (2017).
# Write SQL query for the following:
#
# What is the total revenue generated from orders each day in each month of the year 2017?

# %%
# %%sql
# select SUM(total_amt_usd), DAY(occurred_at) as Day, MONTH(occurred_at) as Month, YEAR(occurred_at) as Year from orders
# WHERE YEAR(occurred_at) = '2017'
# GROUP BY DAY(occurred_at)
# ORDER BY DAY ASC;
#  * mysql+pymysql://b476dbe7:***@localhost/b476dbe7
# 1 rows affected.
# Out:
#  * mysql+pymysql://root:***@localhost/Sales_EDA
# 1 rows affected.
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MariaDB server version for the right syntax to use near '* mysql+pymysql://b476dbe7:***@localhost/b476dbe7\n1 rows affected.' at line 1")
# [SQL: * mysql+pymysql://b476dbe7:***@localhost/b476dbe7
# 1 rows affected.]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# # Task 14: Unlocking New Year's Data.
# This concise query has a clear purpose in the world of data analysis. It extracts and summarizes daily sales totals specifically for January 1st, offering insights into the start of each year. Its brevity is deliberate, designed to efficiently uncover granular insights without unnecessary complexity.
#
# In a dynamic business environment, time efficiency is essential. Such succinct queries empower decision-makers to rapidly access precise information, aiding informed choices without cumbersome data analysis. This query, with its precision and brevity, showcases the power of streamlined data analysis, uncovering specific details for agile decision-making in the fast-paced business landscape.
#
# =============
#
# Total Revenue on January 1st.
# Write SQL query for the following:
#
# What is the total revenue generated from orders on January 1st of each year?

# %%
# %%sql
# select SUM(total_amt_usd), DAY(occurred_at) as Day, MONTH(occurred_at) as Month, YEAR(occurred_at) as Year from orders
# WHERE DAY(occurred_at) = '01' AND MONTH(occurred_at) = '01'
# GROUP BY Year(occurred_at);
# Out:
#  * mysql+pymysql://root:***@localhost/Sales_EDA
# 4 rows affected.
# [(Decimal('7453.77'), 1, 1, 2014),
#  (Decimal('7747.95'), 1, 1, 2015),
#  (Decimal('6499.10'), 1, 1, 2016),
#  (Decimal('23424.03'), 1, 1, 2017)]

# %% [markdown]
# # Task 15: Walmart's Triumph.
# This query efficiently extracts the highest monthly gloss sales for 'Walmart,' showcasing detailed insights into their performance. Its brevity is strategic, enabling rapid access to the most critical data without unnecessary complexity.
#
# In the fast-paced world of business, time efficiency is invaluable. Such succinct queries empower decision-makers to swiftly access precise information, aiding quick and informed choices without delving into unnecessary data layers. This query, with its precision and brevity, embodies the power of streamlined data analysis, helping businesses extract vital insights with minimal effort.
#
# ==============
#
# Monthly Gloss Revenue for Walmart.
# Write SQL query for the following:
#
# What is the total revenue generated from gloss orders each month for the account named Walmart, and which month had the highest gloss revenue?

# %%
# %%sql
# select accounts.name as account_name, MONTH(occurred_at) as Month, YEAR(occurred_at) as Year, SUM(gloss_amt_usd) as total from orders
# JOIN accounts on accounts.id =orders.account_id
# WHERE accounts.name = 'Walmart'
# GROUP BY Month(occurred_at), Year(occurred_at)
# ORDER BY total DESC
# LIMIT 1;
# Out:
#  * mysql+pymysql://root:***@localhost/Sales_EDA
# 1 rows affected.
# [('Walmart', 10, 2016, Decimal('1071.07'))]
